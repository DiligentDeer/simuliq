# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import pandas as pd
import logging
import matplotlib.pyplot as plt
import json
import pickle
from itertools import product
from tqdm import tqdm
import numpy as np

# Add the project root to the system path using the current working directory
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# Import using absolute path from project root
from src.instances.chain_instance import ARBITRUM_DTO, OPTIMISM_DTO, ETHEREUM_DTO, BASE_DTO
from src.instances.aave_instance import AaveArbitrum, AaveOptimism, AaveEthereum, AaveBase
from src.models.token import TokenDTO
from src.models.trade_pair import PairDTO
# Out:
# 2024-12-15 21:38:28,675 INFO src.models.aave_protocol Initialized Aave Protocol DTO for network: Arbitrum
# 2024-12-15 21:38:28,676 INFO src.models.aave_protocol Initialized Aave Protocol DTO for network: Optimism
# 2024-12-15 21:38:28,677 INFO src.models.aave_protocol Initialized Aave Protocol DTO for network: Ethereum
# 2024-12-15 21:38:28,677 INFO src.models.aave_protocol Initialized Aave Protocol DTO for network: Base

# %%
from src.scripts.process_stored_data_aave import update_trade_pair_exchange_price, \
    create_liquidatable_user_data_series, create_health_ratio_data_emode, create_asset_mapping, \
    create_health_ratio_data, create_liquidatable_user_data, scale_supply_and_create_liquidations, \
    create_liquidations_v2, scale_price_and_identify_liquidatable_collateral

# %%
chain_object_mapping = {
    'ethereum': [ETHEREUM_DTO, AaveEthereum],
    'arbitrum': [ARBITRUM_DTO, AaveArbitrum],
    'optimism': [OPTIMISM_DTO, AaveOptimism],
    'base': [BASE_DTO, AaveBase]
}

# %%
CHOOSEN_CHAIN = 'ethereum'
AAVE_EMODE_LT = 0.95
ASSET_UNDER_CONSIDERATION = "weETH"
EMODE_SWITCH = False
ASSET_UNDER_CONSIDERATION_CURVE = 'wstETH'
SOFT_LIQUIDATION_EFFICIENCY = 0.80
PRICE_DROP_FACTOR = 0.80



if CHOOSEN_CHAIN not in chain_object_mapping:
    print("Invalid chain chosen.")
    exit(1)
else:
    chain_instance, aave_instance = chain_object_mapping[CHOOSEN_CHAIN]

# %%
if not os.path.exists('aave_supported_asset_data.csv'):
    print("File not found. Fetching from RPC.")
    aave_supported_asset_data = aave_instance.get_aave_supported_asset_data()
    print("Saving to file.")
    aave_supported_asset_data.to_csv('aave_supported_asset_data.csv', index=False)
else:
    print("File found. Reading from file.")
    aave_supported_asset_data = pd.read_csv('aave_supported_asset_data.csv')
# Out:
# File found. Reading from file.

# %%
if not os.path.exists('aave_user_position_data.csv'):
    print("File not found. Fetching from RPC.")
    aave_user_position_data = aave_instance.get_user_position_data(aave_supported_asset_data)
    print("Saving to file.")
    aave_user_position_data.to_csv('aave_user_position_data.csv', index=False)
else:
    print("File found. Reading from file.")
    aave_user_position_data = pd.read_csv('aave_user_position_data.csv')


if not EMODE_SWITCH:
    # Filter out 0 from emode column
    aave_user_position_data = aave_user_position_data[aave_user_position_data['emode'] == 0]
# Out:
# File found. Reading from file.

# %%
aave_asset_object_dict = {}

for _, row in tqdm(aave_supported_asset_data.iterrows(), total=len(aave_supported_asset_data), desc="Creating TokenDTO objects"):
    token = TokenDTO(
        address=row['assetAddress'],
        name=row['symbol'],
        symbol=row['symbol'],
        decimals=row['decimals'],
        chain=chain_instance,
        price=row['price'],
    )
    aave_asset_object_dict[row['symbol']] = token
# Out:
# Creating TokenDTO objects: 100%|██████████| 37/37 [00:09<00:00,  3.91it/s]

# %%
current_price_mapping = {}
for index, asset in aave_supported_asset_data.iterrows():
    current_price_mapping[asset['symbol']] = asset['price']

# %%
# liquidatable_price_df = scale_price_and_identify_liquidatable_collateral(aave_supported_asset_data, 
#                                                             aave_user_position_data, 
#                                                             current_price_mapping, 
#                                                             AAVE_EMODE_LT, 
#                                                             ASSET_UNDER_CONSIDERATION,
#                                                             0.5, 
#                                                             30)

# %%
# # plot scale and liquidatable_collateral
# plt.figure(figsize=(16, 8))
# plt.plot(liquidatable_price_df['price'], liquidatable_price_df['liquidatable_collateral'], label='Liquidatable Collateral')
# plt.xlabel('Price')
# plt.ylabel('Liquidatable Collateral')
# plt.title('Liquidatable Collateral vs Scale')
# plt.legend()
# plt.grid(True, linestyle=':', alpha=0.7)
# plt.show()

# %% [markdown]
# ## Curve user positions

# %%
from src.instances.curve_mint_market_instance import market_objects_dict

# %%
market = market_objects_dict[ASSET_UNDER_CONSIDERATION_CURVE]
df = market.get_user_position_data()

# %%
output_liq_df, output_liq_df_raw = market.compute_price_for_max_hard_liq(df, SOFT_LIQUIDATION_EFFICIENCY)

# %%
output_liq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   max_price             8 non-null      float64
#  1   max_collateral_value  8 non-null      float64
#  2   debt                  8 non-null      float64
# dtypes: float64(3)
# memory usage: 324.0 bytes

# %%
# # Convert liquidatable_price_df's cumulative values to absolute values
# liquidatable_price_abs_df = liquidatable_price_df.copy()
# liquidatable_price_abs_df = liquidatable_price_abs_df.sort_values('price', ascending=True)  # Sort ascending first
# liquidatable_price_abs_df = liquidatable_price_abs_df.reset_index(drop=True)  # Reset index after sorting

# # Calculate differences from bottom up
# liquidatable_price_abs_df['liquidatable_collateral_abs'] = liquidatable_price_abs_df['liquidatable_collateral'].diff(-1)
# # Fill the last row with its liquidatable_collateral value since it's the base value
# liquidatable_price_abs_df.loc[liquidatable_price_abs_df.index[-1], 'liquidatable_collateral_abs'] = liquidatable_price_abs_df.loc[liquidatable_price_abs_df.index[-1], 'liquidatable_collateral']

# # Sort back to descending order for the rest of the processing
# liquidatable_price_abs_df = liquidatable_price_abs_df.sort_values('price', ascending=False)
# liquidatable_price_abs_df = liquidatable_price_abs_df.reset_index(drop=True)

# # Create new dataframes with renamed columns for clarity
# df1 = output_liq_df[['max_price', 'max_collateral_value']].rename(
#     columns={'max_price': 'price', 'max_collateral_value': 'liquidatable_collateral_abs'})
# df2 = liquidatable_price_abs_df[['price', 'liquidatable_collateral_abs']]

# # Concatenate the dataframes
# combined_df = pd.concat([df1, df2], ignore_index=True)

# # Sort by price in descending order
# combined_df = combined_df.sort_values('price', ascending=False)

# # Create cumulative sum column
# combined_df['cumulative_liquidatable_collateral'] = combined_df['liquidatable_collateral_abs'].cumsum()

# # Reset index after sorting
# combined_df = combined_df.reset_index(drop=True)

# %%
# # plot scale and liquidatable_collateral
# plt.figure(figsize=(16, 8))
# plt.plot(combined_df['price'], combined_df['cumulative_liquidatable_collateral'], label='Liquidatable Collateral')
# plt.xlabel('Price')
# plt.ylabel('Liquidatable Collateral')
# plt.title('Liquidatable Collateral vs Scale')
# plt.legend()
# plt.grid(True, linestyle=':', alpha=0.7)
# plt.show()

# %%
# # Calculate first and second derivatives
# first_derivative = np.gradient(combined_df['cumulative_liquidatable_collateral'], combined_df['price'])
# second_derivative = np.gradient(first_derivative, combined_df['price'])

# # Create subplots
# fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(16, 24))

# # Plot original function
# ax1.plot(combined_df['price'], combined_df['cumulative_liquidatable_collateral'], 'b-', label='Liquidatable Collateral')
# ax1.set_xlabel('Price')
# ax1.set_ylabel('Liquidatable Collateral')
# ax1.set_title('Original Function')
# ax1.grid(True, linestyle=':', alpha=0.7)
# ax1.legend()

# # Plot first derivative
# ax2.plot(combined_df['price'], first_derivative, 'r-', label='First Derivative')
# ax2.set_xlabel('Price')
# ax2.set_ylabel('Rate of Change')
# ax2.set_title('First Derivative')
# ax2.grid(True, linestyle=':', alpha=0.7)
# ax2.legend()

# # Plot second derivative
# ax3.plot(combined_df['price'], second_derivative, 'g-', label='Second Derivative')
# ax3.set_xlabel('Price')
# ax3.set_ylabel('Rate of Change of Rate of Change')
# ax3.set_title('Second Derivative')
# ax3.grid(True, linestyle=':', alpha=0.7)
# ax3.legend()

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ---

# %%
# Find value from aave_asset_object_dict where the key is the same as ASSET_UNDER_CONSIDERATION
asset_object = next((value for key, value in aave_asset_object_dict.items() if key == ASSET_UNDER_CONSIDERATION), None)

# %%
PRICE_ASSUMPTION = PRICE_DROP_FACTOR*asset_object.price

# %%
PRICE_ASSUMPTION
# Out:
# 3122.2406325077604

# %%
def get_curve_liquidation_data(output_liq_df: pd.DataFrame, price_assumption: float) -> tuple[float, float]:
    """
    Get curve liquidation data for the closest price point >= price_assumption.
    Returns (collateral, debt) tuple or (None, None) if no suitable price found.
    """
    # Check if there are any prices >= price_assumption
    valid_rows = output_liq_df[output_liq_df['max_price'] <= price_assumption]
    
    if valid_rows.empty:
        return None, None
    
    # Get the closest row
    closest_row = valid_rows.sort_values('max_price').iloc[-1]
    return {ASSET_UNDER_CONSIDERATION_CURVE:float(closest_row['max_collateral_value'])}, {'crvUSD':float(closest_row['debt'])}

# %%
# Create a copy and sort by max_price in descending order
plot_df = output_liq_df.copy()
plot_df = plot_df.sort_values('max_price', ascending=False)

# Add cumulative sum column
plot_df['cum_collateral'] = plot_df['max_collateral_value'].cumsum()

plot_df['cum_debt'] = plot_df['debt'].cumsum()

# Create the plot
plt.figure(figsize=(12, 8))
plt.plot(plot_df['max_price'], plot_df['cum_collateral'], 
         label='Cumulative Collateral', 
         color='blue',
         linewidth=2)

plt.xlabel('Price')
plt.ylabel('Cumulative Collateral')
plt.title('Cumulative Liquidatable Collateral vs Price')
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
curve_collateral, curve_debt = get_curve_liquidation_data(output_liq_df, PRICE_ASSUMPTION)

# %%
print("Curve Liquidatable Collateral:")
print(json.dumps(curve_collateral, indent=4))
print("\nCurve Liquidatable Debt:")
print(json.dumps(curve_debt, indent=4))
# Out:
# Curve Liquidatable Collateral:
# {
#     "wstETH": 0.015368727905653934
# }
#
# Curve Liquidatable Debt:
# {
#     "crvUSD": 41.34550000643669
# }

# %%
def analyze_liquidatable_positions(
    aave_supported_asset_data: pd.DataFrame,
    aave_user_position_data: pd.DataFrame,
    asset_under_consideration: str,
    price_assumption: float,
    emode_lt: float,
    min_usd_threshold: float = 5000
) -> dict:
    """
    Analyzes liquidatable positions for given asset and price assumption.
    Returns both raw and USD values for liquidatable collateral and debt.
    """
    # Create price mapping
    new_price_mapping = {asset_under_consideration: price_assumption}
    price_mapping = dict(zip(aave_supported_asset_data['symbol'], aave_supported_asset_data['price']))
    
    # Create asset mapping and get health ratios
    asset_mapping = create_asset_mapping(aave_supported_asset_data, new_price_mapping)
    
    # Get health ratio data for both normal and emode
    health_ratio_data_no_emode = create_health_ratio_data(aave_user_position_data, asset_mapping)
    health_ratio_data_emode = create_health_ratio_data_emode(aave_user_position_data, asset_mapping, emode_lt)
    health_ratio_data = pd.concat([health_ratio_data_no_emode, health_ratio_data_emode])
    
    # Get liquidatable positions
    total_liquidatable_collateral, total_liquidatable_debt = create_liquidatable_user_data(health_ratio_data)
    
    # Filter non-zero positions
    total_liquidatable_collateral = {k: v for k, v in total_liquidatable_collateral.items() if v > 0}
    total_liquidatable_debt = {k: v for k, v in total_liquidatable_debt.items() if v > 0}
    
    # Convert to USD
    total_liquidatable_collateral_usd = {
        symbol: quantity * price_mapping.get(symbol, 1)
        for symbol, quantity in total_liquidatable_collateral.items()
    }
    
    total_liquidatable_debt_usd = {
        symbol: quantity * price_mapping.get(symbol, 1)
        for symbol, quantity in total_liquidatable_debt.items()
    }
    
    # Filter by USD threshold
    filtered_collateral_usd = {k: v for k, v in total_liquidatable_collateral_usd.items() if v > min_usd_threshold}
    filtered_debt_usd = {k: v for k, v in total_liquidatable_debt_usd.items() if v > min_usd_threshold}
    
    # Reconstruct raw values from filtered USD values
    filtered_collateral = {
        symbol: float(usd_value) / price_mapping.get(symbol, 1)
        for symbol, usd_value in filtered_collateral_usd.items()
    }
    
    filtered_debt = {
        symbol: float(usd_value) / price_mapping.get(symbol, 1)
        for symbol, usd_value in filtered_debt_usd.items()
    }
    
    return filtered_collateral, filtered_debt

# %%
aave_collateral, aave_debt = analyze_liquidatable_positions(
    aave_supported_asset_data,
    aave_user_position_data,
    ASSET_UNDER_CONSIDERATION,
    PRICE_ASSUMPTION,
    AAVE_EMODE_LT
)

aave_collateral
# Out:
# {'wstETH': 110.10172051475205, 'weETH': 1892.5807069249815}

# %%
print("Aave Liquidatable Collateral:")
print(json.dumps(aave_collateral, indent=4))
print("\nAave Liquidatable Debt:")
print(json.dumps(aave_debt, indent=4))
# Out:
# Aave Liquidatable Collateral:
# {
#     "wstETH": 110.10172051475205,
#     "weETH": 1892.5807069249815
# }
#
# Aave Liquidatable Debt:
# {
#     "WETH": 1280.8183894330864,
#     "WBTC": 0.71294871,
#     "RPL": 2269.469508227577,
#     "cbBTC": 5.00026428,
#     "USDS": 50172.53931724315
# }

# %%
def merge_liquidation_data(aave_data: dict, curve_data: dict) -> dict:
    """
    Merge liquidation data from Aave and Curve protocols.
    """
    merged_data = aave_data.copy()  # Start with Aave data
    
    # Merge Curve data
    for token, amount in curve_data.items():
        if token in merged_data:
            merged_data[token] += amount
        else:
            merged_data[token] = amount
    
    return merged_data

# %%
# Merge collateral data
total_collateral = merge_liquidation_data(aave_collateral, curve_collateral)

# Merge debt data
total_debt = merge_liquidation_data(aave_debt, curve_debt)

print("Total Liquidatable Collateral:")
print(json.dumps(total_collateral, indent=4))
print("\nTotal Liquidatable Debt:")
print(json.dumps(total_debt, indent=4))
# Out:
# Total Liquidatable Collateral:
# {
#     "wstETH": 110.1170892426577,
#     "weETH": 1892.5807069249815
# }
#
# Total Liquidatable Debt:
# {
#     "WETH": 1280.8183894330864,
#     "WBTC": 0.71294871,
#     "RPL": 2269.469508227577,
#     "cbBTC": 5.00026428,
#     "USDS": 50172.53931724315,
#     "crvUSD": 41.34550000643669
# }

# %%
# Try to load existing trade_pair_hashmap or create new one
try:
    if os.path.exists('trade_pair_hashmap.pkl'):
        with open('trade_pair_hashmap.pkl', 'rb') as f:
            trade_pair_hashmap = pickle.load(f)
        print(f"Loaded existing trade_pair_hashmap with {len(trade_pair_hashmap)} pairs")
    else:
        trade_pair_hashmap = {}
        print("Created new empty trade_pair_hashmap")
except Exception as e:
    print(f"Error loading trade_pair_hashmap: {str(e)}")
    trade_pair_hashmap = {}
    print("Created new empty trade_pair_hashmap due to error")
# Out:
# Loaded existing trade_pair_hashmap with 111 pairs

# %%
# FLASHLOAN_ASSET_SYMBOLS = ['WETH']
FLASHLOAN_ASSET_SYMBOLS = ['USDC', 'USDT', 'DAI', 'WETH']

# Create sets for easier lookup
flashloan_assets = set(FLASHLOAN_ASSET_SYMBOLS)
liquidatable_debt_assets = set(total_debt.keys())
liquidatable_collateral_assets = set(total_collateral.keys())

# Function to create and store PairDTO if it doesn't exist
def create_and_store_pair(sell_token, buy_token, trade_pair_hashmap):
    if sell_token != buy_token:
        key = f"{sell_token}-{buy_token}"
        if key not in trade_pair_hashmap:
            
            print(f"Creating pair: {sell_token} -> {buy_token}")
            
            pair_dto = PairDTO(
                sell_token=aave_asset_object_dict[sell_token],
                buy_token=aave_asset_object_dict[buy_token],
                network=ETHEREUM_DTO
            )
            trade_pair_hashmap[key] = pair_dto
            return 1
    return 0

# Set 1: Flashloan assets as sell, liquidatable debt as buy
new_pairs_count = 0
total_pairs_set1 = len(flashloan_assets) * len(liquidatable_debt_assets)
for sell_token, buy_token in tqdm(product(flashloan_assets, liquidatable_debt_assets), 
                                  total=total_pairs_set1, 
                                  desc="Creating Set 1 PairDTO objects"):
    new_pairs_count += create_and_store_pair(sell_token, buy_token, trade_pair_hashmap)

# Set 2: Liquidatable collateral as sell, flashloan assets as buy
total_pairs_set2 = len(liquidatable_collateral_assets) * len(flashloan_assets)
for sell_token, buy_token in tqdm(product(liquidatable_collateral_assets, flashloan_assets), 
                                  total=total_pairs_set2, 
                                  desc="Creating Set 2 PairDTO objects"):
    new_pairs_count += create_and_store_pair(sell_token, buy_token, trade_pair_hashmap)

print(f"Total pairs in trade_pair_hashmap: {len(trade_pair_hashmap)}")
print(f"New pairs added: {new_pairs_count}")

# Save updated trade_pair_hashmap to a pickle file
import pickle
with open('trade_pair_hashmap.pkl', 'wb') as f:
    pickle.dump(trade_pair_hashmap, f)
# Out:
# Creating Set 1 PairDTO objects: 100%|██████████| 24/24 [00:00<?, ?it/s]
# Creating Set 2 PairDTO objects: 100%|██████████| 8/8 [00:00<?, ?it/s]
# Total pairs in trade_pair_hashmap: 111
# New pairs added: 0

# %%
# Creata a copy of updated_trade_pair_hashmap
updated_trade_pair_hashmap_copy = trade_pair_hashmap.copy()


pair = updated_trade_pair_hashmap_copy["WBTC-USDT"]


def derived_func(x, r, k, c):
    """
    Calculate the value of y based on the given formula.

    Parameters:
        x (float): The value of x in the formula.
        r (float): The value of r in the formula.
        k (float): The value of k in the formula.
        c (float): The value of c in the formula.

    Returns:
        float: The calculated value of y.
    """
    exponent = k * (x ** -c)
    y = (x * r) * (1 - (1/np.exp(exponent)))
    return y

r = pair.exchange_price
k = pair.k
c = pair.c

pair_quotes_df = pair.quotes_df

# Create a new figure with a larger size
plt.figure(figsize=(16, 9))

# Plot scatter points for each dex_aggregator
aggregators = pair_quotes_df['dex_aggregator'].unique()
colors = plt.cm.rainbow(np.linspace(0, 1, len(aggregators)))

sell_token_decimals = pair.sell_token.decimals
buy_token_decimals = pair.buy_token.decimals

for aggregator, color in zip(aggregators, colors):
    df_agg = pair_quotes_df[pair_quotes_df['dex_aggregator'] == aggregator]
    if not df_agg.empty:
        adjusted_sell_amount = df_agg['sell_token_amount'] / (10 ** sell_token_decimals)
        adjusted_buy_amount = df_agg['buy_token_amount'] / (10 ** buy_token_decimals)
        plt.scatter(adjusted_sell_amount, 
                    adjusted_buy_amount, 
                    label=aggregator, color=color, alpha=0.7)
    else:
        print(f"No data for aggregator: {aggregator}")

# Plot the derived function
if not pair_quotes_df.empty:
    x_min = pair_quotes_df['sell_token_amount'].min() / (10 ** sell_token_decimals)
    x_max = pair_quotes_df['sell_token_amount'].max() / (10 ** sell_token_decimals)
    x_range = np.linspace(x_min, x_max, 1000)
    y_derived = derived_func(x_range, r, k, c)
    plt.plot(x_range, y_derived, 'k-', label='Derived Function', linewidth=2)

plt.xlabel(f'Sell Token Amount ({pair.sell_token.symbol})')
plt.ylabel(f'Buy Token Amount ({pair.buy_token.symbol})')
plt.title(f'Sell Token vs Buy Token: {pair.sell_token.symbol} -> {pair.buy_token.symbol}')
plt.legend()
plt.grid(True, alpha=0.3)
# plt.xscale('log')
# plt.yscale('log')
plt.show()

# Print the function parameters
print(f"\nFunction parameters:")
print(f"Exchange Price (r): {r:.6f}")
print(f"k: {k:.6f}")
print(f"c: {c:.6f}")
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_69492\3834038245.py:22: RuntimeWarning: overflow encountered in exp
#   y = (x * r) * (1 - (1/np.exp(exponent)))
# Function parameters:
# Exchange Price (r): 97028.000000
# k: 18238.618139
# c: 1.238565

# %%
def plot_trading_pair_analysis(pair_symbol, trade_pair_hashmap):
    """
    Create a scatter plot of trading data with derived function for a specific trading pair.
    
    Parameters:
        pair_symbol (str): Trading pair symbol (e.g., "WBTC-USDT")
        trade_pair_hashmap (dict): Dictionary containing trading pair data
    
    Returns:
        None (displays plot)
    """
    # Get the trading pair data
    pair = trade_pair_hashmap[pair_symbol]
    
    def derived_func(x, r, k, c):
        """Calculate the value of y based on the given formula."""
        exponent = k * (x ** -c)
        y = (x * r) * (1 - (1/np.exp(exponent)))
        return y

    r = pair.exchange_price
    k = pair.k
    c = pair.c
    pair_quotes_df = pair.quotes_df

    # Create plot
    plt.figure(figsize=(16, 9))

    # Plot scatter points for each dex_aggregator
    aggregators = pair_quotes_df['dex_aggregator'].unique()
    colors = plt.cm.rainbow(np.linspace(0, 1, len(aggregators)))

    sell_token_decimals = pair.sell_token.decimals
    buy_token_decimals = pair.buy_token.decimals

    # Plot data points for each aggregator
    for aggregator, color in zip(aggregators, colors):
        df_agg = pair_quotes_df[pair_quotes_df['dex_aggregator'] == aggregator]
        if not df_agg.empty:
            adjusted_sell_amount = df_agg['sell_token_amount'] / (10 ** sell_token_decimals)
            adjusted_buy_amount = df_agg['buy_token_amount'] / (10 ** buy_token_decimals)
            plt.scatter(adjusted_sell_amount, 
                       adjusted_buy_amount, 
                       label=aggregator, color=color, alpha=0.7)
        else:
            print(f"No data for aggregator: {aggregator}")

    # Plot derived function
    if not pair_quotes_df.empty:
        x_min = pair_quotes_df['sell_token_amount'].min() / (10 ** sell_token_decimals)
        x_max = pair_quotes_df['sell_token_amount'].max() / (10 ** sell_token_decimals)
        x_range = np.linspace(x_min, x_max, 1000)
        y_derived = derived_func(x_range, r, k, c)
        plt.plot(x_range, y_derived, 'k-', label='Derived Function', linewidth=2)

    # Set labels and title
    plt.xlabel(f'Sell Token Amount ({pair.sell_token.symbol})')
    plt.ylabel(f'Buy Token Amount ({pair.buy_token.symbol})')
    plt.title(f'Sell Token vs Buy Token: {pair.sell_token.symbol} -> {pair.buy_token.symbol}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    # Print function parameters
    print(f"\nFunction parameters:")
    print(f"Exchange Price (r): {r:.6f}")
    print(f"k: {k:.6f}")
    print(f"c: {c:.6f}")

# %%
plot_trading_pair_analysis("weETH-USDT", trade_pair_hashmap)
# Out:
# Function parameters:
# Exchange Price (r): 3902.800791
# k: 519206.108219
# c: 1.315034

# %%
plot_trading_pair_analysis("weETH-WETH", trade_pair_hashmap)
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_69492\1409966717.py:18: RuntimeWarning: overflow encountered in exp
#   y = (x * r) * (1 - (1/np.exp(exponent)))
# Function parameters:
# Exchange Price (r): 1.050385
# k: 36183319485219.570312
# c: 3.175488

# %%
# Create price mapping
new_price_mapping = {ASSET_UNDER_CONSIDERATION: PRICE_ASSUMPTION}
price_mapping = dict(zip(aave_supported_asset_data['symbol'], aave_supported_asset_data['price']))

# Create asset mapping and get health ratios
asset_mapping = create_asset_mapping(aave_supported_asset_data, new_price_mapping)

# %%
asset_mapping
# Out:
# {'WETH': {'price': 3715.59, 'liquidationThreshold': 0.83},
#  'wstETH': {'price': 4402.51, 'liquidationThreshold': 0.81},
#  'WBTC': {'price': 97028.0, 'liquidationThreshold': 0.78},
#  'USDC': {'price': 0.999451, 'liquidationThreshold': 0.78},
#  'DAI': {'price': 1.0, 'liquidationThreshold': 0.77},
#  'LINK': {'price': 22.48, 'liquidationThreshold': 0.71},
#  'AAVE': {'price': 256.34, 'liquidationThreshold': 0.73},
#  'cbETH': {'price': 4026.01, 'liquidationThreshold': 0.79},
#  'USDT': {'price': 1.0, 'liquidationThreshold': 0.78},
#  'rETH': {'price': 4164.8, 'liquidationThreshold': 0.79},
#  'LUSD': {'price': 0.998643, 'liquidationThreshold': 0.77},
#  'CRV': {'price': 1.062, 'liquidationThreshold': 0.41},
#  'MKR': {'price': 1881.12, 'liquidationThreshold': 0.7},
#  'SNX': {'price': 2.77, 'liquidationThreshold': 0.65},
#  'BAL': {'price': 3.24, 'liquidationThreshold': 0.59},
#  'UNI': {'price': 15.73, 'liquidationThreshold': 0.74},
#  'LDO': {'price': 1.82, 'liquidationThreshold': 0.5},
#  'ENS': {'price': 33.56461523924799, 'liquidationThreshold': 0.49},
#  '1INCH': {'price': 0.5428575874874582, 'liquidationThreshold': 0.67},
#  'FRAX': {'price': 0.997974, 'liquidationThreshold': 0.72},
#  'GHO': {'price': 0.996103, 'liquidationThreshold': 0.0},
#  'RPL': {'price': 13.79, 'liquidationThreshold': 0.0},
#  'sDAI': {'price': 1.123656307486038, 'liquidationThreshold': 0.78},
#  'STG': {'price': 0.352966, 'liquidationThreshold': 0.37},
#  'KNC': {'price': 0.674338, 'liquidationThreshold': 0.37},
#  'FXS': {'price': 3.62, 'liquidationThreshold': 0.42},
#  'crvUSD': {'price': 0.999966, 'liquidationThreshold': 0.0},
#  'PYUSD': {'price': 1.002, 'liquidationThreshold': 0.78},
#  'weETH': {'price': 3122.2406325077604, 'liquidationThreshold': 0.75},
#  'osETH': {'price': 3838.8633311288622, 'liquidationThreshold': 0.75},
#  'USDe': {'price': 1.001, 'liquidationThreshold': 0.75},
#  'ETHx': {'price': 3872.24, 'liquidationThreshold': 0.77},
#  'sUSDe': {'price': 1.1329020379301624, 'liquidationThreshold': 0.75},
#  'tBTC': {'price': 97148.0, 'liquidationThreshold': 0.78},
#  'cbBTC': {'price': 97440.0, 'liquidationThreshold': 0.78},
#  'USDS': {'price': 1.0, 'liquidationThreshold': 0.78},
#  'rsETH': {'price': 3833.35, 'liquidationThreshold': 0.75}}

# %%
def construct_new_price_mapping(asset_mapping, 
                                new_price_mapping,
                                total_liquidatable_collateral,
                                total_liquidatable_debt):
    
    output_mapping = {}
    
    # Extract keys from total_liquidatable_collateral and total_liquidatable_debt and add to separate sets
    liquidatable_collateral_assets = set(total_liquidatable_collateral.keys())
    liquidatable_debt_assets = set(total_liquidatable_debt.keys())
    
    # Join liquidatable_collateral_assets and liquidatable_debt_assets and remove duplicates
    liquidatable_assets = liquidatable_collateral_assets.union(liquidatable_debt_assets)    
    
    for asset in liquidatable_assets:
        if asset in new_price_mapping:
            price = new_price_mapping[asset]
            
            output_mapping[asset] = price
        else:
            price = asset_mapping[asset]['price']
            output_mapping[asset] = price
    
    for asset in FLASHLOAN_ASSET_SYMBOLS:
        price = asset_mapping[asset]['price']
        output_mapping[asset] = price
            
    return output_mapping

# %%
new_broad_price_mapping = construct_new_price_mapping(asset_mapping, new_price_mapping, total_collateral, total_debt)

# %%
updated_trade_pair_hashmap = update_trade_pair_exchange_price(trade_pair_hashmap, new_broad_price_mapping)
# Out:
# Warning: Price not found for USDT or PYUSD. Skipping update for pair USDT-PYUSD.
# Warning: Price not found for USDT or UNI. Skipping update for pair USDT-UNI.
# Warning: Price not found for DAI or PYUSD. Skipping update for pair DAI-PYUSD.
# Warning: Price not found for DAI or UNI. Skipping update for pair DAI-UNI.
# Warning: Price not found for USDC or PYUSD. Skipping update for pair USDC-PYUSD.
# Warning: Price not found for USDC or UNI. Skipping update for pair USDC-UNI.
# Warning: Price not found for WETH or PYUSD. Skipping update for pair WETH-PYUSD.
# Warning: Price not found for WETH or UNI. Skipping update for pair WETH-UNI.
# Warning: Price not found for sfrxETH or USDC. Skipping update for pair sfrxETH-USDC.
# Warning: Price not found for sfrxETH or DAI. Skipping update for pair sfrxETH-DAI.
# Warning: Price not found for sfrxETH or WETH. Skipping update for pair sfrxETH-WETH.
# Warning: Price not found for DAI or GHO. Skipping update for pair DAI-GHO.
# Warning: Price not found for DAI or ENS. Skipping update for pair DAI-ENS.
# Warning: Price not found for DAI or rETH. Skipping update for pair DAI-rETH.
# Warning: Price not found for USDT or GHO. Skipping update for pair USDT-GHO.
# Warning: Price not found for USDT or ENS. Skipping update for pair USDT-ENS.
# Warning: Price not found for USDT or rETH. Skipping update for pair USDT-rETH.
# Warning: Price not found for WETH or GHO. Skipping update for pair WETH-GHO.
# Warning: Price not found for WETH or ENS. Skipping update for pair WETH-ENS.
# Warning: Price not found for WETH or rETH. Skipping update for pair WETH-rETH.
# Warning: Price not found for USDC or GHO. Skipping update for pair USDC-GHO.
# Warning: Price not found for USDC or ENS. Skipping update for pair USDC-ENS.
# Warning: Price not found for USDC or rETH. Skipping update for pair USDC-rETH.
# Warning: Price not found for LINK or DAI. Skipping update for pair LINK-DAI.
# Warning: Price not found for LINK or USDT. Skipping update for pair LINK-USDT.
# Warning: Price not found for LINK or WETH. Skipping update for pair LINK-WETH.
# Warning: Price not found for LINK or USDC. Skipping update for pair LINK-USDC.
# Warning: Price not found for rETH or DAI. Skipping update for pair rETH-DAI.
# Warning: Price not found for rETH or USDT. Skipping update for pair rETH-USDT.
# Warning: Price not found for rETH or WETH. Skipping update for pair rETH-WETH.
# Warning: Price not found for rETH or USDC. Skipping update for pair rETH-USDC.
# Warning: Price not found for AAVE or DAI. Skipping update for pair AAVE-DAI.
# Warning: Price not found for AAVE or USDT. Skipping update for pair AAVE-USDT.
# Warning: Price not found for AAVE or WETH. Skipping update for pair AAVE-WETH.
# Warning: Price not found for AAVE or USDC. Skipping update for pair AAVE-USDC.
# Warning: Price not found for tBTC or USDT. Skipping update for pair tBTC-USDT.
# Warning: Price not found for tBTC or DAI. Skipping update for pair tBTC-DAI.
# Warning: Price not found for tBTC or USDC. Skipping update for pair tBTC-USDC.
# Warning: Price not found for tBTC or WETH. Skipping update for pair tBTC-WETH.
# Warning: Price not found for USDC or CRV. Skipping update for pair USDC-CRV.
# Warning: Price not found for DAI or CRV. Skipping update for pair DAI-CRV.
# Warning: Price not found for WETH or CRV. Skipping update for pair WETH-CRV.
# Warning: Price not found for USDT or CRV. Skipping update for pair USDT-CRV.
# Warning: Price not found for cbETH or USDC. Skipping update for pair cbETH-USDC.
# Warning: Price not found for cbETH or DAI. Skipping update for pair cbETH-DAI.
# Warning: Price not found for cbETH or WETH. Skipping update for pair cbETH-WETH.
# Warning: Price not found for cbETH or USDT. Skipping update for pair cbETH-USDT.
# Warning: Price not found for stETH or USDC. Skipping update for pair stETH-USDC.
# Warning: Price not found for stETH or DAI. Skipping update for pair stETH-DAI.
# Warning: Price not found for stETH or WETH. Skipping update for pair stETH-WETH.
# Warning: Price not found for stETH or USDT. Skipping update for pair stETH-USDT.
# Warning: Price not found for frxETH or USDC. Skipping update for pair frxETH-USDC.
# Warning: Price not found for frxETH or DAI. Skipping update for pair frxETH-DAI.
# Warning: Price not found for frxETH or USDT. Skipping update for pair frxETH-USDT.
# Warning: Price not found for frxETH or WETH. Skipping update for pair frxETH-WETH.

# %%
liquidation_profits_df = scale_supply_and_create_liquidations(updated_trade_pair_hashmap, 
                                                              asset_mapping, 
                                                              total_collateral, 
                                                              total_debt,
                                                              0.02, 
                                                              10,
                                                              50)
# Out:
# {
#     "wstETH": 2.202341784853154,
#     "weETH": 37.851614138499635
# }
# {
#     "WETH": 25.61636778866173,
#     "WBTC": 0.014258974200000002,
#     "RPL": 45.38939016455154,
#     "cbBTC": 0.1000052856,
#     "USDS": 1003.450786344863,
#     "crvUSD": 0.8269100001287337
# }
# {
#     "wstETH": 2.202341784853154,
#     "weETH": 37.851614138499635
# }
# {
#     "WETH": 25.61636778866173,
#     "WBTC": 0.014258974200000002,
#     "RPL": 45.38939016455154,
#     "cbBTC": 0.1000052856,
#     "USDS": 1003.450786344863,
#     "crvUSD": 0.8269100001287337
# }
# {
#     "wstETH": 2.202341784853154,
#     "weETH": 37.851614138499635
# }
# {
#     "WETH": 25.61636778866173,
#     "WBTC": 0.014258974200000002,
#     "RPL": 45.38939016455154,
#     "cbBTC": 0.1000052856,
#     "USDS": 1003.450786344863,
#     "crvUSD": 0.8269100001287337
# }
# {
#     "wstETH": 2.202341784853154,
#     "weETH": 37.851614138499635
# }
# {
#     "WETH": 25.61636778866173,
#     "WBTC": 0.014258974200000002,
#     "RPL": 45.38939016455154,
#     "cbBTC": 0.1000052856,
#     "USDS": 1003.450786344863,
#     "crvUSD": 0.8269100001287337
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 96862.46796349964,
#         "flashloan_start_usd": 96809.29046858769,
#         "flashloan_end": 118246.76514329245,
#         "flashloan_end_usd": 118181.84766922878,
#         "flashloan_profit": 21372.5572006411,
#         "flashloan_profit_usd": 21360.823666737946
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 96809.29046858769,
#         "flashloan_start_usd": 96809.29046858769,
#         "flashloan_end": 118181.84766922878,
#         "flashloan_end_usd": 118181.84766922878,
#         "flashloan_profit": 21372.557200641095,
#         "flashloan_profit_usd": 21372.557200641095
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 96809.29046858769,
#         "flashloan_start_usd": 96809.29046858769,
#         "flashloan_end": 118181.84766922878,
#         "flashloan_end_usd": 118181.84766922878,
#         "flashloan_profit": 21372.557200641095,
#         "flashloan_profit_usd": 21372.557200641095
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 29.05007068272184,
#         "flashloan_start_usd": 107938.15212801445,
#         "flashloan_end": 34.41652049888783,
#         "flashloan_end_usd": 127877.67940046263,
#         "flashloan_profit": 19939.527272448177,
#         "flashloan_profit_usd": 74087108.13823572
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 24.63027138978629,
#     "weETH": 423.32009281424075
# }
# {
#     "WETH": 286.4850928201352,
#     "WBTC": 0.1594677114612245,
#     "RPL": 507.6201185749846,
#     "cbBTC": 1.1184264593632651,
#     "USDS": 11222.265937081325,
#     "crvUSD": 9.247891430011144
# }
# {
#     "wstETH": 24.63027138978629,
#     "weETH": 423.32009281424075
# }
# {
#     "WETH": 286.4850928201352,
#     "WBTC": 0.1594677114612245,
#     "RPL": 507.6201185749846,
#     "cbBTC": 1.1184264593632651,
#     "USDS": 11222.265937081325,
#     "crvUSD": 9.247891430011144
# }
# {
#     "wstETH": 24.63027138978629,
#     "weETH": 423.32009281424075
# }
# {
#     "WETH": 286.4850928201352,
#     "WBTC": 0.1594677114612245,
#     "RPL": 507.6201185749846,
#     "cbBTC": 1.1184264593632651,
#     "USDS": 11222.265937081325,
#     "crvUSD": 9.247891430011144
# }
# {
#     "wstETH": 24.63027138978629,
#     "weETH": 423.32009281424075
# }
# {
#     "WETH": 286.4850928201352,
#     "WBTC": 0.1594677114612245,
#     "RPL": 507.6201185749846,
#     "cbBTC": 1.1184264593632651,
#     "USDS": 11222.265937081325,
#     "crvUSD": 9.247891430011144
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 1083278.2131509061,
#         "flashloan_start_usd": 1082683.4934118863,
#         "flashloan_end": 1430927.7897944239,
#         "flashloan_end_usd": 1430142.2104378266,
#         "flashloan_profit": 347458.7170259404,
#         "flashloan_profit_usd": 347267.9621902932
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1082683.4934138474,
#         "flashloan_start_usd": 1082683.4934138474,
#         "flashloan_end": 1430142.210437827,
#         "flashloan_end_usd": 1430142.210437827,
#         "flashloan_profit": 347458.71702397964,
#         "flashloan_profit_usd": 347458.71702397964
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1082683.4937186204,
#         "flashloan_start_usd": 1082683.4937186204,
#         "flashloan_end": 1429921.719702766,
#         "flashloan_end_usd": 1429921.719702766,
#         "flashloan_profit": 347238.22598414565,
#         "flashloan_profit_usd": 347238.22598414565
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 324.8865047849835,
#         "flashloan_start_usd": 1207145.048314037,
#         "flashloan_end": 384.9031272120516,
#         "flashloan_end_usd": 1430142.2104378268,
#         "flashloan_profit": 222997.1621237898,
#         "flashloan_profit_usd": 828566025.6155322
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 47.058200994719435,
#     "weETH": 808.7885714899819
# }
# {
#     "WETH": 547.3538178516088,
#     "WBTC": 0.30467644872244903,
#     "RPL": 969.8508469854177,
#     "cbBTC": 2.1368476331265307,
#     "USDS": 21441.081087817787,
#     "crvUSD": 17.668872859893558
# }
# {
#     "wstETH": 47.058200994719435,
#     "weETH": 808.7885714899819
# }
# {
#     "WETH": 547.3538178516088,
#     "WBTC": 0.30467644872244903,
#     "RPL": 969.8508469854177,
#     "cbBTC": 2.1368476331265307,
#     "USDS": 21441.081087817787,
#     "crvUSD": 17.668872859893558
# }
# {
#     "wstETH": 47.058200994719435,
#     "weETH": 808.7885714899819
# }
# {
#     "WETH": 547.3538178516088,
#     "WBTC": 0.30467644872244903,
#     "RPL": 969.8508469854177,
#     "cbBTC": 2.1368476331265307,
#     "USDS": 21441.081087817787,
#     "crvUSD": 17.668872859893558
# }
# {
#     "wstETH": 47.058200994719435,
#     "weETH": 808.7885714899819
# }
# {
#     "WETH": 547.3538178516088,
#     "WBTC": 0.30467644872244903,
#     "RPL": 969.8508469854177,
#     "cbBTC": 2.1368476331265307,
#     "USDS": 21441.081087817787,
#     "crvUSD": 17.668872859893558
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 2069711.665661075,
#         "flashloan_start_usd": 2068575.393956627,
#         "flashloan_end": 2733907.656778763,
#         "flashloan_end_usd": 2732406.7414751914,
#         "flashloan_profit": 663831.3475185646,
#         "flashloan_profit_usd": 663466.9041087768
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2068575.3979320957,
#         "flashloan_start_usd": 2068575.3979320957,
#         "flashloan_end": 2732406.7414751914,
#         "flashloan_end_usd": 2732406.7414751914,
#         "flashloan_profit": 663831.3435430957,
#         "flashloan_profit_usd": 663831.3435430957
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2068575.6508920963,
#         "flashloan_start_usd": 2068575.6508920963,
#         "flashloan_end": 2703325.5799334818,
#         "flashloan_end_usd": 2703325.5799334818,
#         "flashloan_profit": 634749.9290413854,
#         "flashloan_profit_usd": 634749.9290413854
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 620.7229401414876,
#         "flashloan_start_usd": 2306351.94916031,
#         "flashloan_end": 735.3897339252154,
#         "flashloan_end_usd": 2732406.7414751914,
#         "flashloan_profit": 426054.7923148813,
#         "flashloan_profit_usd": 1583044925.7772498
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 69.48613059965257,
#     "weETH": 1194.257050165723
# }
# {
#     "WETH": 808.2225428830823,
#     "WBTC": 0.4498851859836735,
#     "RPL": 1432.0815753958507,
#     "cbBTC": 3.155268806889796,
#     "USDS": 31659.89623855425,
#     "crvUSD": 26.089854289775968
# }
# {
#     "wstETH": 69.48613059965257,
#     "weETH": 1194.257050165723
# }
# {
#     "WETH": 808.2225428830823,
#     "WBTC": 0.4498851859836735,
#     "RPL": 1432.0815753958507,
#     "cbBTC": 3.155268806889796,
#     "USDS": 31659.89623855425,
#     "crvUSD": 26.089854289775968
# }
# {
#     "wstETH": 69.48613059965257,
#     "weETH": 1194.257050165723
# }
# {
#     "WETH": 808.2225428830823,
#     "WBTC": 0.4498851859836735,
#     "RPL": 1432.0815753958507,
#     "cbBTC": 3.155268806889796,
#     "USDS": 31659.89623855425,
#     "crvUSD": 26.089854289775968
# }
# {
#     "wstETH": 69.48613059965257,
#     "weETH": 1194.257050165723
# }
# {
#     "WETH": 808.2225428830823,
#     "WBTC": 0.4498851859836735,
#     "RPL": 1432.0815753958507,
#     "cbBTC": 3.155268806889796,
#     "USDS": 31659.89623855425,
#     "crvUSD": 26.089854289775968
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 3056136.802828147,
#         "flashloan_start_usd": 3054458.9837233946,
#         "flashloan_end": 4036887.5237631015,
#         "flashloan_end_usd": 4034671.2725125556,
#         "flashloan_profit": 980212.2887891611,
#         "flashloan_profit_usd": 979674.1522426158
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3054459.079389307,
#         "flashloan_start_usd": 3054459.079389307,
#         "flashloan_end": 4034671.2725125556,
#         "flashloan_end_usd": 4034671.2725125556,
#         "flashloan_profit": 980212.1931232484,
#         "flashloan_profit_usd": 980212.1931232484
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3054463.5069984295,
#         "flashloan_start_usd": 3054463.5069984295,
#         "flashloan_end": 3846693.763443308,
#         "flashloan_end_usd": 3846693.763443308,
#         "flashloan_profit": 792230.2564448784,
#         "flashloan_profit_usd": 792230.2564448784
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 916.559446640952,
#         "flashloan_start_usd": 3405559.114344655,
#         "flashloan_end": 1085.8763406383791,
#         "flashloan_end_usd": 4034671.272512555,
#         "flashloan_profit": 629112.1581679002,
#         "flashloan_profit_usd": 2337522843.7670684
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 91.91406020458571,
#     "weETH": 1579.7255288414642
# }
# {
#     "WETH": 1069.0912679145558,
#     "WBTC": 0.595093923244898,
#     "RPL": 1894.3123038062838,
#     "cbBTC": 4.173689980653061,
#     "USDS": 41878.711389290715,
#     "crvUSD": 34.51083571965838
# }
# {
#     "wstETH": 91.91406020458571,
#     "weETH": 1579.7255288414642
# }
# {
#     "WETH": 1069.0912679145558,
#     "WBTC": 0.595093923244898,
#     "RPL": 1894.3123038062838,
#     "cbBTC": 4.173689980653061,
#     "USDS": 41878.711389290715,
#     "crvUSD": 34.51083571965838
# }
# {
#     "wstETH": 91.91406020458571,
#     "weETH": 1579.7255288414642
# }
# {
#     "WETH": 1069.0912679145558,
#     "WBTC": 0.595093923244898,
#     "RPL": 1894.3123038062838,
#     "cbBTC": 4.173689980653061,
#     "USDS": 41878.711389290715,
#     "crvUSD": 34.51083571965838
# }
# {
#     "wstETH": 91.91406020458571,
#     "weETH": 1579.7255288414642
# }
# {
#     "WETH": 1069.0912679145558,
#     "WBTC": 0.595093923244898,
#     "RPL": 1894.3123038062838,
#     "cbBTC": 4.173689980653061,
#     "USDS": 41878.711389290715,
#     "crvUSD": 34.51083571965838
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 4042567.7497007665,
#         "flashloan_start_usd": 4040348.3800061806,
#         "flashloan_end": 5339867.390745665,
#         "flashloan_end_usd": 5336935.803548145,
#         "flashloan_profit": 1296587.4235419647,
#         "flashloan_profit_usd": 1295875.5970464402
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 4040348.9650474186,
#         "flashloan_start_usd": 4040348.9650474186,
#         "flashloan_end": 5336935.803549874,
#         "flashloan_end_usd": 5336935.803549874,
#         "flashloan_profit": 1296586.838502455,
#         "flashloan_profit_usd": 1296586.838502455
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 4040372.064060423,
#         "flashloan_start_usd": 4040372.064060423,
#         "flashloan_end": 4811525.886578649,
#         "flashloan_end_usd": 4811525.886578649,
#         "flashloan_profit": 771153.8225182262,
#         "flashloan_profit_usd": 771153.8225182262
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1212.3965633779774,
#         "flashloan_start_usd": 4504768.546921579,
#         "flashloan_end": 1436.362947351543,
#         "flashloan_end_usd": 5336935.80354992,
#         "flashloan_profit": 832167.2566283407,
#         "flashloan_profit_usd": 3091992337.0556965
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 114.34198980951885,
#     "weETH": 1965.1940075172054
# }
# {
#     "WETH": 1329.9599929460294,
#     "WBTC": 0.7403026605061225,
#     "RPL": 2356.5430322167167,
#     "cbBTC": 5.1921111544163265,
#     "USDS": 52097.526540027175,
#     "crvUSD": 42.93181714954079
# }
# {
#     "wstETH": 114.34198980951885,
#     "weETH": 1965.1940075172054
# }
# {
#     "WETH": 1329.9599929460294,
#     "WBTC": 0.7403026605061225,
#     "RPL": 2356.5430322167167,
#     "cbBTC": 5.1921111544163265,
#     "USDS": 52097.526540027175,
#     "crvUSD": 42.93181714954079
# }
# {
#     "wstETH": 114.34198980951885,
#     "weETH": 1965.1940075172054
# }
# {
#     "WETH": 1329.9599929460294,
#     "WBTC": 0.7403026605061225,
#     "RPL": 2356.5430322167167,
#     "cbBTC": 5.1921111544163265,
#     "USDS": 52097.526540027175,
#     "crvUSD": 42.93181714954079
# }
# {
#     "wstETH": 114.34198980951885,
#     "weETH": 1965.1940075172054
# }
# {
#     "WETH": 1329.9599929460294,
#     "WBTC": 0.7403026605061225,
#     "RPL": 2356.5430322167167,
#     "cbBTC": 5.1921111544163265,
#     "USDS": 52097.526540027175,
#     "crvUSD": 42.93181714954079
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 5029015.109984287,
#         "flashloan_start_usd": 5026254.1806889055,
#         "flashloan_end": 6642847.255190455,
#         "flashloan_end_usd": 6639200.332047355,
#         "flashloan_profit": 1612946.15135845,
#         "flashloan_profit_usd": 1612060.6439213543
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 5026256.112241518,
#         "flashloan_start_usd": 5026256.112241518,
#         "flashloan_end": 6639200.334403721,
#         "flashloan_end_usd": 6639200.334403721,
#         "flashloan_profit": 1612944.222162203,
#         "flashloan_profit_usd": 1612944.222162203
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 5026325.7081577005,
#         "flashloan_start_usd": 5026325.7081577005,
#         "flashloan_end": 5612924.758819776,
#         "flashloan_end_usd": 5612924.758819776,
#         "flashloan_profit": 586599.0506620752,
#         "flashloan_profit_usd": 586599.0506620752
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1508.2358196754392,
#         "flashloan_start_usd": 5603985.929227865,
#         "flashloan_end": 1786.849554064707,
#         "flashloan_end_usd": 6639200.334587285,
#         "flashloan_profit": 1035214.4053594198,
#         "flashloan_profit_usd": 3846432292.4094067
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 136.769919414452,
#     "weETH": 2350.6624861929463
# }
# {
#     "WETH": 1590.828717977503,
#     "WBTC": 0.885511397767347,
#     "RPL": 2818.77376062715,
#     "cbBTC": 6.210532328179592,
#     "USDS": 62316.341690763635,
#     "crvUSD": 51.3527985794232
# }
# {
#     "wstETH": 136.769919414452,
#     "weETH": 2350.6624861929463
# }
# {
#     "WETH": 1590.828717977503,
#     "WBTC": 0.885511397767347,
#     "RPL": 2818.77376062715,
#     "cbBTC": 6.210532328179592,
#     "USDS": 62316.341690763635,
#     "crvUSD": 51.3527985794232
# }
# {
#     "wstETH": 136.769919414452,
#     "weETH": 2350.6624861929463
# }
# {
#     "WETH": 1590.828717977503,
#     "WBTC": 0.885511397767347,
#     "RPL": 2818.77376062715,
#     "cbBTC": 6.210532328179592,
#     "USDS": 62316.341690763635,
#     "crvUSD": 51.3527985794232
# }
# {
#     "wstETH": 136.769919414452,
#     "weETH": 2350.6624861929463
# }
# {
#     "WETH": 1590.828717977503,
#     "WBTC": 0.885511397767347,
#     "RPL": 2818.77376062715,
#     "cbBTC": 6.210532328179592,
#     "USDS": 62316.341690763635,
#     "crvUSD": 51.3527985794232
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 6015493.501376163,
#         "flashloan_start_usd": 6012190.995443908,
#         "flashloan_end": 7945826.860061092,
#         "flashloan_end_usd": 7941464.6011149185,
#         "flashloan_profit": 1929273.605671011,
#         "flashloan_profit_usd": 1928214.4344614975
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 6012195.562712834,
#         "flashloan_start_usd": 6012195.562712834,
#         "flashloan_end": 7941464.830140239,
#         "flashloan_end_usd": 7941464.830140239,
#         "flashloan_profit": 1929269.2674274044,
#         "flashloan_profit_usd": 1929269.2674274044
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 6012351.06015874,
#         "flashloan_start_usd": 6012351.06015874,
#         "flashloan_end": 6282148.612490183,
#         "flashloan_end_usd": 6282148.612490183,
#         "flashloan_profit": 269797.55233144294,
#         "flashloan_profit_usd": 269797.55233144294
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1804.079756143583,
#         "flashloan_start_usd": 6703220.701129535,
#         "flashloan_end": 2137.3361607778706,
#         "flashloan_end_usd": 7941464.8656246485,
#         "flashloan_profit": 1238244.164495113,
#         "flashloan_profit_usd": 4600807635.156398
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 159.19784901938513,
#     "weETH": 2736.1309648686874
# }
# {
#     "WETH": 1851.6974430089763,
#     "WBTC": 1.0307201350285715,
#     "RPL": 3281.004489037583,
#     "cbBTC": 7.228953501942857,
#     "USDS": 72535.1568415001,
#     "crvUSD": 59.77378000930561
# }
# {
#     "wstETH": 159.19784901938513,
#     "weETH": 2736.1309648686874
# }
# {
#     "WETH": 1851.6974430089763,
#     "WBTC": 1.0307201350285715,
#     "RPL": 3281.004489037583,
#     "cbBTC": 7.228953501942857,
#     "USDS": 72535.1568415001,
#     "crvUSD": 59.77378000930561
# }
# {
#     "wstETH": 159.19784901938513,
#     "weETH": 2736.1309648686874
# }
# {
#     "WETH": 1851.6974430089763,
#     "WBTC": 1.0307201350285715,
#     "RPL": 3281.004489037583,
#     "cbBTC": 7.228953501942857,
#     "USDS": 72535.1568415001,
#     "crvUSD": 59.77378000930561
# }
# {
#     "wstETH": 159.19784901938513,
#     "weETH": 2736.1309648686874
# }
# {
#     "WETH": 1851.6974430089763,
#     "WBTC": 1.0307201350285715,
#     "RPL": 3281.004489037583,
#     "cbBTC": 7.228953501942857,
#     "USDS": 72535.1568415001,
#     "crvUSD": 59.77378000930561
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 7002019.044761918,
#         "flashloan_start_usd": 6998174.936306343,
#         "flashloan_end": 9248800.451462267,
#         "flashloan_end_usd": 9243722.860014414,
#         "flashloan_profit": 2245547.923708071,
#         "flashloan_profit_usd": 2244315.1178979552
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 6998183.756620589,
#         "flashloan_start_usd": 6998183.756620589,
#         "flashloan_end": 9243728.074745225,
#         "flashloan_end_usd": 9243728.074745225,
#         "flashloan_profit": 2245544.318124636,
#         "flashloan_profit_usd": 2245544.318124636
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 6998473.291469484,
#         "flashloan_start_usd": 6998473.291469484,
#         "flashloan_end": 6848183.054187171,
#         "flashloan_end_usd": 6848183.054187171,
#         "flashloan_profit": -150290.23728231248,
#         "flashloan_profit_usd": -150290.23728231248
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 2099.9315588652894,
#         "flashloan_start_usd": 7802484.700804281,
#         "flashloan_end": 2487.822767491034,
#         "flashloan_end_usd": 9243729.396662012,
#         "flashloan_profit": 1441244.6958577307,
#         "flashloan_profit_usd": 5355074379.482026
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 181.62577862431826,
#     "weETH": 3121.5994435444286
# }
# {
#     "WETH": 2112.56616804045,
#     "WBTC": 1.175928872289796,
#     "RPL": 3743.235217448016,
#     "cbBTC": 8.247374675706123,
#     "USDS": 82753.97199223656,
#     "crvUSD": 68.19476143918803
# }
# {
#     "wstETH": 181.62577862431826,
#     "weETH": 3121.5994435444286
# }
# {
#     "WETH": 2112.56616804045,
#     "WBTC": 1.175928872289796,
#     "RPL": 3743.235217448016,
#     "cbBTC": 8.247374675706123,
#     "USDS": 82753.97199223656,
#     "crvUSD": 68.19476143918803
# }
# {
#     "wstETH": 181.62577862431826,
#     "weETH": 3121.5994435444286
# }
# {
#     "WETH": 2112.56616804045,
#     "WBTC": 1.175928872289796,
#     "RPL": 3743.235217448016,
#     "cbBTC": 8.247374675706123,
#     "USDS": 82753.97199223656,
#     "crvUSD": 68.19476143918803
# }
# {
#     "wstETH": 181.62577862431826,
#     "weETH": 3121.5994435444286
# }
# {
#     "WETH": 2112.56616804045,
#     "WBTC": 1.175928872289796,
#     "RPL": 3743.235217448016,
#     "cbBTC": 8.247374675706123,
#     "USDS": 82753.97199223656,
#     "crvUSD": 68.19476143918803
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 7988607.68375521,
#         "flashloan_start_usd": 7984221.938136828,
#         "flashloan_end": 10551719.056550406,
#         "flashloan_end_usd": 10545926.16278836,
#         "flashloan_profit": 2561704.224651532,
#         "flashloan_profit_usd": 2560297.849032198
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 7984236.854868342,
#         "flashloan_start_usd": 7984236.854868342,
#         "flashloan_end": 10545975.637991672,
#         "flashloan_end_usd": 10545975.637991672,
#         "flashloan_profit": 2561738.78312333,
#         "flashloan_profit_usd": 2561738.78312333
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 7984714.948885372,
#         "flashloan_start_usd": 7984714.948885372,
#         "flashloan_end": 7334030.316841002,
#         "flashloan_end_usd": 7334030.316841002,
#         "flashloan_profit": -650684.6320443703,
#         "flashloan_profit_usd": -650684.6320443703
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 2395.794671093144,
#         "flashloan_start_usd": 8901790.721966976,
#         "flashloan_end": 2838.3093742041874,
#         "flashloan_end_usd": 10545993.927699337,
#         "flashloan_profit": 1644203.2057323612,
#         "flashloan_profit_usd": 6109184989.187104
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 204.0537082292514,
#     "weETH": 3507.0679222201697
# }
# {
#     "WETH": 2373.4348930719234,
#     "WBTC": 1.3211376095510206,
#     "RPL": 4205.465945858449,
#     "cbBTC": 9.265795849469388,
#     "USDS": 92972.78714297303,
#     "crvUSD": 76.61574286907043
# }
# {
#     "wstETH": 204.0537082292514,
#     "weETH": 3507.0679222201697
# }
# {
#     "WETH": 2373.4348930719234,
#     "WBTC": 1.3211376095510206,
#     "RPL": 4205.465945858449,
#     "cbBTC": 9.265795849469388,
#     "USDS": 92972.78714297303,
#     "crvUSD": 76.61574286907043
# }
# {
#     "wstETH": 204.0537082292514,
#     "weETH": 3507.0679222201697
# }
# {
#     "WETH": 2373.4348930719234,
#     "WBTC": 1.3211376095510206,
#     "RPL": 4205.465945858449,
#     "cbBTC": 9.265795849469388,
#     "USDS": 92972.78714297303,
#     "crvUSD": 76.61574286907043
# }
# {
#     "wstETH": 204.0537082292514,
#     "weETH": 3507.0679222201697
# }
# {
#     "WETH": 2373.4348930719234,
#     "WBTC": 1.3211376095510206,
#     "RPL": 4205.465945858449,
#     "cbBTC": 9.265795849469388,
#     "USDS": 92972.78714297303,
#     "crvUSD": 76.61574286907043
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 8975274.382963635,
#         "flashloan_start_usd": 8970346.957327388,
#         "flashloan_end": 11854366.090450644,
#         "flashloan_end_usd": 11847858.043466987,
#         "flashloan_profit": 2877511.086139599,
#         "flashloan_profit_usd": 2875931.332553308
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 8970369.963823812,
#         "flashloan_start_usd": 8970369.963823812,
#         "flashloan_end": 11848124.866236946,
#         "flashloan_end_usd": 11848124.866236946,
#         "flashloan_profit": 2877754.9024131335,
#         "flashloan_profit_usd": 2877754.9024131335
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 8971095.939694446,
#         "flashloan_start_usd": 8971095.939694446,
#         "flashloan_end": 7757146.364569868,
#         "flashloan_end_usd": 7757146.364569868,
#         "flashloan_profit": -1213949.5751245776,
#         "flashloan_profit_usd": -1213949.5751245776
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 2691.6725294818043,
#         "flashloan_start_usd": 10001151.533817297,
#         "flashloan_end": 3188.7959809160448,
#         "flashloan_end_usd": 11848258.458731847,
#         "flashloan_profit": 1847106.9249145496,
#         "flashloan_profit_usd": 6863092019.143251
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 226.48163783418454,
#     "weETH": 3892.536400895911
# }
# {
#     "WETH": 2634.3036181033967,
#     "WBTC": 1.466346346812245,
#     "RPL": 4667.696674268882,
#     "cbBTC": 10.284217023232653,
#     "USDS": 103191.60229370948,
#     "crvUSD": 85.03672429895285
# }
# {
#     "wstETH": 226.48163783418454,
#     "weETH": 3892.536400895911
# }
# {
#     "WETH": 2634.3036181033967,
#     "WBTC": 1.466346346812245,
#     "RPL": 4667.696674268882,
#     "cbBTC": 10.284217023232653,
#     "USDS": 103191.60229370948,
#     "crvUSD": 85.03672429895285
# }
# {
#     "wstETH": 226.48163783418454,
#     "weETH": 3892.536400895911
# }
# {
#     "WETH": 2634.3036181033967,
#     "WBTC": 1.466346346812245,
#     "RPL": 4667.696674268882,
#     "cbBTC": 10.284217023232653,
#     "USDS": 103191.60229370948,
#     "crvUSD": 85.03672429895285
# }
# {
#     "wstETH": 226.48163783418454,
#     "weETH": 3892.536400895911
# }
# {
#     "WETH": 2634.3036181033967,
#     "WBTC": 1.466346346812245,
#     "RPL": 4667.696674268882,
#     "cbBTC": 10.284217023232653,
#     "USDS": 103191.60229370948,
#     "crvUSD": 85.03672429895285
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 10964678.30443534,
#         "flashloan_start_usd": 10958658.696046205,
#         "flashloan_end": 13156133.173700765,
#         "flashloan_end_usd": 13148910.456588402,
#         "flashloan_profit": 2190251.760542197,
#         "flashloan_profit_usd": 2189049.312325659
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 10958691.007249236,
#         "flashloan_start_usd": 10958691.007249236,
#         "flashloan_end": 13149890.971979752,
#         "flashloan_end_usd": 13149890.971979752,
#         "flashloan_profit": 2191199.964730516,
#         "flashloan_profit_usd": 2191199.964730516
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 11126124.170343217,
#         "flashloan_start_usd": 11126124.170343217,
#         "flashloan_end": 8130651.267469601,
#         "flashloan_end_usd": 8130651.267469601,
#         "flashloan_profit": -2995472.9028736157,
#         "flashloan_profit_usd": -2995472.9028736157
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 2987.56842263153,
#         "flashloan_start_usd": 11100579.355445487,
#         "flashloan_end": 3539.282587578358,
#         "flashloan_end_usd": 13150522.989580272,
#         "flashloan_profit": 2049943.6341347834,
#         "flashloan_profit_usd": 7616750067.55486
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 248.9095674391177,
#     "weETH": 4278.004879571652
# }
# {
#     "WETH": 2895.1723431348705,
#     "WBTC": 1.6115550840734696,
#     "RPL": 5129.9274026793155,
#     "cbBTC": 11.302638196995918,
#     "USDS": 113410.41744444595,
#     "crvUSD": 93.45770572883525
# }
# {
#     "wstETH": 248.9095674391177,
#     "weETH": 4278.004879571652
# }
# {
#     "WETH": 2895.1723431348705,
#     "WBTC": 1.6115550840734696,
#     "RPL": 5129.9274026793155,
#     "cbBTC": 11.302638196995918,
#     "USDS": 113410.41744444595,
#     "crvUSD": 93.45770572883525
# }
# {
#     "wstETH": 248.9095674391177,
#     "weETH": 4278.004879571652
# }
# {
#     "WETH": 2895.1723431348705,
#     "WBTC": 1.6115550840734696,
#     "RPL": 5129.9274026793155,
#     "cbBTC": 11.302638196995918,
#     "USDS": 113410.41744444595,
#     "crvUSD": 93.45770572883525
# }
# {
#     "wstETH": 248.9095674391177,
#     "weETH": 4278.004879571652
# }
# {
#     "WETH": 2895.1723431348705,
#     "WBTC": 1.6115550840734696,
#     "RPL": 5129.9274026793155,
#     "cbBTC": 11.302638196995918,
#     "USDS": 113410.41744444595,
#     "crvUSD": 93.45770572883525
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 12050834.198562846,
#         "flashloan_start_usd": 12044218.290587835,
#         "flashloan_end": 14455778.719497945,
#         "flashloan_end_usd": 14447842.49698094,
#         "flashloan_profit": 2403624.2063931064,
#         "flashloan_profit_usd": 2402304.6167037967
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 12044259.28611057,
#         "flashloan_start_usd": 12044259.28611057,
#         "flashloan_end": 14450589.710862394,
#         "flashloan_end_usd": 14450589.710862394,
#         "flashloan_profit": 2406330.424751824,
#         "flashloan_profit_usd": 2406330.424751824
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 12298545.854085509,
#         "flashloan_start_usd": 12298545.854085509,
#         "flashloan_end": 8464437.845602516,
#         "flashloan_end_usd": 8464437.845602516,
#         "flashloan_profit": -3834108.0084829926,
#         "flashloan_profit_usd": -3834108.0084829926
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 3283.4854319745446,
#         "flashloan_start_usd": 12200085.636190299,
#         "flashloan_end": 3889.7691933913666,
#         "flashloan_end_usd": 14452787.517273027,
#         "flashloan_profit": 2252701.88108273,
#         "flashloan_profit_usd": 8370116582.332181
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 271.33749704405085,
#     "weETH": 4663.473358247394
# }
# {
#     "WETH": 3156.041068166344,
#     "WBTC": 1.7567638213346939,
#     "RPL": 5592.158131089748,
#     "cbBTC": 12.321059370759183,
#     "USDS": 123629.2325951824,
#     "crvUSD": 101.87868715871767
# }
# {
#     "wstETH": 271.33749704405085,
#     "weETH": 4663.473358247394
# }
# {
#     "WETH": 3156.041068166344,
#     "WBTC": 1.7567638213346939,
#     "RPL": 5592.158131089748,
#     "cbBTC": 12.321059370759183,
#     "USDS": 123629.2325951824,
#     "crvUSD": 101.87868715871767
# }
# {
#     "wstETH": 271.33749704405085,
#     "weETH": 4663.473358247394
# }
# {
#     "WETH": 3156.041068166344,
#     "WBTC": 1.7567638213346939,
#     "RPL": 5592.158131089748,
#     "cbBTC": 12.321059370759183,
#     "USDS": 123629.2325951824,
#     "crvUSD": 101.87868715871767
# }
# {
#     "wstETH": 271.33749704405085,
#     "weETH": 4663.473358247394
# }
# {
#     "WETH": 3156.041068166344,
#     "WBTC": 1.7567638213346939,
#     "RPL": 5592.158131089748,
#     "cbBTC": 12.321059370759183,
#     "USDS": 123629.2325951824,
#     "crvUSD": 101.87868715871767
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 13137115.068532968,
#         "flashloan_start_usd": 13129902.792360343,
#         "flashloan_end": 15751286.436052578,
#         "flashloan_end_usd": 15742638.979799185,
#         "flashloan_profit": 2612736.1874388414,
#         "flashloan_profit_usd": 2611301.7952719373
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 13129945.375425346,
#         "flashloan_start_usd": 13129945.375425346,
#         "flashloan_end": 15748952.802221313,
#         "flashloan_end_usd": 15748952.802221313,
#         "flashloan_profit": 2619007.426795967,
#         "flashloan_profit_usd": 2619007.426795967
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 13503576.210841732,
#         "flashloan_start_usd": 13503576.210841732,
#         "flashloan_end": 8766021.90599296,
#         "flashloan_end_usd": 8766021.90599296,
#         "flashloan_profit": -4737554.304848772,
#         "flashloan_profit_usd": -4737554.304848772
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 3579.4264194259054,
#         "flashloan_start_usd": 13299681.0097547,
#         "flashloan_end": 4240.255791132687,
#         "flashloan_end_usd": 15755052.0149747,
#         "flashloan_profit": 2455371.0052199997,
#         "flashloan_profit_usd": 9123151953.28538
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 293.765426648984,
#     "weETH": 5048.941836923134
# }
# {
#     "WETH": 3416.9097931978176,
#     "WBTC": 1.9019725585959184,
#     "RPL": 6054.388859500181,
#     "cbBTC": 13.339480544522448,
#     "USDS": 133848.04774591888,
#     "crvUSD": 110.29966858860007
# }
# {
#     "wstETH": 293.765426648984,
#     "weETH": 5048.941836923134
# }
# {
#     "WETH": 3416.9097931978176,
#     "WBTC": 1.9019725585959184,
#     "RPL": 6054.388859500181,
#     "cbBTC": 13.339480544522448,
#     "USDS": 133848.04774591888,
#     "crvUSD": 110.29966858860007
# }
# {
#     "wstETH": 293.765426648984,
#     "weETH": 5048.941836923134
# }
# {
#     "WETH": 3416.9097931978176,
#     "WBTC": 1.9019725585959184,
#     "RPL": 6054.388859500181,
#     "cbBTC": 13.339480544522448,
#     "USDS": 133848.04774591888,
#     "crvUSD": 110.29966858860007
# }
# {
#     "wstETH": 293.765426648984,
#     "weETH": 5048.941836923134
# }
# {
#     "WETH": 3416.9097931978176,
#     "WBTC": 1.9019725585959184,
#     "RPL": 6054.388859500181,
#     "cbBTC": 13.339480544522448,
#     "USDS": 133848.04774591888,
#     "crvUSD": 110.29966858860007
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 14223545.698875913,
#         "flashloan_start_usd": 14215736.97228723,
#         "flashloan_end": 17039884.212496154,
#         "flashloan_end_usd": 17030529.316063493,
#         "flashloan_profit": 2814792.343776263,
#         "flashloan_profit_usd": 2813247.0227795294
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 14215759.73844047,
#         "flashloan_start_usd": 14215759.73844047,
#         "flashloan_end": 17043035.86394636,
#         "flashloan_end_usd": 17043035.86394636,
#         "flashloan_profit": 2827276.125505889,
#         "flashloan_profit_usd": 2827276.125505889
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 14752404.170274844,
#         "flashloan_start_usd": 14752404.170274844,
#         "flashloan_end": 9041160.645973315,
#         "flashloan_end_usd": 9041160.645973315,
#         "flashloan_profit": -5711243.524301529,
#         "flashloan_profit_usd": -5711243.524301529
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 3875.394038575173,
#         "flashloan_start_usd": 14399375.335789528,
#         "flashloan_end": 4590.7423396418135,
#         "flashloan_end_usd": 17057316.329749726,
#         "flashloan_profit": 2657940.993960199,
#         "flashloan_profit_usd": 9875818977.748575
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 316.1933562539171,
#     "weETH": 5434.410315598876
# }
# {
#     "WETH": 3677.778518229291,
#     "WBTC": 2.047181295857143,
#     "RPL": 6516.619587910614,
#     "cbBTC": 14.357901718285714,
#     "USDS": 144066.86289665534,
#     "crvUSD": 118.72065001848249
# }
# {
#     "wstETH": 316.1933562539171,
#     "weETH": 5434.410315598876
# }
# {
#     "WETH": 3677.778518229291,
#     "WBTC": 2.047181295857143,
#     "RPL": 6516.619587910614,
#     "cbBTC": 14.357901718285714,
#     "USDS": 144066.86289665534,
#     "crvUSD": 118.72065001848249
# }
# {
#     "wstETH": 316.1933562539171,
#     "weETH": 5434.410315598876
# }
# {
#     "WETH": 3677.778518229291,
#     "WBTC": 2.047181295857143,
#     "RPL": 6516.619587910614,
#     "cbBTC": 14.357901718285714,
#     "USDS": 144066.86289665534,
#     "crvUSD": 118.72065001848249
# }
# {
#     "wstETH": 316.1933562539171,
#     "weETH": 5434.410315598876
# }
# {
#     "WETH": 3677.778518229291,
#     "WBTC": 2.047181295857143,
#     "RPL": 6516.619587910614,
#     "cbBTC": 14.357901718285714,
#     "USDS": 144066.86289665534,
#     "crvUSD": 118.72065001848249
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 15310162.373121854,
#         "flashloan_start_usd": 15301757.09397901,
#         "flashloan_end": 18318205.333117675,
#         "flashloan_end_usd": 18308148.638389792,
#         "flashloan_profit": 3006391.5444107833,
#         "flashloan_profit_usd": 3004741.035452902
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 15301712.034086475,
#         "flashloan_start_usd": 15301712.034086475,
#         "flashloan_end": 18330251.164108776,
#         "flashloan_end_usd": 18330251.164108776,
#         "flashloan_profit": 3028539.1300223004,
#         "flashloan_profit_usd": 3028539.1300223004
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 16061692.294505417,
#         "flashloan_start_usd": 16061692.294505417,
#         "flashloan_end": 9294297.628796482,
#         "flashloan_end_usd": 9294297.628796482,
#         "flashloan_profit": -6767394.665708935,
#         "flashloan_profit_usd": -6767394.665708935
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 4171.390756060832,
#         "flashloan_start_usd": 15499177.779312069,
#         "flashloan_end": 4941.228674289357,
#         "flashloan_end_usd": 18359579.84990279,
#         "flashloan_profit": 2860402.070590723,
#         "flashloan_profit_usd": 10628081329.466185
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 338.62128585885023,
#     "weETH": 5819.878794274617
# }
# {
#     "WETH": 3938.6472432607643,
#     "WBTC": 2.1923900331183677,
#     "RPL": 6978.850316321047,
#     "cbBTC": 15.376322892048979,
#     "USDS": 154285.6780473918,
#     "crvUSD": 127.1416314483649
# }
# {
#     "wstETH": 338.62128585885023,
#     "weETH": 5819.878794274617
# }
# {
#     "WETH": 3938.6472432607643,
#     "WBTC": 2.1923900331183677,
#     "RPL": 6978.850316321047,
#     "cbBTC": 15.376322892048979,
#     "USDS": 154285.6780473918,
#     "crvUSD": 127.1416314483649
# }
# {
#     "wstETH": 338.62128585885023,
#     "weETH": 5819.878794274617
# }
# {
#     "WETH": 3938.6472432607643,
#     "WBTC": 2.1923900331183677,
#     "RPL": 6978.850316321047,
#     "cbBTC": 15.376322892048979,
#     "USDS": 154285.6780473918,
#     "crvUSD": 127.1416314483649
# }
# {
#     "wstETH": 338.62128585885023,
#     "weETH": 5819.878794274617
# }
# {
#     "WETH": 3938.6472432607643,
#     "WBTC": 2.1923900331183677,
#     "RPL": 6978.850316321047,
#     "cbBTC": 15.376322892048979,
#     "USDS": 154285.6780473918,
#     "crvUSD": 127.1416314483649
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 16397016.99817401,
#         "flashloan_start_usd": 16388015.035842013,
#         "flashloan_end": 19582530.205228034,
#         "flashloan_end_usd": 19571779.396145362,
#         "flashloan_profit": 3183764.3603033517,
#         "flashloan_profit_usd": 3182016.4736695453
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 16387811.262283133,
#         "flashloan_start_usd": 16387811.262283133,
#         "flashloan_end": 19607505.948167197,
#         "flashloan_end_usd": 19607505.948167197,
#         "flashloan_profit": 3219694.685884064,
#         "flashloan_profit_usd": 3219694.685884064
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 17457576.679163218,
#         "flashloan_start_usd": 17457576.679163218,
#         "flashloan_end": 9528885.41254884,
#         "flashloan_end_usd": 9528885.41254884,
#         "flashloan_profit": -7928691.2666143775,
#         "flashloan_profit_usd": -7928691.2666143775
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 4467.418876023892,
#         "flashloan_start_usd": 16599096.901565613,
#         "flashloan_end": 5291.714295174145,
#         "flashloan_end_usd": 19661840.718006104,
#         "flashloan_profit": 3062743.816440489,
#         "flashloan_profit_usd": 11379900296.928118
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 361.0492154637834,
#     "weETH": 6205.347272950358
# }
# {
#     "WETH": 4199.515968292238,
#     "WBTC": 2.337598770379592,
#     "RPL": 7441.081044731481,
#     "cbBTC": 16.394744065812244,
#     "USDS": 164504.49319812824,
#     "crvUSD": 135.5626128782473
# }
# {
#     "wstETH": 361.0492154637834,
#     "weETH": 6205.347272950358
# }
# {
#     "WETH": 4199.515968292238,
#     "WBTC": 2.337598770379592,
#     "RPL": 7441.081044731481,
#     "cbBTC": 16.394744065812244,
#     "USDS": 164504.49319812824,
#     "crvUSD": 135.5626128782473
# }
# {
#     "wstETH": 361.0492154637834,
#     "weETH": 6205.347272950358
# }
# {
#     "WETH": 4199.515968292238,
#     "WBTC": 2.337598770379592,
#     "RPL": 7441.081044731481,
#     "cbBTC": 16.394744065812244,
#     "USDS": 164504.49319812824,
#     "crvUSD": 135.5626128782473
# }
# {
#     "wstETH": 361.0492154637834,
#     "weETH": 6205.347272950358
# }
# {
#     "WETH": 4199.515968292238,
#     "WBTC": 2.337598770379592,
#     "RPL": 7441.081044731481,
#     "cbBTC": 16.394744065812244,
#     "USDS": 164504.49319812824,
#     "crvUSD": 135.5626128782473
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 17484180.045087546,
#         "flashloan_start_usd": 17474581.230242793,
#         "flashloan_end": 20829043.652203783,
#         "flashloan_end_usd": 20817608.507238723,
#         "flashloan_profit": 3343027.2769959304,
#         "flashloan_profit_usd": 3341191.9550208594
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 17474065.899130225,
#         "flashloan_start_usd": 17474065.899130225,
#         "flashloan_end": 20871400.507445846,
#         "flashloan_end_usd": 20871400.507445846,
#         "flashloan_profit": 3397334.6083156206,
#         "flashloan_profit_usd": 3397334.6083156206
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 18983776.651852924,
#         "flashloan_start_usd": 18983776.651852924,
#         "flashloan_end": 9747622.948163457,
#         "flashloan_end_usd": 9747622.948163457,
#         "flashloan_profit": -9236153.703689467,
#         "flashloan_profit_usd": -9236153.703689467
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 4763.480564130376,
#         "flashloan_start_usd": 17699140.749277182,
#         "flashloan_end": 5642.197979956749,
#         "flashloan_end_usd": 20964094.392347496,
#         "flashloan_profit": 3264953.6430703145,
#         "flashloan_profit_usd": 12131229106.65563
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 383.47714506871654,
#     "weETH": 6590.815751626099
# }
# {
#     "WETH": 4460.384693323712,
#     "WBTC": 2.4828075076408163,
#     "RPL": 7903.311773141913,
#     "cbBTC": 17.41316523957551,
#     "USDS": 174723.30834886472,
#     "crvUSD": 143.9835943081297
# }
# {
#     "wstETH": 383.47714506871654,
#     "weETH": 6590.815751626099
# }
# {
#     "WETH": 4460.384693323712,
#     "WBTC": 2.4828075076408163,
#     "RPL": 7903.311773141913,
#     "cbBTC": 17.41316523957551,
#     "USDS": 174723.30834886472,
#     "crvUSD": 143.9835943081297
# }
# {
#     "wstETH": 383.47714506871654,
#     "weETH": 6590.815751626099
# }
# {
#     "WETH": 4460.384693323712,
#     "WBTC": 2.4828075076408163,
#     "RPL": 7903.311773141913,
#     "cbBTC": 17.41316523957551,
#     "USDS": 174723.30834886472,
#     "crvUSD": 143.9835943081297
# }
# {
#     "wstETH": 383.47714506871654,
#     "weETH": 6590.815751626099
# }
# {
#     "WETH": 4460.384693323712,
#     "WBTC": 2.4828075076408163,
#     "RPL": 7903.311773141913,
#     "cbBTC": 17.41316523957551,
#     "USDS": 174723.30834886472,
#     "crvUSD": 143.9835943081297
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 18571741.97322268,
#         "flashloan_start_usd": 18561546.08687938,
#         "flashloan_end": 22054061.596265968,
#         "flashloan_end_usd": 22041953.916449618,
#         "flashloan_profit": 3480407.8295702366,
#         "flashloan_profit_usd": 3478497.0856718025
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 18560484.043444294,
#         "flashloan_start_usd": 18560484.043444294,
#         "flashloan_end": 22118439.08712981,
#         "flashloan_end_usd": 22118439.08712981,
#         "flashloan_profit": 3557955.0436855145,
#         "flashloan_profit_usd": 3557955.0436855145
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 20719877.22111106,
#         "flashloan_start_usd": 20719877.22111106,
#         "flashloan_end": 9952632.965029158,
#         "flashloan_end_usd": 9952632.965029158,
#         "flashloan_profit": -10767244.256081901,
#         "flashloan_profit_usd": -10767244.256081901
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 5059.577869604524,
#         "flashloan_start_usd": 18799316.936523873,
#         "flashloan_end": 5992.677212094638,
#         "flashloan_end_usd": 22266331.522486717,
#         "flashloan_profit": 3467014.585962844,
#         "flashloan_profit_usd": 12882004725.457684
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 405.90507467364966,
#     "weETH": 6976.284230301841
# }
# {
#     "WETH": 4721.253418355185,
#     "WBTC": 2.628016244902041,
#     "RPL": 8365.542501552347,
# ...
# {
#     "wstETH": 989.0312444019113,
#     "weETH": 16998.46467587111
# }
# {
#     "WETH": 11503.840269173495,
#     "WBTC": 6.403443413693878,
#     "RPL": 20383.541440223606,
#     "cbBTC": 44.91053693118367,
#     "USDS": 450631.31741874915,
#     "crvUSD": 371.3500929149548
# }
# {
#     "wstETH": 989.0312444019113,
#     "weETH": 16998.46467587111
# }
# {
#     "WETH": 11503.840269173495,
#     "WBTC": 6.403443413693878,
#     "RPL": 20383.541440223606,
#     "cbBTC": 44.91053693118367,
#     "USDS": 450631.31741874915,
#     "crvUSD": 371.3500929149548
# }
# {
#     "wstETH": 989.0312444019113,
#     "weETH": 16998.46467587111
# }
# {
#     "WETH": 11503.840269173495,
#     "WBTC": 6.403443413693878,
#     "RPL": 20383.541440223606,
#     "cbBTC": 44.91053693118367,
#     "USDS": 450631.31741874915,
#     "crvUSD": 371.3500929149548
# }
# {
#     "wstETH": 989.0312444019113,
#     "weETH": 16998.46467587111
# }
# {
#     "WETH": 11503.840269173495,
#     "WBTC": 6.403443413693878,
#     "RPL": 20383.541440223606,
#     "cbBTC": 44.91053693118367,
#     "USDS": 450631.31741874915,
#     "crvUSD": 371.3500929149548
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 48957576.111955546,
#         "flashloan_start_usd": 48930698.40267008,
#         "flashloan_end": 43199673.62783167,
#         "flashloan_end_usd": 43175957.00700999,
#         "flashloan_profit": -5754741.395660094,
#         "flashloan_profit_usd": -5751582.042633876
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 48171915.31919105,
#         "flashloan_start_usd": 48171915.31919105,
#         "flashloan_end": 44560747.4311576,
#         "flashloan_end_usd": 44560747.4311576,
#         "flashloan_profit": -3611167.888033457,
#         "flashloan_profit_usd": -3611167.888033457
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1349661998.3638885,
#         "flashloan_start_usd": 1349661998.3638885,
#         "flashloan_end": 12940612.900646029,
#         "flashloan_end_usd": 12940612.900646029,
#         "flashloan_profit": -1336721385.4632425,
#         "flashloan_profit_usd": -1336721385.4632425
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 13073.975258352588,
#         "flashloan_start_usd": 48577531.73018229,
#         "flashloan_end": 11615.050534993634,
#         "flashloan_end_usd": 43156765.617317,
#         "flashloan_profit": -5420766.112865296,
#         "flashloan_profit_usd": -20141344361.301167
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 1011.4591740068445,
#     "weETH": 17383.933154546852
# }
# {
#     "WETH": 11764.70899420497,
#     "WBTC": 6.548652150955102,
#     "RPL": 20845.772168634037,
#     "cbBTC": 45.928958104946936,
#     "USDS": 460850.13256948564,
#     "crvUSD": 379.77107434483725
# }
# {
#     "wstETH": 1011.4591740068445,
#     "weETH": 17383.933154546852
# }
# {
#     "WETH": 11764.70899420497,
#     "WBTC": 6.548652150955102,
#     "RPL": 20845.772168634037,
#     "cbBTC": 45.928958104946936,
#     "USDS": 460850.13256948564,
#     "crvUSD": 379.77107434483725
# }
# {
#     "wstETH": 1011.4591740068445,
#     "weETH": 17383.933154546852
# }
# {
#     "WETH": 11764.70899420497,
#     "WBTC": 6.548652150955102,
#     "RPL": 20845.772168634037,
#     "cbBTC": 45.928958104946936,
#     "USDS": 460850.13256948564,
#     "crvUSD": 379.77107434483725
# }
# {
#     "wstETH": 1011.4591740068445,
#     "weETH": 17383.933154546852
# }
# {
#     "WETH": 11764.70899420497,
#     "WBTC": 6.548652150955102,
#     "RPL": 20845.772168634037,
#     "cbBTC": 45.928958104946936,
#     "USDS": 460850.13256948564,
#     "crvUSD": 379.77107434483725
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 50190180.871129125,
#         "flashloan_start_usd": 50162626.46183088,
#         "flashloan_end": 43603138.734132275,
#         "flashloan_end_usd": 43579200.610967234,
#         "flashloan_profit": -6583425.850863639,
#         "flashloan_profit_usd": -6579811.550071515
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 49303811.775344424,
#         "flashloan_start_usd": 49303811.775344424,
#         "flashloan_end": 45012235.745770276,
#         "flashloan_end_usd": 45012235.745770276,
#         "flashloan_profit": -4291576.029574148,
#         "flashloan_profit_usd": -4291576.029574148
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 79869935.92943151,
#         "flashloan_start_usd": 79869935.92943151,
#         "flashloan_end": 12996901.552002247,
#         "flashloan_end_usd": 12996901.552002247,
#         "flashloan_profit": -66873034.37742926,
#         "flashloan_profit_usd": -66873034.37742926
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 13371.766879847035,
#         "flashloan_start_usd": 49684003.301090844,
#         "flashloan_end": 11501.978281304408,
#         "flashloan_end_usd": 42736635.48223185,
#         "flashloan_profit": -6947367.818859001,
#         "flashloan_profit_usd": -25813570394.074314
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 1033.8871036117773,
#     "weETH": 17769.40163322259
# }
# {
#     "WETH": 12025.577719236442,
#     "WBTC": 6.693860888216326,
#     "RPL": 21308.00289704447,
#     "cbBTC": 46.947379278710194,
#     "USDS": 471068.94772022206,
#     "crvUSD": 388.19205577471956
# }
# {
#     "wstETH": 1033.8871036117773,
#     "weETH": 17769.40163322259
# }
# {
#     "WETH": 12025.577719236442,
#     "WBTC": 6.693860888216326,
#     "RPL": 21308.00289704447,
#     "cbBTC": 46.947379278710194,
#     "USDS": 471068.94772022206,
#     "crvUSD": 388.19205577471956
# }
# {
#     "wstETH": 1033.8871036117773,
#     "weETH": 17769.40163322259
# }
# {
#     "WETH": 12025.577719236442,
#     "WBTC": 6.693860888216326,
#     "RPL": 21308.00289704447,
#     "cbBTC": 46.947379278710194,
#     "USDS": 471068.94772022206,
#     "crvUSD": 388.19205577471956
# }
# {
#     "wstETH": 1033.8871036117773,
#     "weETH": 17769.40163322259
# }
# {
#     "WETH": 12025.577719236442,
#     "WBTC": 6.693860888216326,
#     "RPL": 21308.00289704447,
#     "cbBTC": 46.947379278710194,
#     "USDS": 471068.94772022206,
#     "crvUSD": 388.19205577471956
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 51442187.96329146,
#         "flashloan_start_usd": 51413946.202099614,
#         "flashloan_end": 43987970.92950337,
#         "flashloan_end_usd": 43963821.53346307,
#         "flashloan_profit": -7450124.668636543,
#         "flashloan_profit_usd": -7446034.550193461
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 50441571.2918819,
#         "flashloan_start_usd": 50441571.2918819,
#         "flashloan_end": 45444488.90923865,
#         "flashloan_end_usd": 45444488.90923865,
#         "flashloan_profit": -4997082.382643245,
#         "flashloan_profit_usd": -4997082.382643245
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 85915159.65304217,
#         "flashloan_start_usd": 85915159.65304217,
#         "flashloan_end": 13050847.327156099,
#         "flashloan_end_usd": 13050847.327156099,
#         "flashloan_profit": -72864312.32588607,
#         "flashloan_profit_usd": -72864312.32588607
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 13669.645474696486,
#         "flashloan_start_usd": 50790798.02932752,
#         "flashloan_end": 11373.912271340178,
#         "flashloan_end_usd": 42260794.69626885,
#         "flashloan_profit": -8530003.333058668,
#         "flashloan_profit_usd": -31693995084.279457
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 1056.3150332167106,
#     "weETH": 18154.87011189833
# }
# {
#     "WETH": 12286.446444267916,
#     "WBTC": 6.839069625477551,
#     "RPL": 21770.2336254549,
#     "cbBTC": 47.96580045247346,
#     "USDS": 481287.76287095854,
#     "crvUSD": 396.613037204602
# }
# {
#     "wstETH": 1056.3150332167106,
#     "weETH": 18154.87011189833
# }
# {
#     "WETH": 12286.446444267916,
#     "WBTC": 6.839069625477551,
#     "RPL": 21770.2336254549,
#     "cbBTC": 47.96580045247346,
#     "USDS": 481287.76287095854,
#     "crvUSD": 396.613037204602
# }
# {
#     "wstETH": 1056.3150332167106,
#     "weETH": 18154.87011189833
# }
# {
#     "WETH": 12286.446444267916,
#     "WBTC": 6.839069625477551,
#     "RPL": 21770.2336254549,
#     "cbBTC": 47.96580045247346,
#     "USDS": 481287.76287095854,
#     "crvUSD": 396.613037204602
# }
# {
#     "wstETH": 1056.3150332167106,
#     "weETH": 18154.87011189833
# }
# {
#     "WETH": 12286.446444267916,
#     "WBTC": 6.839069625477551,
#     "RPL": 21770.2336254549,
#     "cbBTC": 47.96580045247346,
#     "USDS": 481287.76287095854,
#     "crvUSD": 396.613037204602
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 52716800.54810457,
#         "flashloan_start_usd": 52687859.02460366,
#         "flashloan_end": 44354957.27284317,
#         "flashloan_end_usd": 44330606.40130038,
#         "flashloan_profit": -8357252.623303283,
#         "flashloan_profit_usd": -8352664.491613089
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 51585695.79754524,
#         "flashloan_start_usd": 51585695.79754524,
#         "flashloan_end": 45858275.23582993,
#         "flashloan_end_usd": 45858275.23582993,
#         "flashloan_profit": -5727420.561715312,
#         "flashloan_profit_usd": -5727420.561715312
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 89866512.42163976,
#         "flashloan_start_usd": 89866512.42163976,
#         "flashloan_end": 13102552.310739841,
#         "flashloan_end_usd": 13102552.310739841,
#         "flashloan_profit": -76763960.11089991,
#         "flashloan_profit_usd": -76763960.11089991
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 13967.613379723653,
#         "flashloan_start_usd": 51897924.59756741,
#         "flashloan_end": 11233.122712050466,
#         "flashloan_end_usd": 41737678.4176676,
#         "flashloan_profit": -10160246.179899814,
#         "flashloan_profit_usd": -37751309103.57395
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 1078.7429628216437,
#     "weETH": 18540.338590574072
# }
# {
#     "WETH": 12547.31516929939,
#     "WBTC": 6.984278362738776,
#     "RPL": 22232.464353865336,
#     "cbBTC": 48.98422162623673,
#     "USDS": 491506.578021695,
#     "crvUSD": 405.0340186344844
# }
# {
#     "wstETH": 1078.7429628216437,
#     "weETH": 18540.338590574072
# }
# {
#     "WETH": 12547.31516929939,
#     "WBTC": 6.984278362738776,
#     "RPL": 22232.464353865336,
#     "cbBTC": 48.98422162623673,
#     "USDS": 491506.578021695,
#     "crvUSD": 405.0340186344844
# }
# {
#     "wstETH": 1078.7429628216437,
#     "weETH": 18540.338590574072
# }
# {
#     "WETH": 12547.31516929939,
#     "WBTC": 6.984278362738776,
#     "RPL": 22232.464353865336,
#     "cbBTC": 48.98422162623673,
#     "USDS": 491506.578021695,
#     "crvUSD": 405.0340186344844
# }
# {
#     "wstETH": 1078.7429628216437,
#     "weETH": 18540.338590574072
# }
# {
#     "WETH": 12547.31516929939,
#     "WBTC": 6.984278362738776,
#     "RPL": 22232.464353865336,
#     "cbBTC": 48.98422162623673,
#     "USDS": 491506.578021695,
#     "crvUSD": 405.0340186344844
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 54018052.78653584,
#         "flashloan_start_usd": 53988396.87555603,
#         "flashloan_end": 44704854.55258043,
#         "flashloan_end_usd": 44680311.587431066,
#         "flashloan_profit": -9308085.288124964,
#         "flashloan_profit_usd": -9302975.149301782
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 52736705.405805305,
#         "flashloan_start_usd": 52736705.405805305,
#         "flashloan_end": 46254333.07263267,
#         "flashloan_end_usd": 46254333.07263267,
#         "flashloan_profit": -6482372.333172634,
#         "flashloan_profit_usd": -6482372.333172634
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 94081545.68729535,
#         "flashloan_start_usd": 94081545.68729535,
#         "flashloan_end": 13152113.859896977,
#         "flashloan_end_usd": 13152113.859896977,
#         "flashloan_profit": -80929431.82739837,
#         "flashloan_profit_usd": -80929431.82739837
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 14265.673037825212,
#         "flashloan_start_usd": 53005392.082612984,
#         "flashloan_end": 11081.714771455208,
#         "flashloan_end_usd": 41175108.58767126,
#         "flashloan_profit": -11830283.494941723,
#         "flashloan_profit_usd": -43956483050.97052
#     }
# ]
# ****************************************************************************************************
# {
#     "wstETH": 1101.170892426577,
#     "weETH": 18925.807069249815
# }
# {
#     "WETH": 12808.183894330865,
#     "WBTC": 7.1294871,
#     "RPL": 22694.69508227577,
#     "cbBTC": 50.0026428,
#     "USDS": 501725.3931724315,
#     "crvUSD": 413.45500006436686
# }
# {
#     "wstETH": 1101.170892426577,
#     "weETH": 18925.807069249815
# }
# {
#     "WETH": 12808.183894330865,
#     "WBTC": 7.1294871,
#     "RPL": 22694.69508227577,
#     "cbBTC": 50.0026428,
#     "USDS": 501725.3931724315,
#     "crvUSD": 413.45500006436686
# }
# {
#     "wstETH": 1101.170892426577,
#     "weETH": 18925.807069249815
# }
# {
#     "WETH": 12808.183894330865,
#     "WBTC": 7.1294871,
#     "RPL": 22694.69508227577,
#     "cbBTC": 50.0026428,
#     "USDS": 501725.3931724315,
#     "crvUSD": 413.45500006436686
# }
# {
#     "wstETH": 1101.170892426577,
#     "weETH": 18925.807069249815
# }
# {
#     "WETH": 12808.183894330865,
#     "WBTC": 7.1294871,
#     "RPL": 22694.69508227577,
#     "cbBTC": 50.0026428,
#     "USDS": 501725.3931724315,
#     "crvUSD": 413.45500006436686
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 55351143.875114284,
#         "flashloan_start_usd": 55320756.09712685,
#         "flashloan_end": 45038389.67577427,
#         "flashloan_end_usd": 45013663.599842265,
#         "flashloan_profit": -10307092.497284578,
#         "flashloan_profit_usd": -10301433.903503569
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 53895138.569801964,
#         "flashloan_start_usd": 53895138.569801964,
#         "flashloan_end": 46633371.25888987,
#         "flashloan_end_usd": 46633371.25888987,
#         "flashloan_profit": -7261767.310912095,
#         "flashloan_profit_usd": -7261767.310912095
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1396191395.2116673,
#         "flashloan_start_usd": 1396191395.2116673,
#         "flashloan_end": 13199624.818849068,
#         "flashloan_end_usd": 13199624.818849068,
#         "flashloan_profit": -1382991770.3928182,
#         "flashloan_profit_usd": -1382991770.3928182
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 14563.827006223213,
#         "flashloan_start_usd": 54113209.98605291,
#         "flashloan_end": 10921.616987724725,
#         "flashloan_end_usd": 40580250.863420114,
#         "flashloan_profit": -13532959.1226328,
#         "flashloan_profit_usd": -50282927586.4632
#     }
# ]
# ****************************************************************************************************

# %%
# Sort the dataframe by scale
sorted_df = liquidation_profits_df.sort_values('scale')

# Find the point of maximum profit
max_profit_idx = sorted_df['flashloan_profit_usd'].idxmax()
max_profit_x = sorted_df.loc[max_profit_idx, 'scale']
max_profit_y = sorted_df.loc[max_profit_idx, 'flashloan_profit_usd']

# Find the point where profit turns negative
positive_profits = sorted_df[sorted_df['flashloan_profit_usd'] > 0]
if not positive_profits.empty:
    last_positive_idx = positive_profits.index[-1]
    zero_crossing_x = sorted_df.loc[last_positive_idx, 'scale']
    zero_crossing_y = 0
else:
    zero_crossing_x = zero_crossing_y = None

# Create the plot
plt.figure(figsize=(12, 8))
plt.scatter(sorted_df['scale'], sorted_df['flashloan_profit_usd'], alpha=0.6)
plt.plot(sorted_df['scale'], sorted_df['flashloan_profit_usd'], 'r-', alpha=0.3)

# Add vertical lines and annotations
plt.axvline(x=max_profit_x, color='g', linestyle='--', label='Max Profit')
plt.text(max_profit_x, plt.ylim()[1], f'Max Profit\n({max_profit_x:.4f}, {max_profit_y:.4f})', 
         rotation=90, va='top', ha='left', color='g')

if zero_crossing_x:
    plt.axvline(x=zero_crossing_x, color='r', linestyle='--', label='Profit turns negative')
    plt.text(zero_crossing_x, plt.ylim()[1], f'Profit turns negative\n({zero_crossing_x:.4f})', 
             rotation=90, va='top', ha='right', color='r')

# Adjust y-axis to give more space for labels
plt.ylim(plt.ylim()[0], plt.ylim()[1] * 1.1)

plt.xlabel('Scale')
plt.ylabel('Flashloan Profit USD')
plt.title('Flashloan Profit USD vs Scale')
plt.legend()

# Add grid for better readability
plt.grid(True, linestyle=':', alpha=0.7)

# Use scientific notation for y-axis if numbers are very large
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

# plt.tight_layout()
plt.show()

# Print the exact values
print(f"Maximum profit point: Scale = {max_profit_x:.2f}, Profit = {max_profit_y:.2f}")
if zero_crossing_x:
    print(f"Profit turns negative at: Scale = {zero_crossing_x:.2f}")
else:
    print("Profit does not turn negative within the given data range.")
# Out:
# Maximum profit point: Scale = 6.13, Profit = 20970592399.97
# Profit turns negative at: Scale = 7.96

# %% [markdown]
# ---

# %%
print("Total Liquidatable Collateral:")
print(json.dumps(total_collateral, indent=4))
print("\nTotal Liquidatable Debt:")
print(json.dumps(total_debt, indent=4))
# Out:
# Total Liquidatable Collateral:
# {
#     "wstETH": 110.1170892426577,
#     "weETH": 1892.5807069249815
# }
#
# Total Liquidatable Debt:
# {
#     "WETH": 1280.8183894330864,
#     "WBTC": 0.71294871,
#     "RPL": 2269.469508227577,
#     "cbBTC": 5.00026428,
#     "USDS": 50172.53931724315,
#     "crvUSD": 41.34550000643669
# }
