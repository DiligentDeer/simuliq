# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os
import pandas as pd
import logging
import matplotlib.pyplot as plt
import json
import pickle
from itertools import product
from tqdm import tqdm
import numpy as np

# Add the project root to the system path using the current working directory
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# Import using absolute path from project root
from src.instances.chain_instance import ARBITRUM_DTO, OPTIMISM_DTO, ETHEREUM_DTO, BASE_DTO
from src.instances.aave_instance import AaveArbitrum, AaveOptimism, AaveEthereum, AaveBase
from src.models.token import TokenDTO
from src.models.trade_pair import PairDTO

# %%
from src.scripts.process_stored_data_aave import update_trade_pair_exchange_price, \
    create_liquidatable_user_data_series, create_health_ratio_data_emode, create_asset_mapping, \
    create_health_ratio_data, create_liquidatable_user_data, scale_supply_and_create_liquidations, \
    create_liquidations_v2, scale_price_and_identify_liquidatable_collateral

# %%
chain_object_mapping = {
    'ethereum': [ETHEREUM_DTO, AaveEthereum],
    'arbitrum': [ARBITRUM_DTO, AaveArbitrum],
    'optimism': [OPTIMISM_DTO, AaveOptimism],
    'base': [BASE_DTO, AaveBase]
}

# %%
CHOOSEN_CHAIN = 'ethereum'
AAVE_EMODE_LT = 0.95
ASSET_UNDER_CONSIDERATION = "sfrxETH"
EMODE_SWITCH = False
ASSET_UNDER_CONSIDERATION_CURVE = 'sfrxETH'
SOFT_LIQUIDATION_EFFICIENCY = 0.80
PRICE_DROP_FACTOR = 0.80



if CHOOSEN_CHAIN not in chain_object_mapping:
    print("Invalid chain chosen.")
    exit(1)
else:
    chain_instance, aave_instance = chain_object_mapping[CHOOSEN_CHAIN]

# %%
if not os.path.exists('aave_supported_asset_data.csv'):
    print("File not found. Fetching from RPC.")
    aave_supported_asset_data = aave_instance.get_aave_supported_asset_data()
    print("Saving to file.")
    aave_supported_asset_data.to_csv('aave_supported_asset_data.csv', index=False)
else:
    print("File found. Reading from file.")
    aave_supported_asset_data = pd.read_csv('aave_supported_asset_data.csv')
# Out:
# File found. Reading from file.

# %%
if not os.path.exists('aave_user_position_data.csv'):
    print("File not found. Fetching from RPC.")
    aave_user_position_data = aave_instance.get_user_position_data(aave_supported_asset_data)
    print("Saving to file.")
    aave_user_position_data.to_csv('aave_user_position_data.csv', index=False)
else:
    print("File found. Reading from file.")
    aave_user_position_data = pd.read_csv('aave_user_position_data.csv')


if not EMODE_SWITCH:
    # Filter out 0 from emode column
    aave_user_position_data = aave_user_position_data[aave_user_position_data['emode'] == 0]
# Out:
# File found. Reading from file.

# %%
aave_asset_object_dict = {}

for _, row in tqdm(aave_supported_asset_data.iterrows(), total=len(aave_supported_asset_data), desc="Creating TokenDTO objects"):
    token = TokenDTO(
        address=row['assetAddress'],
        name=row['symbol'],
        symbol=row['symbol'],
        decimals=row['decimals'],
        chain=chain_instance,
        price=row['price'],
    )
    aave_asset_object_dict[row['symbol']] = token
    
frxeth_token = TokenDTO(
        address='0x5E8422345238F34275888049021821E8E08CAa1f',
        name='Frax Ether',
        symbol='frxETH',
        decimals=18,
        chain=ETHEREUM_DTO,
    )
aave_asset_object_dict['frxETH'] = frxeth_token

sfrxeth_token = TokenDTO(
        address='0xac3E018457B222d93114458476f3E3416Abbe38F',
        name='Staked Frax Ether',
        symbol='sfrxETH',
        decimals=18,
        chain=ETHEREUM_DTO,
    )
aave_asset_object_dict['sfrxETH'] = sfrxeth_token
# Out:
# Creating TokenDTO objects: 100%|██████████| 37/37 [00:10<00:00,  3.70it/s]

# %%
# EXCHANGE_RATE = sfrxeth_token.price/frxeth_token.price
# EXCHANGE_RATE

# %%
current_price_mapping = {}
for index, asset in aave_supported_asset_data.iterrows():
    current_price_mapping[asset['symbol']] = asset['price']

# %%
# liquidatable_price_df = scale_price_and_identify_liquidatable_collateral(aave_supported_asset_data, 
#                                                             aave_user_position_data, 
#                                                             current_price_mapping, 
#                                                             AAVE_EMODE_LT, 
#                                                             ASSET_UNDER_CONSIDERATION,
#                                                             0.5, 
#                                                             30)

# %%
# # plot scale and liquidatable_collateral
# plt.figure(figsize=(16, 8))
# plt.plot(liquidatable_price_df['price'], liquidatable_price_df['liquidatable_collateral'], label='Liquidatable Collateral')
# plt.xlabel('Price')
# plt.ylabel('Liquidatable Collateral')
# plt.title('Liquidatable Collateral vs Scale')
# plt.legend()
# plt.grid(True, linestyle=':', alpha=0.7)
# plt.show()

# %% [markdown]
# ## Curve user positions

# %%
from src.instances.curve_mint_market_instance import market_objects_dict

# %%
market = market_objects_dict[ASSET_UNDER_CONSIDERATION_CURVE]
df = market.get_user_position_data()

# %% [markdown]
# ---

# %%
market_params = {
    'base_price': market.base_price,
    'A': market.A,
    'liq_discount': market.liq_discount
}

# %%
output_liq_df, output_raw = market.compute_price_for_max_hard_liq(df, SOFT_LIQUIDATION_EFFICIENCY)

# %%
output_liq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   max_price             10 non-null     float64
#  1   max_collateral_value  10 non-null     float64
#  2   debt                  10 non-null     float64
# dtypes: float64(3)
# memory usage: 372.0 bytes

# %%
# # Convert liquidatable_price_df's cumulative values to absolute values
# liquidatable_price_abs_df = liquidatable_price_df.copy()
# liquidatable_price_abs_df = liquidatable_price_abs_df.sort_values('price', ascending=True)  # Sort ascending first
# liquidatable_price_abs_df = liquidatable_price_abs_df.reset_index(drop=True)  # Reset index after sorting

# # Calculate differences from bottom up
# liquidatable_price_abs_df['liquidatable_collateral_abs'] = liquidatable_price_abs_df['liquidatable_collateral'].diff(-1)
# # Fill the last row with its liquidatable_collateral value since it's the base value
# liquidatable_price_abs_df.loc[liquidatable_price_abs_df.index[-1], 'liquidatable_collateral_abs'] = liquidatable_price_abs_df.loc[liquidatable_price_abs_df.index[-1], 'liquidatable_collateral']

# # Sort back to descending order for the rest of the processing
# liquidatable_price_abs_df = liquidatable_price_abs_df.sort_values('price', ascending=False)
# liquidatable_price_abs_df = liquidatable_price_abs_df.reset_index(drop=True)

# # Create new dataframes with renamed columns for clarity
# df1 = output_liq_df[['max_price', 'max_collateral_value']].rename(
#     columns={'max_price': 'price', 'max_collateral_value': 'liquidatable_collateral_abs'})
# df2 = liquidatable_price_abs_df[['price', 'liquidatable_collateral_abs']]

# # Concatenate the dataframes
# combined_df = pd.concat([df1, df2], ignore_index=True)

# # Sort by price in descending order
# combined_df = combined_df.sort_values('price', ascending=False)

# # Create cumulative sum column
# combined_df['cumulative_liquidatable_collateral'] = combined_df['liquidatable_collateral_abs'].cumsum()

# # Reset index after sorting
# combined_df = combined_df.reset_index(drop=True)

# %%
# # plot scale and liquidatable_collateral
# plt.figure(figsize=(16, 8))
# plt.plot(combined_df['price'], combined_df['cumulative_liquidatable_collateral'], label='Liquidatable Collateral')
# plt.xlabel('Price')
# plt.ylabel('Liquidatable Collateral')
# plt.title('Liquidatable Collateral vs Scale')
# plt.legend()
# plt.grid(True, linestyle=':', alpha=0.7)
# plt.show()

# %%
# # Calculate first and second derivatives
# first_derivative = np.gradient(combined_df['cumulative_liquidatable_collateral'], combined_df['price'])
# second_derivative = np.gradient(first_derivative, combined_df['price'])

# # Create subplots
# fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(16, 24))

# # Plot original function
# ax1.plot(combined_df['price'], combined_df['cumulative_liquidatable_collateral'], 'b-', label='Liquidatable Collateral')
# ax1.set_xlabel('Price')
# ax1.set_ylabel('Liquidatable Collateral')
# ax1.set_title('Original Function')
# ax1.grid(True, linestyle=':', alpha=0.7)
# ax1.legend()

# # Plot first derivative
# ax2.plot(combined_df['price'], first_derivative, 'r-', label='First Derivative')
# ax2.set_xlabel('Price')
# ax2.set_ylabel('Rate of Change')
# ax2.set_title('First Derivative')
# ax2.grid(True, linestyle=':', alpha=0.7)
# ax2.legend()

# # Plot second derivative
# ax3.plot(combined_df['price'], second_derivative, 'g-', label='Second Derivative')
# ax3.set_xlabel('Price')
# ax3.set_ylabel('Rate of Change of Rate of Change')
# ax3.set_title('Second Derivative')
# ax3.grid(True, linestyle=':', alpha=0.7)
# ax3.legend()

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ---

# %%
# Find value from aave_asset_object_dict where the key is the same as ASSET_UNDER_CONSIDERATION
asset_object = next((value for key, value in aave_asset_object_dict.items() if key == ASSET_UNDER_CONSIDERATION), None)

# %%
if asset_object is None:
    print(f"Asset {ASSET_UNDER_CONSIDERATION} not found in aave_asset_object_dict")
    




PRICE_ASSUMPTION = PRICE_DROP_FACTOR*asset_object.price

# %%
PRICE_ASSUMPTION
# Out:
# 3533.624

# %%
def get_curve_liquidation_data(output_liq_df: pd.DataFrame, price_assumption: float) -> tuple[float, float]:
    """
    Get curve liquidation data for the closest price point >= price_assumption.
    Returns (collateral, debt) tuple or (None, None) if no suitable price found.
    """
    # Check if there are any prices >= price_assumption
    valid_rows = output_liq_df[output_liq_df['max_price'] <= price_assumption]
    
    if valid_rows.empty:
        return None, None
    
    # Get the closest row
    closest_row = valid_rows.sort_values('max_price').iloc[-1]
    return {ASSET_UNDER_CONSIDERATION_CURVE:float(closest_row['max_collateral_value'])}, {'crvUSD':float(closest_row['debt'])}

# %%
# Create a copy and sort by max_price in descending order
plot_df = output_liq_df.copy()
plot_df = plot_df.sort_values('max_price', ascending=False)

# Add cumulative sum column
plot_df['cum_collateral'] = plot_df['max_collateral_value'].cumsum()

plot_df['cum_debt'] = plot_df['debt'].cumsum()

# Create the plot
plt.figure(figsize=(12, 8))
plt.plot(plot_df['max_price'], plot_df['cum_collateral'], 
         label='Cumulative Collateral', 
         color='blue',
         linewidth=2)

plt.xlabel('Price')
plt.ylabel('Cumulative Collateral')
plt.title('Cumulative Liquidatable Collateral vs Price')
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
curve_collateral, curve_debt = get_curve_liquidation_data(output_liq_df, PRICE_ASSUMPTION)

# %%
print("Curve Liquidatable Collateral:")
print(json.dumps(curve_collateral, indent=4))
print("\nCurve Liquidatable Debt:")
print(json.dumps(curve_debt, indent=4))
# Out:
# Curve Liquidatable Collateral:
# {
#     "sfrxETH": 2.25
# }
#
# Curve Liquidatable Debt:
# {
#     "crvUSD": 5498.180408006912
# }

# %%
def analyze_liquidatable_positions(
    aave_supported_asset_data: pd.DataFrame,
    aave_user_position_data: pd.DataFrame,
    asset_under_consideration: str,
    price_assumption: float,
    emode_lt: float,
    min_usd_threshold: float = 15000
) -> dict:
    """
    Analyzes liquidatable positions for given asset and price assumption.
    Returns both raw and USD values for liquidatable collateral and debt.
    """
    # Create price mapping
    new_price_mapping = {asset_under_consideration: price_assumption}
    price_mapping = dict(zip(aave_supported_asset_data['symbol'], aave_supported_asset_data['price']))
    
    # Create asset mapping and get health ratios
    asset_mapping = create_asset_mapping(aave_supported_asset_data, new_price_mapping)
    
    # Get health ratio data for both normal and emode
    health_ratio_data_no_emode = create_health_ratio_data(aave_user_position_data, asset_mapping)
    health_ratio_data_emode = create_health_ratio_data_emode(aave_user_position_data, asset_mapping, emode_lt)
    health_ratio_data = pd.concat([health_ratio_data_no_emode, health_ratio_data_emode])
    
    # Get liquidatable positions
    total_liquidatable_collateral, total_liquidatable_debt = create_liquidatable_user_data(health_ratio_data)
    
    # Filter non-zero positions
    total_liquidatable_collateral = {k: v for k, v in total_liquidatable_collateral.items() if v > 0}
    total_liquidatable_debt = {k: v for k, v in total_liquidatable_debt.items() if v > 0}
    
    # Convert to USD
    total_liquidatable_collateral_usd = {
        symbol: quantity * price_mapping.get(symbol, 1)
        for symbol, quantity in total_liquidatable_collateral.items()
    }
    
    total_liquidatable_debt_usd = {
        symbol: quantity * price_mapping.get(symbol, 1)
        for symbol, quantity in total_liquidatable_debt.items()
    }
    
    # Filter by USD threshold
    filtered_collateral_usd = {k: v for k, v in total_liquidatable_collateral_usd.items() if v > min_usd_threshold}
    filtered_debt_usd = {k: v for k, v in total_liquidatable_debt_usd.items() if v > min_usd_threshold}
    
    # Reconstruct raw values from filtered USD values
    filtered_collateral = {
        symbol: float(usd_value) / price_mapping.get(symbol, 1)
        for symbol, usd_value in filtered_collateral_usd.items()
    }
    
    filtered_debt = {
        symbol: float(usd_value) / price_mapping.get(symbol, 1)
        for symbol, usd_value in filtered_debt_usd.items()
    }
    
    return filtered_collateral, filtered_debt

# %%
aave_collateral, aave_debt = analyze_liquidatable_positions(
    aave_supported_asset_data,
    aave_user_position_data,
    ASSET_UNDER_CONSIDERATION,
    PRICE_ASSUMPTION,
    AAVE_EMODE_LT
)

aave_collateral
# Out:
# {}

# %%
def merge_liquidation_data(aave_data: dict, curve_data: dict) -> dict:
    """
    Merge liquidation data from Aave and Curve protocols.
    """
    merged_data = aave_data.copy()  # Start with Aave data
    
    # Merge Curve data
    for token, amount in curve_data.items():
        if token in merged_data:
            merged_data[token] += amount
        else:
            merged_data[token] = amount
    
    return merged_data

# %%
print("Aave Liquidatable Collateral:")
print(json.dumps(aave_collateral, indent=4))
print("\nAave Liquidatable Debt:")
print(json.dumps(aave_debt, indent=4))
# Out:
# Aave Liquidatable Collateral:
# {}
#
# Aave Liquidatable Debt:
# {
#     "RPL": 2269.469508227577
# }

# %%
sfrxeth_token.price
# Out:
# 4417.03

# %%
# Merge collateral data
total_collateral = merge_liquidation_data(aave_collateral, curve_collateral)

# Merge debt data
total_debt = merge_liquidation_data(aave_debt, curve_debt)

print("Total Liquidatable Collateral:")
print(json.dumps(total_collateral, indent=4))
print("\nTotal Liquidatable Debt:")
print(json.dumps(total_debt, indent=4))
# Out:
# Total Liquidatable Collateral:
# {
#     "sfrxETH": 2.25
# }
#
# Total Liquidatable Debt:
# {
#     "RPL": 2269.469508227577,
#     "crvUSD": 5498.180408006912
# }

# %%
EXCHANGE_RATE = asset_object.price/frxeth_token.price

total_collateral['frxETH']=EXCHANGE_RATE*total_collateral['sfrxETH']
total_collateral.pop('sfrxETH', None)


total_debt.pop('RPL', None)
# Out:
# 2269.469508227577

# %%
print("Total Liquidatable Collateral:")
print(json.dumps(total_collateral, indent=4))
print("\nTotal Liquidatable Debt:")
print(json.dumps(total_debt, indent=4))
# Out:
# Total Liquidatable Collateral:
# {
#     "frxETH": 2.501615375708575
# }
#
# Total Liquidatable Debt:
# {
#     "crvUSD": 5498.180408006912
# }

# %%
# Try to load existing trade_pair_hashmap or create new one
try:
    if os.path.exists('trade_pair_hashmap.pkl'):
        with open('trade_pair_hashmap.pkl', 'rb') as f:
            trade_pair_hashmap = pickle.load(f)
        print(f"Loaded existing trade_pair_hashmap with {len(trade_pair_hashmap)} pairs")
    else:
        trade_pair_hashmap = {}
        print("Created new empty trade_pair_hashmap")
except Exception as e:
    print(f"Error loading trade_pair_hashmap: {str(e)}")
    trade_pair_hashmap = {}
    print("Created new empty trade_pair_hashmap due to error")
# Out:
# Loaded existing trade_pair_hashmap with 107 pairs

# %%
# FLASHLOAN_ASSET_SYMBOLS = ['WETH']
FLASHLOAN_ASSET_SYMBOLS = ['USDC', 'USDT', 'DAI', 'WETH']

# Create sets for easier lookup
flashloan_assets = set(FLASHLOAN_ASSET_SYMBOLS)
liquidatable_debt_assets = set(total_debt.keys())
liquidatable_collateral_assets = set(total_collateral.keys())

# Function to create and store PairDTO if it doesn't exist
def create_and_store_pair(sell_token, buy_token, trade_pair_hashmap):
    if sell_token != buy_token:
        key = f"{sell_token}-{buy_token}"
        if key not in trade_pair_hashmap:
            print(f"Creating pair: {sell_token} -> {buy_token}")
            
            try:
                pair_dto = PairDTO(
                    sell_token=aave_asset_object_dict[sell_token],
                    buy_token=aave_asset_object_dict[buy_token],
                    network=ETHEREUM_DTO
                )
                
                # Only add to hashmap if the pair is valid
                if pair_dto.is_valid():
                    trade_pair_hashmap[key] = pair_dto
                    return 1
                else:
                    print(f"Skipping invalid pair: {key}")
                    return 0
                    
            except Exception as e:
                print(f"Error creating pair {key}: {str(e)}")
                return 0
    return 0

# Set 1: Flashloan assets as sell, liquidatable debt as buy
new_pairs_count = 0
total_pairs_set1 = len(flashloan_assets) * len(liquidatable_debt_assets)
for sell_token, buy_token in tqdm(product(flashloan_assets, liquidatable_debt_assets), 
                                  total=total_pairs_set1, 
                                  desc="Creating Set 1 PairDTO objects"):
    new_pairs_count += create_and_store_pair(sell_token, buy_token, trade_pair_hashmap)

# Set 2: Liquidatable collateral as sell, flashloan assets as buy
total_pairs_set2 = len(liquidatable_collateral_assets) * len(flashloan_assets)
for sell_token, buy_token in tqdm(product(liquidatable_collateral_assets, flashloan_assets), 
                                  total=total_pairs_set2, 
                                  desc="Creating Set 2 PairDTO objects"):
    new_pairs_count += create_and_store_pair(sell_token, buy_token, trade_pair_hashmap)

print(f"Total pairs in trade_pair_hashmap: {len(trade_pair_hashmap)}")
print(f"New pairs added: {new_pairs_count}")

# Save updated trade_pair_hashmap to a pickle file
import pickle
with open('trade_pair_hashmap.pkl', 'wb') as f:
    pickle.dump(trade_pair_hashmap, f)
# Out:
# Creating Set 1 PairDTO objects: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Creating Set 2 PairDTO objects:   0%|          | 0/4 [00:00<?, ?it/s]
# Creating pair: frxETH -> USDC
# Creating Set 2 PairDTO objects:  25%|██▌       | 1/4 [00:33<01:40, 33.36s/it]
# Creating pair: frxETH -> DAI
# Creating Set 2 PairDTO objects:  50%|█████     | 2/4 [01:03<01:02, 31.42s/it]
# Creating pair: frxETH -> USDT
# Creating Set 2 PairDTO objects:  75%|███████▌  | 3/4 [01:34<00:31, 31.14s/it]
# Creating pair: frxETH -> WETH
# Creating Set 2 PairDTO objects: 100%|██████████| 4/4 [02:03<00:00, 30.95s/it]
# Total pairs in trade_pair_hashmap: 111
# New pairs added: 4

# %%
# Creata a copy of updated_trade_pair_hashmap
updated_trade_pair_hashmap_copy = trade_pair_hashmap.copy()


pair = updated_trade_pair_hashmap_copy["sfrxETH-WETH"]


def derived_func(x, r, k, c):
    """
    Calculate the value of y based on the given formula.

    Parameters:
        x (float): The value of x in the formula.
        r (float): The value of r in the formula.
        k (float): The value of k in the formula.
        c (float): The value of c in the formula.

    Returns:
        float: The calculated value of y.
    """
    exponent = k * (x ** -c)
    y = (x * r) * (1 - (1/np.exp(exponent)))
    return y

r = pair.exchange_price
k = pair.k
c = pair.c

pair_quotes_df = pair.quotes_df

# Create a new figure with a larger size
plt.figure(figsize=(16, 9))

# Plot scatter points for each dex_aggregator
aggregators = pair_quotes_df['dex_aggregator'].unique()
colors = plt.cm.rainbow(np.linspace(0, 1, len(aggregators)))

sell_token_decimals = pair.sell_token.decimals
buy_token_decimals = pair.buy_token.decimals

for aggregator, color in zip(aggregators, colors):
    df_agg = pair_quotes_df[pair_quotes_df['dex_aggregator'] == aggregator]
    if not df_agg.empty:
        adjusted_sell_amount = df_agg['sell_token_amount'] / (10 ** sell_token_decimals)
        adjusted_buy_amount = df_agg['buy_token_amount'] / (10 ** buy_token_decimals)
        plt.scatter(adjusted_sell_amount, 
                    adjusted_buy_amount, 
                    label=aggregator, color=color, alpha=0.7)
    else:
        print(f"No data for aggregator: {aggregator}")

# Plot the derived function
if not pair_quotes_df.empty:
    x_min = pair_quotes_df['sell_token_amount'].min() / (10 ** sell_token_decimals)
    x_max = pair_quotes_df['sell_token_amount'].max() / (10 ** sell_token_decimals)
    x_range = np.linspace(x_min, x_max, 1000)
    y_derived = derived_func(x_range, r, k, c)
    plt.plot(x_range, y_derived, 'k-', label='Derived Function', linewidth=2)

plt.xlabel(f'Sell Token Amount ({pair.sell_token.symbol})')
plt.ylabel(f'Buy Token Amount ({pair.buy_token.symbol})')
plt.title(f'Sell Token vs Buy Token: {pair.sell_token.symbol} -> {pair.buy_token.symbol}')
plt.legend()
plt.grid(True, alpha=0.3)
# plt.xscale('log')
# plt.yscale('log')
plt.show()

# Print the function parameters
print(f"\nFunction parameters:")
print(f"Exchange Price (r): {r:.6f}")
print(f"k: {k:.6f}")
print(f"c: {c:.6f}")
# Out:
# No data for aggregator: nan
# Function parameters:
# Exchange Price (r): 1.163971
# k: 17383.685495
# c: 1.407607

# %%
def plot_trading_pair_analysis(pair_symbol, trade_pair_hashmap):
    """
    Create a scatter plot of trading data with derived function for a specific trading pair.
    
    Parameters:
        pair_symbol (str): Trading pair symbol (e.g., "WBTC-USDT")
        trade_pair_hashmap (dict): Dictionary containing trading pair data
    
    Returns:
        None (displays plot)
    """
    # Get the trading pair data
    pair = trade_pair_hashmap[pair_symbol]
    
    def derived_func(x, r, k, c):
        """Calculate the value of y based on the given formula."""
        exponent = k * (x ** -c)
        y = (x * r) * (1 - (1/np.exp(exponent)))
        return y

    r = pair.exchange_price
    k = pair.k
    c = pair.c
    pair_quotes_df = pair.quotes_df

    # Create plot
    plt.figure(figsize=(16, 9))

    # Plot scatter points for each dex_aggregator
    aggregators = pair_quotes_df['dex_aggregator'].unique()
    colors = plt.cm.rainbow(np.linspace(0, 1, len(aggregators)))

    sell_token_decimals = pair.sell_token.decimals
    buy_token_decimals = pair.buy_token.decimals

    # Plot data points for each aggregator
    for aggregator, color in zip(aggregators, colors):
        df_agg = pair_quotes_df[pair_quotes_df['dex_aggregator'] == aggregator]
        if not df_agg.empty:
            adjusted_sell_amount = df_agg['sell_token_amount'] / (10 ** sell_token_decimals)
            adjusted_buy_amount = df_agg['buy_token_amount'] / (10 ** buy_token_decimals)
            plt.scatter(adjusted_sell_amount, 
                       adjusted_buy_amount, 
                       label=aggregator, color=color, alpha=0.7)
        else:
            print(f"No data for aggregator: {aggregator}")

    # Plot derived function
    if not pair_quotes_df.empty:
        x_min = pair_quotes_df['sell_token_amount'].min() / (10 ** sell_token_decimals)
        x_max = pair_quotes_df['sell_token_amount'].max() / (10 ** sell_token_decimals)
        x_range = np.linspace(x_min, x_max, 1000)
        y_derived = derived_func(x_range, r, k, c)
        plt.plot(x_range, y_derived, 'k-', label='Derived Function', linewidth=2)

    # Set labels and title
    plt.xlabel(f'Sell Token Amount ({pair.sell_token.symbol})')
    plt.ylabel(f'Buy Token Amount ({pair.buy_token.symbol})')
    plt.title(f'Sell Token vs Buy Token: {pair.sell_token.symbol} -> {pair.buy_token.symbol}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    # Print function parameters
    print(f"\nFunction parameters:")
    print(f"Exchange Price (r): {r:.6f}")
    print(f"k: {k:.6f}")
    print(f"c: {c:.6f}")

# %%
plot_trading_pair_analysis("frxETH-WETH", trade_pair_hashmap)
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_70880\1409966717.py:18: RuntimeWarning: overflow encountered in exp
#   y = (x * r) * (1 - (1/np.exp(exponent)))
# Function parameters:
# Exchange Price (r): 1.069214
# k: 67615.530922
# c: 1.290181

# %%
plot_trading_pair_analysis("sfrxETH-WETH", trade_pair_hashmap)
# Out:
# No data for aggregator: nan
# Function parameters:
# Exchange Price (r): 1.163971
# k: 17383.685495
# c: 1.407607

# %%
# Create price mapping
new_price_mapping = {ASSET_UNDER_CONSIDERATION: PRICE_ASSUMPTION}
price_mapping = dict(zip(aave_supported_asset_data['symbol'], aave_supported_asset_data['price']))

# Create asset mapping and get health ratios
asset_mapping = create_asset_mapping(aave_supported_asset_data, new_price_mapping)

# %%
asset_mapping['frxETH'] = {}
asset_mapping['frxETH']['price'] = frxeth_token.price
asset_mapping['frxETH']['liquidationThreshold'] = 0.9

# %%
def construct_new_price_mapping(asset_mapping, 
                                new_price_mapping,
                                total_liquidatable_collateral,
                                total_liquidatable_debt):
    
    output_mapping = {}
    
    # Extract keys from total_liquidatable_collateral and total_liquidatable_debt and add to separate sets
    liquidatable_collateral_assets = set(total_liquidatable_collateral.keys())
    liquidatable_debt_assets = set(total_liquidatable_debt.keys())
    
    # Join liquidatable_collateral_assets and liquidatable_debt_assets and remove duplicates
    liquidatable_assets = liquidatable_collateral_assets.union(liquidatable_debt_assets)    
    
    for asset in liquidatable_assets:
        if asset in new_price_mapping:
            price = new_price_mapping[asset]
            
            output_mapping[asset] = price
        else:
            price = asset_mapping[asset]['price']
            output_mapping[asset] = price
    
    for asset in FLASHLOAN_ASSET_SYMBOLS:
        price = asset_mapping[asset]['price']
        output_mapping[asset] = price
            
    return output_mapping

# %%
new_broad_price_mapping = construct_new_price_mapping(asset_mapping, new_price_mapping, total_collateral, total_debt)

# %%
new_broad_price_mapping = {}

# %%
updated_trade_pair_hashmap = update_trade_pair_exchange_price(trade_pair_hashmap, new_broad_price_mapping)
# Out:
# Warning: Price not found for USDT or DAI. Skipping update for pair USDT-DAI.
# Warning: Price not found for USDT or USDC. Skipping update for pair USDT-USDC.
# Warning: Price not found for USDT or RPL. Skipping update for pair USDT-RPL.
# Warning: Price not found for USDT or WETH. Skipping update for pair USDT-WETH.
# Warning: Price not found for USDT or PYUSD. Skipping update for pair USDT-PYUSD.
# Warning: Price not found for USDT or crvUSD. Skipping update for pair USDT-crvUSD.
# Warning: Price not found for USDT or cbBTC. Skipping update for pair USDT-cbBTC.
# Warning: Price not found for USDT or UNI. Skipping update for pair USDT-UNI.
# Warning: Price not found for DAI or USDC. Skipping update for pair DAI-USDC.
# Warning: Price not found for DAI or RPL. Skipping update for pair DAI-RPL.
# Warning: Price not found for DAI or USDT. Skipping update for pair DAI-USDT.
# Warning: Price not found for DAI or WETH. Skipping update for pair DAI-WETH.
# Warning: Price not found for DAI or PYUSD. Skipping update for pair DAI-PYUSD.
# Warning: Price not found for DAI or crvUSD. Skipping update for pair DAI-crvUSD.
# Warning: Price not found for DAI or cbBTC. Skipping update for pair DAI-cbBTC.
# Warning: Price not found for DAI or UNI. Skipping update for pair DAI-UNI.
# Warning: Price not found for USDC or DAI. Skipping update for pair USDC-DAI.
# Warning: Price not found for USDC or RPL. Skipping update for pair USDC-RPL.
# Warning: Price not found for USDC or USDT. Skipping update for pair USDC-USDT.
# Warning: Price not found for USDC or WETH. Skipping update for pair USDC-WETH.
# Warning: Price not found for USDC or PYUSD. Skipping update for pair USDC-PYUSD.
# Warning: Price not found for USDC or crvUSD. Skipping update for pair USDC-crvUSD.
# Warning: Price not found for USDC or cbBTC. Skipping update for pair USDC-cbBTC.
# Warning: Price not found for USDC or UNI. Skipping update for pair USDC-UNI.
# Warning: Price not found for WETH or DAI. Skipping update for pair WETH-DAI.
# Warning: Price not found for WETH or USDC. Skipping update for pair WETH-USDC.
# Warning: Price not found for WETH or RPL. Skipping update for pair WETH-RPL.
# Warning: Price not found for WETH or USDT. Skipping update for pair WETH-USDT.
# Warning: Price not found for WETH or PYUSD. Skipping update for pair WETH-PYUSD.
# Warning: Price not found for WETH or crvUSD. Skipping update for pair WETH-crvUSD.
# Warning: Price not found for WETH or cbBTC. Skipping update for pair WETH-cbBTC.
# Warning: Price not found for WETH or UNI. Skipping update for pair WETH-UNI.
# Warning: Price not found for WBTC or USDT. Skipping update for pair WBTC-USDT.
# Warning: Price not found for WBTC or DAI. Skipping update for pair WBTC-DAI.
# Warning: Price not found for WBTC or USDC. Skipping update for pair WBTC-USDC.
# Warning: Price not found for WBTC or WETH. Skipping update for pair WBTC-WETH.
# Warning: Price not found for USDT or USDS. Skipping update for pair USDT-USDS.
# Warning: Price not found for USDT or WBTC. Skipping update for pair USDT-WBTC.
# Warning: Price not found for USDC or USDS. Skipping update for pair USDC-USDS.
# Warning: Price not found for USDC or WBTC. Skipping update for pair USDC-WBTC.
# Warning: Price not found for DAI or USDS. Skipping update for pair DAI-USDS.
# Warning: Price not found for DAI or WBTC. Skipping update for pair DAI-WBTC.
# Warning: Price not found for WETH or USDS. Skipping update for pair WETH-USDS.
# Warning: Price not found for WETH or WBTC. Skipping update for pair WETH-WBTC.
# Warning: Price not found for wstETH or USDT. Skipping update for pair wstETH-USDT.
# Warning: Price not found for wstETH or USDC. Skipping update for pair wstETH-USDC.
# Warning: Price not found for wstETH or DAI. Skipping update for pair wstETH-DAI.
# Warning: Price not found for wstETH or WETH. Skipping update for pair wstETH-WETH.
# Warning: Price not found for weETH or USDT. Skipping update for pair weETH-USDT.
# Warning: Price not found for weETH or USDC. Skipping update for pair weETH-USDC.
# Warning: Price not found for weETH or DAI. Skipping update for pair weETH-DAI.
# Warning: Price not found for weETH or WETH. Skipping update for pair weETH-WETH.
# Warning: Price not found for sfrxETH or USDC. Skipping update for pair sfrxETH-USDC.
# Warning: Price not found for sfrxETH or DAI. Skipping update for pair sfrxETH-DAI.
# Warning: Price not found for sfrxETH or WETH. Skipping update for pair sfrxETH-WETH.
# Warning: Price not found for DAI or GHO. Skipping update for pair DAI-GHO.
# Warning: Price not found for DAI or ENS. Skipping update for pair DAI-ENS.
# Warning: Price not found for DAI or rETH. Skipping update for pair DAI-rETH.
# Warning: Price not found for DAI or wstETH. Skipping update for pair DAI-wstETH.
# Warning: Price not found for USDT or GHO. Skipping update for pair USDT-GHO.
# Warning: Price not found for USDT or ENS. Skipping update for pair USDT-ENS.
# Warning: Price not found for USDT or rETH. Skipping update for pair USDT-rETH.
# Warning: Price not found for USDT or wstETH. Skipping update for pair USDT-wstETH.
# Warning: Price not found for WETH or GHO. Skipping update for pair WETH-GHO.
# Warning: Price not found for WETH or ENS. Skipping update for pair WETH-ENS.
# Warning: Price not found for WETH or rETH. Skipping update for pair WETH-rETH.
# Warning: Price not found for WETH or wstETH. Skipping update for pair WETH-wstETH.
# Warning: Price not found for USDC or GHO. Skipping update for pair USDC-GHO.
# Warning: Price not found for USDC or ENS. Skipping update for pair USDC-ENS.
# Warning: Price not found for USDC or rETH. Skipping update for pair USDC-rETH.
# Warning: Price not found for USDC or wstETH. Skipping update for pair USDC-wstETH.
# Warning: Price not found for LINK or DAI. Skipping update for pair LINK-DAI.
# Warning: Price not found for LINK or USDT. Skipping update for pair LINK-USDT.
# Warning: Price not found for LINK or WETH. Skipping update for pair LINK-WETH.
# Warning: Price not found for LINK or USDC. Skipping update for pair LINK-USDC.
# Warning: Price not found for rETH or DAI. Skipping update for pair rETH-DAI.
# Warning: Price not found for rETH or USDT. Skipping update for pair rETH-USDT.
# Warning: Price not found for rETH or WETH. Skipping update for pair rETH-WETH.
# Warning: Price not found for rETH or USDC. Skipping update for pair rETH-USDC.
# Warning: Price not found for cbBTC or DAI. Skipping update for pair cbBTC-DAI.
# Warning: Price not found for cbBTC or USDT. Skipping update for pair cbBTC-USDT.
# Warning: Price not found for cbBTC or WETH. Skipping update for pair cbBTC-WETH.
# Warning: Price not found for cbBTC or USDC. Skipping update for pair cbBTC-USDC.
# Warning: Price not found for AAVE or DAI. Skipping update for pair AAVE-DAI.
# Warning: Price not found for AAVE or USDT. Skipping update for pair AAVE-USDT.
# Warning: Price not found for AAVE or WETH. Skipping update for pair AAVE-WETH.
# Warning: Price not found for AAVE or USDC. Skipping update for pair AAVE-USDC.
# Warning: Price not found for tBTC or USDT. Skipping update for pair tBTC-USDT.
# Warning: Price not found for tBTC or DAI. Skipping update for pair tBTC-DAI.
# Warning: Price not found for tBTC or USDC. Skipping update for pair tBTC-USDC.
# Warning: Price not found for tBTC or WETH. Skipping update for pair tBTC-WETH.
# Warning: Price not found for USDC or weETH. Skipping update for pair USDC-weETH.
# Warning: Price not found for USDC or CRV. Skipping update for pair USDC-CRV.
# Warning: Price not found for DAI or weETH. Skipping update for pair DAI-weETH.
# Warning: Price not found for DAI or CRV. Skipping update for pair DAI-CRV.
# Warning: Price not found for WETH or weETH. Skipping update for pair WETH-weETH.
# Warning: Price not found for WETH or CRV. Skipping update for pair WETH-CRV.
# Warning: Price not found for USDT or weETH. Skipping update for pair USDT-weETH.
# Warning: Price not found for USDT or CRV. Skipping update for pair USDT-CRV.
# Warning: Price not found for cbETH or USDC. Skipping update for pair cbETH-USDC.
# Warning: Price not found for cbETH or DAI. Skipping update for pair cbETH-DAI.
# Warning: Price not found for cbETH or WETH. Skipping update for pair cbETH-WETH.
# Warning: Price not found for cbETH or USDT. Skipping update for pair cbETH-USDT.
# Warning: Price not found for stETH or USDC. Skipping update for pair stETH-USDC.
# Warning: Price not found for stETH or DAI. Skipping update for pair stETH-DAI.
# Warning: Price not found for stETH or WETH. Skipping update for pair stETH-WETH.
# Warning: Price not found for stETH or USDT. Skipping update for pair stETH-USDT.
# Warning: Price not found for frxETH or USDC. Skipping update for pair frxETH-USDC.
# Warning: Price not found for frxETH or DAI. Skipping update for pair frxETH-DAI.
# Warning: Price not found for frxETH or USDT. Skipping update for pair frxETH-USDT.
# Warning: Price not found for frxETH or WETH. Skipping update for pair frxETH-WETH.

# %%
liquidation_profits_df = scale_supply_and_create_liquidations(updated_trade_pair_hashmap, 
                                                              asset_mapping, 
                                                              total_collateral, 
                                                              total_debt,
                                                              0.02, 
                                                              3000,
                                                              100)
# Out:
# {
#     "frxETH": 0.0500323075141715
# }
# {
#     "crvUSD": 109.96360816013825
# }
# {
#     "frxETH": 0.0500323075141715
# }
# {
#     "crvUSD": 109.96360816013825
# }
# {
#     "frxETH": 0.0500323075141715
# }
# {
#     "crvUSD": 109.96360816013825
# }
# {
#     "frxETH": 0.0500323075141715
# }
# {
#     "crvUSD": 109.96360816013825
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 110.02027052597957,
#         "flashloan_start_usd": 109.9598693974608,
#         "flashloan_end": 0,
#         "flashloan_end_usd": 0.0,
#         "flashloan_profit": -109.9598693974608,
#         "flashloan_profit_usd": -109.8995014291616
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 109.9598693974608,
#         "flashloan_start_usd": 109.9598693974608,
#         "flashloan_end": 0,
#         "flashloan_end_usd": 0.0,
#         "flashloan_profit": -109.9598693974608,
#         "flashloan_profit_usd": -109.9598693974608
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 109.9598693974608,
#         "flashloan_start_usd": 109.9598693974608,
#         "flashloan_end": 0,
#         "flashloan_end_usd": 0.0,
#         "flashloan_profit": -109.9598693974608,
#         "flashloan_profit_usd": -109.9598693974608
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 0.029594188109414873,
#         "flashloan_start_usd": 109.9598693974608,
#         "flashloan_end": 0.05349523225113642,
#         "flashloan_end_usd": 198.76635,
#         "flashloan_profit": 88.80648060253917,
#         "flashloan_profit_usd": 329968.4712619885
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 75.85605346729407
# }
# {
#     "crvUSD": 166720.38038000435
# }
# {
#     "frxETH": 75.85605346729407
# }
# {
#     "crvUSD": 166720.38038000435
# }
# {
#     "frxETH": 75.85605346729407
# }
# {
#     "crvUSD": 166720.38038000435
# }
# {
#     "frxETH": 75.85605346729407
# }
# {
#     "crvUSD": 166720.38038000435
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 166806.2885394796,
#         "flashloan_start_usd": 166714.71188707143,
#         "flashloan_end": 301523.431336531,
#         "flashloan_end_usd": 301357.8949727272,
#         "flashloan_profit": 134643.18308565582,
#         "flashloan_profit_usd": 134569.2639781418
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 166714.71188707143,
#         "flashloan_start_usd": 166714.71188707143,
#         "flashloan_end": 301357.8949727272,
#         "flashloan_end_usd": 301357.8949727272,
#         "flashloan_profit": 134643.1830856558,
#         "flashloan_profit_usd": 134643.1830856558
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 166714.71188707143,
#         "flashloan_start_usd": 166714.71188707143,
#         "flashloan_end": 301357.8949727272,
#         "flashloan_end_usd": 301357.8949727272,
#         "flashloan_profit": 134643.1830856558,
#         "flashloan_profit_usd": 134643.1830856558
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 44.86897421057529,
#         "flashloan_start_usd": 166714.71188707143,
#         "flashloan_end": 81.10633707506135,
#         "flashloan_end_usd": 301357.8949727272,
#         "flashloan_profit": 134643.18308565576,
#         "flashloan_profit_usd": 500278864.6412317
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 151.662074627074
# }
# {
#     "crvUSD": 333330.79715184856
# }
# {
#     "frxETH": 151.662074627074
# }
# {
#     "crvUSD": 333330.79715184856
# }
# {
#     "frxETH": 151.662074627074
# }
# {
#     "crvUSD": 333330.79715184856
# }
# {
#     "frxETH": 151.662074627074
# }
# {
#     "crvUSD": 333330.79715184856
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 333502.5568084332,
#         "flashloan_start_usd": 333319.46390474535,
#         "flashloan_end": 602847.9871403946,
#         "flashloan_end_usd": 602517.0235954545,
#         "flashloan_profit": 269197.55969070917,
#         "flashloan_profit_usd": 269049.77023043897
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 333319.46390474535,
#         "flashloan_start_usd": 333319.46390474535,
#         "flashloan_end": 602517.0235954545,
#         "flashloan_end_usd": 602517.0235954545,
#         "flashloan_profit": 269197.55969070917,
#         "flashloan_profit_usd": 269197.55969070917
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 333319.46390474535,
#         "flashloan_start_usd": 333319.46390474535,
#         "flashloan_end": 602517.0235952267,
#         "flashloan_end_usd": 602517.0235952267,
#         "flashloan_profit": 269197.55969048134,
#         "flashloan_profit_usd": 269197.55969048134
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 89.70835423304116,
#         "flashloan_start_usd": 333319.4639047454,
#         "flashloan_end": 162.15917891787157,
#         "flashloan_end_usd": 602517.0235954544,
#         "flashloan_profit": 269197.55969070905,
#         "flashloan_profit_usd": 1000227760.8112017
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 227.4680957868539
# }
# {
#     "crvUSD": 499941.21392369276
# }
# {
#     "frxETH": 227.4680957868539
# }
# {
#     "crvUSD": 499941.21392369276
# }
# {
#     "frxETH": 227.4680957868539
# }
# {
#     "crvUSD": 499941.21392369276
# }
# {
#     "frxETH": 227.4680957868539
# }
# {
#     "crvUSD": 499941.21392369276
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 500198.82507738686,
#         "flashloan_start_usd": 499924.2159224194,
#         "flashloan_end": 904172.5429442582,
#         "flashloan_end_usd": 903676.1522181818,
#         "flashloan_profit": 403751.9362957624,
#         "flashloan_profit_usd": 403530.27648273605
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 499924.21592241933,
#         "flashloan_start_usd": 499924.21592241933,
#         "flashloan_end": 903676.1522181818,
#         "flashloan_end_usd": 903676.1522181818,
#         "flashloan_profit": 403751.9362957624,
#         "flashloan_profit_usd": 403751.9362957624
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 499924.21592241933,
#         "flashloan_start_usd": 499924.21592241933,
#         "flashloan_end": 903676.1380029434,
#         "flashloan_end_usd": 903676.1380029434,
#         "flashloan_profit": 403751.92208052403,
#         "flashloan_profit_usd": 403751.92208052403
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 134.54773425550704,
#         "flashloan_start_usd": 499924.2159224194,
#         "flashloan_end": 243.21202076068178,
#         "flashloan_end_usd": 903676.1522181816,
#         "flashloan_profit": 403751.93629576225,
#         "flashloan_profit_usd": 1500176656.9811714
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 303.2741169466338
# }
# {
#     "crvUSD": 666551.630695537
# }
# {
#     "frxETH": 303.2741169466338
# }
# {
#     "crvUSD": 666551.630695537
# }
# {
#     "frxETH": 303.2741169466338
# }
# {
#     "crvUSD": 666551.630695537
# }
# {
#     "frxETH": 303.2741169466338
# }
# {
#     "crvUSD": 666551.630695537
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 666895.0933463405,
#         "flashloan_start_usd": 666528.9679400934,
#         "flashloan_end": 1205497.0987481216,
#         "flashloan_end_usd": 1204835.2808409089,
#         "flashloan_profit": 538306.3129008156,
#         "flashloan_profit_usd": 538010.7827350331
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 666528.9679400933,
#         "flashloan_start_usd": 666528.9679400933,
#         "flashloan_end": 1204835.2808409089,
#         "flashloan_end_usd": 1204835.2808409089,
#         "flashloan_profit": 538306.3129008156,
#         "flashloan_profit_usd": 538306.3129008156
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 666528.9679400933,
#         "flashloan_start_usd": 666528.9679400933,
#         "flashloan_end": 1204832.3258938433,
#         "flashloan_end_usd": 1204832.3258938433,
#         "flashloan_profit": 538303.3579537501,
#         "flashloan_profit_usd": 538303.3579537501
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 179.3871142779729,
#         "flashloan_start_usd": 666528.9679400934,
#         "flashloan_end": 324.264862603492,
#         "flashloan_end_usd": 1204835.2808409089,
#         "flashloan_profit": 538306.3129008156,
#         "flashloan_profit_usd": 2000125553.1511416
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 379.08013810641376
# }
# {
#     "crvUSD": 833162.0474673812
# }
# {
#     "frxETH": 379.08013810641376
# }
# {
#     "crvUSD": 833162.0474673812
# }
# {
#     "frxETH": 379.08013810641376
# }
# {
#     "crvUSD": 833162.0474673812
# }
# {
#     "frxETH": 379.08013810641376
# }
# {
#     "crvUSD": 833162.0474673812
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 833591.3616152941,
#         "flashloan_start_usd": 833133.7199577673,
#         "flashloan_end": 1506821.654551911,
#         "flashloan_end_usd": 1505994.4094635618,
#         "flashloan_profit": 672860.6895057946,
#         "flashloan_profit_usd": 672491.2889872559
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 833133.7199577673,
#         "flashloan_start_usd": 833133.7199577673,
#         "flashloan_end": 1505994.4094632752,
#         "flashloan_end_usd": 1505994.4094632752,
#         "flashloan_profit": 672860.6895055079,
#         "flashloan_profit_usd": 672860.6895055079
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 833133.7199577673,
#         "flashloan_start_usd": 833133.7199577673,
#         "flashloan_end": 1505926.1371445009,
#         "flashloan_end_usd": 1505926.1371445009,
#         "flashloan_profit": 672792.4171867336,
#         "flashloan_profit_usd": 672792.4171867336
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 224.2264943004388,
#         "flashloan_start_usd": 833133.7199577674,
#         "flashloan_end": 405.3177044462963,
#         "flashloan_end_usd": 1505994.4094636142,
#         "flashloan_profit": 672860.6895058468,
#         "flashloan_profit_usd": 2500074449.3210297
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 454.88615926619366
# }
# {
#     "crvUSD": 999772.4642392255
# }
# {
#     "frxETH": 454.88615926619366
# }
# {
#     "crvUSD": 999772.4642392255
# }
# {
#     "frxETH": 454.88615926619366
# }
# {
#     "crvUSD": 999772.4642392255
# }
# {
#     "frxETH": 454.88615926619366
# }
# {
#     "crvUSD": 999772.4642392255
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 1000287.6298842478,
#         "flashloan_start_usd": 999738.4719754413,
#         "flashloan_end": 1808146.2102934257,
#         "flashloan_end_usd": 1807153.5380239745,
#         "flashloan_profit": 807415.0660485333,
#         "flashloan_profit_usd": 806971.7951772726
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 999738.4719754413,
#         "flashloan_start_usd": 999738.4719754413,
#         "flashloan_end": 1807153.5378338245,
#         "flashloan_end_usd": 1807153.5378338245,
#         "flashloan_profit": 807415.0658583832,
#         "flashloan_profit_usd": 807415.0658583832
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 999738.4719754413,
#         "flashloan_start_usd": 999738.4719754413,
#         "flashloan_end": 1806612.7668463632,
#         "flashloan_end_usd": 1806612.7668463632,
#         "flashloan_profit": 806874.2948709219,
#         "flashloan_profit_usd": 806874.2948709219
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 269.0658743229047,
#         "flashloan_start_usd": 999738.4719754414,
#         "flashloan_end": 486.3705462834099,
#         "flashloan_end_usd": 1807153.538065175,
#         "flashloan_profit": 807415.0660897336,
#         "flashloan_profit_usd": 3000023345.4123535
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 530.6921804259736
# }
# {
#     "crvUSD": 1166382.8810110698
# }
# {
#     "frxETH": 530.6921804259736
# }
# {
#     "crvUSD": 1166382.8810110698
# }
# {
#     "frxETH": 530.6921804259736
# }
# {
#     "crvUSD": 1166382.8810110698
# }
# {
#     "frxETH": 530.6921804259736
# }
# {
#     "crvUSD": 1166382.8810110698
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 1166983.8981532014,
#         "flashloan_start_usd": 1166343.2239931154,
#         "flashloan_end": 2109470.7600294664,
#         "flashloan_end_usd": 2108312.66058221,
#         "flashloan_profit": 941969.4365890948,
#         "flashloan_profit_usd": 941452.2953684074
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1166343.2239931154,
#         "flashloan_start_usd": 1166343.2239931154,
#         "flashloan_end": 2108312.645378983,
#         "flashloan_end_usd": 2108312.645378983,
#         "flashloan_profit": 941969.4213858678,
#         "flashloan_profit_usd": 941969.4213858678
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1166343.2239931154,
#         "flashloan_start_usd": 1166343.2239931154,
#         "flashloan_end": 2105962.889600634,
#         "flashloan_end_usd": 2105962.889600634,
#         "flashloan_profit": 939619.6656075187,
#         "flashloan_profit_usd": 939619.6656075187
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 313.90525434537057,
#         "flashloan_start_usd": 1166343.2239931154,
#         "flashloan_end": 567.4233875092547,
#         "flashloan_end_usd": 2108312.6643955116,
#         "flashloan_profit": 941969.4404023961,
#         "flashloan_profit_usd": 3499972233.064739
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 606.4982015857535
# }
# {
#     "crvUSD": 1332993.297782914
# }
# {
#     "frxETH": 606.4982015857535
# }
# {
#     "crvUSD": 1332993.297782914
# }
# {
#     "frxETH": 606.4982015857535
# }
# {
#     "crvUSD": 1332993.297782914
# }
# {
#     "frxETH": 606.4982015857535
# }
# {
#     "crvUSD": 1332993.297782914
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 1333680.1664221552,
#         "flashloan_start_usd": 1332947.9760107894,
#         "flashloan_end": 2410795.1543475324,
#         "flashloan_end_usd": 2409471.6278077955,
#         "flashloan_profit": 1076523.6517970061,
#         "flashloan_profit_usd": 1075932.6403121694
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1332947.9760107894,
#         "flashloan_start_usd": 1332947.9760107894,
#         "flashloan_end": 2409471.2803927353,
#         "flashloan_end_usd": 2409471.2803927353,
#         "flashloan_profit": 1076523.3043819459,
#         "flashloan_profit_usd": 1076523.3043819459
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1332947.9760107913,
#         "flashloan_start_usd": 1332947.9760107913,
#         "flashloan_end": 2402419.44962842,
#         "flashloan_end_usd": 2402419.44962842,
#         "flashloan_profit": 1069471.473617629,
#         "flashloan_profit_usd": 1069471.473617629
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 358.74463436783645,
#         "flashloan_start_usd": 1332947.9760107894,
#         "flashloan_end": 648.4762113517438,
#         "flashloan_end_usd": 2409471.726136426,
#         "flashloan_profit": 1076523.7501256363,
#         "flashloan_profit_usd": 3999920880.7293134
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 682.3042227455334
# }
# {
#     "crvUSD": 1499603.714554758
# }
# {
#     "frxETH": 682.3042227455334
# }
# {
#     "crvUSD": 1499603.714554758
# }
# {
#     "frxETH": 682.3042227455334
# }
# {
#     "crvUSD": 1499603.714554758
# }
# {
#     "frxETH": 682.3042227455334
# }
# {
#     "crvUSD": 1499603.714554758
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 1500376.4346911085,
#         "flashloan_start_usd": 1499552.728028463,
#         "flashloan_end": 2712117.8565470944,
#         "flashloan_end_usd": 2710628.90384385,
#         "flashloan_profit": 1211076.175815387,
#         "flashloan_profit_usd": 1210411.2949948641
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1499552.7280284632,
#         "flashloan_start_usd": 1499552.7280284632,
#         "flashloan_end": 2710625.326473449,
#         "flashloan_end_usd": 2710625.326473449,
#         "flashloan_profit": 1211072.5984449857,
#         "flashloan_profit_usd": 1211072.5984449857
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1499552.728028735,
#         "flashloan_start_usd": 1499552.728028735,
#         "flashloan_end": 2694048.827713452,
#         "flashloan_end_usd": 2694048.827713452,
#         "flashloan_profit": 1194496.099684717,
#         "flashloan_profit_usd": 1194496.099684717
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 403.5840143903023,
#         "flashloan_start_usd": 1499552.7280284634,
#         "flashloan_end": 729.528829513982,
#         "flashloan_end_usd": 2710630.0236538565,
#         "flashloan_profit": 1211077.2956253933,
#         "flashloan_profit_usd": 4499866688.852756
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 758.1102439053133
# }
# {
#     "crvUSD": 1666214.1313266023
# }
# {
#     "frxETH": 758.1102439053133
# }
# {
#     "crvUSD": 1666214.1313266023
# }
# {
#     "frxETH": 758.1102439053133
# }
# {
#     "crvUSD": 1666214.1313266023
# }
# {
#     "frxETH": 758.1102439053133
# }
# {
#     "crvUSD": 1666214.1313266023
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 1667072.7029600623,
#         "flashloan_start_usd": 1666157.4800461372,
#         "flashloan_end": 3013430.4188630576,
#         "flashloan_end_usd": 3011776.045563102,
#         "flashloan_profit": 1345618.5655169645,
#         "flashloan_profit_usd": 1344879.8209244956
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1666157.4800461372,
#         "flashloan_start_usd": 1666157.4800461372,
#         "flashloan_end": 3011754.489468443,
#         "flashloan_end_usd": 3011754.489468443,
#         "flashloan_profit": 1345597.009422306,
#         "flashloan_profit_usd": 1345597.009422306
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1666157.480059685,
#         "flashloan_start_usd": 1666157.480059685,
#         "flashloan_end": 2978878.6106160493,
#         "flashloan_end_usd": 2978878.6106160493,
#         "flashloan_profit": 1312721.1305563643,
#         "flashloan_profit_usd": 1312721.1305563643
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 448.4233944127682,
#         "flashloan_start_usd": 1666157.4800461375,
#         "flashloan_end": 810.5801209907333,
#         "flashloan_end_usd": 3011783.391751959,
#         "flashloan_profit": 1345625.9117058218,
#         "flashloan_profit_usd": 4999794181.275035
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 833.9162650650932
# }
# {
#     "crvUSD": 1832824.5480984463
# }
# {
#     "frxETH": 833.9162650650932
# }
# {
#     "crvUSD": 1832824.5480984463
# }
# {
#     "frxETH": 833.9162650650932
# }
# {
#     "crvUSD": 1832824.5480984463
# }
# {
#     "frxETH": 833.9162650650932
# }
# {
#     "crvUSD": 1832824.5480984463
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 1833768.9712290156,
#         "flashloan_start_usd": 1832762.2320638108,
#         "flashloan_end": 3314703.2150995545,
#         "flashloan_end_usd": 3312883.443034465,
#         "flashloan_profit": 1480121.210970654,
#         "flashloan_profit_usd": 1479308.624425831
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1832762.2320638108,
#         "flashloan_start_usd": 1832762.2320638108,
#         "flashloan_end": 3312794.2506252825,
#         "flashloan_end_usd": 3312794.2506252825,
#         "flashloan_profit": 1480032.0185614717,
#         "flashloan_profit_usd": 1480032.0185614717
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1832762.232367439,
#         "flashloan_start_usd": 1832762.232367439,
#         "flashloan_end": 3255158.3700959226,
#         "flashloan_end_usd": 3255158.3700959226,
#         "flashloan_profit": 1422396.1377284836,
#         "flashloan_profit_usd": 1422396.1377284836
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 493.262774435234,
#         "flashloan_start_usd": 1832762.2320638113,
#         "flashloan_end": 891.625859155688,
#         "flashloan_end_usd": 3312916.126020283,
#         "flashloan_profit": 1480153.8939564717,
#         "flashloan_profit_usd": 5499645006.845727
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 909.722286224873
# }
# {
#     "crvUSD": 1999434.9648702906
# }
# {
#     "frxETH": 909.722286224873
# }
# {
#     "crvUSD": 1999434.9648702906
# }
# {
#     "frxETH": 909.722286224873
# }
# {
#     "crvUSD": 1999434.9648702906
# }
# {
#     "frxETH": 909.722286224873
# }
# {
#     "crvUSD": 1999434.9648702906
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 2000465.2394979694,
#         "flashloan_start_usd": 1999366.984081485,
#         "flashloan_end": 3615861.364632338,
#         "flashloan_end_usd": 3613876.2567431545,
#         "flashloan_profit": 1614509.2726616696,
#         "flashloan_profit_usd": 1613622.9070709783
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1999366.9840814848,
#         "flashloan_start_usd": 1999366.9840814848,
#         "flashloan_end": 3613595.349220393,
#         "flashloan_end_usd": 3613595.349220393,
#         "flashloan_profit": 1614228.3651389084,
#         "flashloan_profit_usd": 1614228.3651389084
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1999366.9878818737,
#         "flashloan_start_usd": 1999366.9878818737,
#         "flashloan_end": 3521498.279270375,
#         "flashloan_end_usd": 3521498.279270375,
#         "flashloan_profit": 1522131.2913885014,
#         "flashloan_profit_usd": 1522131.2913885014
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 538.1021544576998,
#         "flashloan_start_usd": 1999366.984081485,
#         "flashloan_end": 972.6546351989107,
#         "flashloan_end_usd": 3613985.8359987205,
#         "flashloan_profit": 1614618.8519172356,
#         "flashloan_profit_usd": 5999261659.995162
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 985.5283073846529
# }
# {
#     "crvUSD": 2166045.381642135
# }
# {
#     "frxETH": 985.5283073846529
# }
# {
#     "crvUSD": 2166045.381642135
# }
# {
#     "frxETH": 985.5283073846529
# }
# {
#     "crvUSD": 2166045.381642135
# }
# {
#     "frxETH": 985.5283073846529
# }
# {
#     "crvUSD": 2166045.381642135
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 2167161.507766923,
#         "flashloan_start_usd": 2165971.736099159,
#         "flashloan_end": 3916756.28104403,
#         "flashloan_end_usd": 3914605.981845737,
#         "flashloan_profit": 1748634.245746578,
#         "flashloan_profit_usd": 1747674.2455456632
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2165971.736099159,
#         "flashloan_start_usd": 2165971.736099159,
#         "flashloan_end": 3913884.401747424,
#         "flashloan_end_usd": 3913884.401747424,
#         "flashloan_profit": 1747912.6656482653,
#         "flashloan_profit_usd": 1747912.6656482653
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2165971.766841046,
#         "flashloan_start_usd": 2165971.766841046,
#         "flashloan_end": 3776907.318994701,
#         "flashloan_end_usd": 3776907.318994701,
#         "flashloan_profit": 1610935.5521536549,
#         "flashloan_profit_usd": 1610935.5521536549
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 582.9415344801657,
#         "flashloan_start_usd": 2165971.736099159,
#         "flashloan_end": 1053.6424159774947,
#         "flashloan_end_usd": 3914903.22438182,
#         "flashloan_profit": 1748931.4882826605,
#         "flashloan_profit_usd": 6498312348.548171
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 1061.334328544433
# }
# {
#     "crvUSD": 2332655.7984139794
# }
# {
#     "frxETH": 1061.334328544433
# }
# {
#     "crvUSD": 2332655.7984139794
# }
# {
#     "frxETH": 1061.334328544433
# }
# {
#     "crvUSD": 2332655.7984139794
# }
# {
#     "frxETH": 1061.334328544433
# }
# {
#     "crvUSD": 2332655.7984139794
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 2333857.776035877,
#         "flashloan_start_usd": 2332576.4881168334,
#         "flashloan_end": 4217142.027616407,
#         "flashloan_end_usd": 4214826.8166432455,
#         "flashloan_profit": 1882250.3285264121,
#         "flashloan_profit_usd": 1881216.973096051
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2332576.4881168334,
#         "flashloan_start_usd": 2332576.4881168334,
#         "flashloan_end": 4213240.750010871,
#         "flashloan_end_usd": 4213240.750010871,
#         "flashloan_profit": 1880664.261894038,
#         "flashloan_profit_usd": 1880664.261894038
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2332576.66602102,
#         "flashloan_start_usd": 2332576.66602102,
#         "flashloan_end": 4020769.3108145194,
#         "flashloan_end_usd": 4020769.3108145194,
#         "flashloan_profit": 1688192.6447934993,
#         "flashloan_profit_usd": 1688192.6447934993
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 627.7809145026317,
#         "flashloan_start_usd": 2332576.4881168334,
#         "flashloan_end": 1134.5471906106072,
#         "flashloan_end_usd": 4215512.195960866,
#         "flashloan_profit": 1882935.7078440327,
#         "flashloan_profit_usd": 6996217086.70821
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 1137.140349704213
# }
# {
#     "crvUSD": 2499266.2151858234
# }
# {
#     "frxETH": 1137.140349704213
# }
# {
#     "crvUSD": 2499266.2151858234
# }
# {
#     "frxETH": 1137.140349704213
# }
# {
#     "crvUSD": 2499266.2151858234
# }
# {
#     "frxETH": 1137.140349704213
# }
# {
#     "crvUSD": 2499266.2151858234
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 2500554.0443048305,
#         "flashloan_start_usd": 2499181.240134507,
#         "flashloan_end": 4516664.018363396,
#         "flashloan_end_usd": 4514184.369817314,
#         "flashloan_profit": 2015003.129682807,
#         "flashloan_profit_usd": 2013896.892964611
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2499181.240134507,
#         "flashloan_start_usd": 2499181.240134507,
#         "flashloan_end": 4511097.253353392,
#         "flashloan_end_usd": 4511097.253353392,
#         "flashloan_profit": 2011916.0132188848,
#         "flashloan_profit_usd": 2011916.0132188848
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2499182.032279355,
#         "flashloan_start_usd": 2499182.032279355,
#         "flashloan_end": 4252788.855879012,
#         "flashloan_end_usd": 4252788.855879012,
#         "flashloan_profit": 1753606.8235996566,
#         "flashloan_profit_usd": 1753606.8235996566
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 672.6202945250975,
#         "flashloan_start_usd": 2499181.240134507,
#         "flashloan_end": 1215.30527124059,
#         "flashloan_end_usd": 4515576.112768824,
#         "flashloan_profit": 2016394.8726343166,
#         "flashloan_profit_usd": 7492096624.81134
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 1212.9463708639928
# }
# {
#     "crvUSD": 2665876.6319576674
# }
# {
#     "frxETH": 1212.9463708639928
# }
# {
#     "crvUSD": 2665876.6319576674
# }
# {
#     "frxETH": 1212.9463708639928
# }
# {
#     "crvUSD": 2665876.6319576674
# }
# {
#     "frxETH": 1212.9463708639928
# }
# {
#     "crvUSD": 2665876.6319576674
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 2667250.312573784,
#         "flashloan_start_usd": 2665785.992152181,
#         "flashloan_end": 4814862.7718595555,
#         "flashloan_end_usd": 4812219.412197804,
#         "flashloan_profit": 2146433.4200456236,
#         "flashloan_profit_usd": 2145255.0280980184
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2665785.9921521824,
#         "flashloan_start_usd": 2665785.9921521824,
#         "flashloan_end": 4806763.4630365325,
#         "flashloan_end_usd": 4806763.4630365325,
#         "flashloan_profit": 2140977.47088435,
#         "flashloan_profit_usd": 2140977.47088435
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2665788.8548933263,
#         "flashloan_start_usd": 2665788.8548933263,
#         "flashloan_end": 4472928.103271057,
#         "flashloan_end_usd": 4472928.103271057,
#         "flashloan_profit": 1807139.2483777306,
#         "flashloan_profit_usd": 1807139.2483777306
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 717.4596745475634,
#         "flashloan_start_usd": 2665785.992152181,
#         "flashloan_end": 1295.8301969109273,
#         "flashloan_end_usd": 4814773.721340273,
#         "flashloan_profit": 2148987.729188091,
#         "flashloan_profit_usd": 7984757316.69398
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 1288.7523920237727
# }
# {
#     "crvUSD": 2832487.048729512
# }
# {
#     "frxETH": 1288.7523920237727
# }
# {
#     "crvUSD": 2832487.048729512
# }
# {
#     "frxETH": 1288.7523920237727
# }
# {
#     "crvUSD": 2832487.048729512
# }
# {
#     "frxETH": 1288.7523920237727
# }
# {
#     "crvUSD": 2832487.048729512
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 2833946.5808427394,
#         "flashloan_start_usd": 2832390.744169857,
#         "flashloan_end": 5111190.793053358,
#         "flashloan_end_usd": 5108384.749307971,
#         "flashloan_profit": 2275994.0051381146,
#         "flashloan_profit_usd": 2274744.484429294
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2832390.7441698965,
#         "flashloan_start_usd": 2832390.7441698965,
#         "flashloan_end": 5099463.71439712,
#         "flashloan_end_usd": 5099463.71439712,
#         "flashloan_profit": 2267072.970227224,
#         "flashloan_profit_usd": 2267072.970227224
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2832399.484018816,
#         "flashloan_start_usd": 2832399.484018816,
#         "flashloan_end": 4681345.893109819,
#         "flashloan_end_usd": 4681345.893109819,
#         "flashloan_profit": 1848946.4090910028,
#         "flashloan_profit_usd": 1848946.4090910028
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 762.2990545700295,
#         "flashloan_start_usd": 2832390.744169856,
#         "flashloan_end": 1376.0143503458676,
#         "flashloan_end_usd": 5112705.160001602,
#         "flashloan_profit": 2280314.415831746,
#         "flashloan_profit_usd": 8472713440.320278
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 1364.5584131835526
# }
# {
#     "crvUSD": 2999097.465501356
# }
# {
#     "frxETH": 1364.5584131835526
# }
# {
#     "crvUSD": 2999097.465501356
# }
# {
#     "frxETH": 1364.5584131835526
# }
# {
#     "crvUSD": 2999097.465501356
# }
# {
#     "frxETH": 1364.5584131835526
# }
# {
#     "crvUSD": 2999097.465501356
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 3000642.849111722,
#         "flashloan_start_usd": 2998995.4961875593,
#         "flashloan_end": 5405038.049515001,
#         "flashloan_end_usd": 5402070.683625816,
#         "flashloan_profit": 2403075.187438257,
#         "flashloan_profit_usd": 2401755.8991603535
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2998995.496188062,
#         "flashloan_start_usd": 2998995.496188062,
#         "flashloan_end": 5388381.18302373,
#         "flashloan_end_usd": 5388381.18302373,
#         "flashloan_profit": 2389385.6868356685,
#         "flashloan_profit_usd": 2389385.6868356685
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2999018.7365883687,
#         "flashloan_start_usd": 2999018.7365883687,
#         "flashloan_end": 4878344.56942417,
#         "flashloan_end_usd": 4878344.56942417,
#         "flashloan_profit": 1879325.8328358014,
#         "flashloan_profit_usd": 1879325.8328358014
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 807.1384345924997,
#         "flashloan_start_usd": 2998995.4961875463,
#         "flashloan_end": 1455.7327534428748,
#         "flashloan_end_usd": 5408906.061364812,
#         "flashloan_profit": 2409910.565177265,
#         "flashloan_profit_usd": 8954239596.866995
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 1440.3644343433325
# }
# {
#     "crvUSD": 3165707.8822732004
# }
# {
#     "frxETH": 1440.3644343433325
# }
# {
#     "crvUSD": 3165707.8822732004
# }
# {
#     "frxETH": 1440.3644343433325
# }
# {
#     "crvUSD": 3165707.8822732004
# }
# {
#     "frxETH": 1440.3644343433325
# }
# {
#     "crvUSD": 3165707.8822732004
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 3167339.1173810055,
#         "flashloan_start_usd": 3165600.2482055635,
#         "flashloan_end": 5695761.001436309,
#         "flashloan_end_usd": 5692634.02864652,
#         "flashloan_profit": 2527033.780440957,
#         "flashloan_profit_usd": 2525646.4388954947
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3165600.248210182,
#         "flashloan_start_usd": 3165600.248210182,
#         "flashloan_end": 5672700.438882539,
#         "flashloan_end_usd": 5672700.438882539,
#         "flashloan_profit": 2507100.190672357,
#         "flashloan_profit_usd": 2507100.190672357
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3165655.367388034,
#         "flashloan_start_usd": 3165655.367388034,
#         "flashloan_end": 5064326.115804977,
#         "flashloan_end_usd": 5064326.115804977,
#         "flashloan_profit": 1898670.748416943,
#         "flashloan_profit_usd": 1898670.748416943
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 851.9778146150176,
#         "flashloan_start_usd": 3165600.248205413,
#         "flashloan_end": 1534.8482060924514,
#         "flashloan_end_usd": 5702866.646075051,
#         "flashloan_profit": 2537266.3978696386,
#         "flashloan_profit_usd": 9427441655.26045
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 1516.1704555031124
# }
# {
#     "crvUSD": 3332318.2990450445
# }
# {
#     "frxETH": 1516.1704555031124
# }
# {
#     "crvUSD": 3332318.2990450445
# }
# {
#     "frxETH": 1516.1704555031124
# }
# {
#     "crvUSD": 3332318.2990450445
# }
# {
#     "frxETH": 1516.1704555031124
# }
# {
#     "crvUSD": 3332318.2990450445
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 3334035.385652772,
#         "flashloan_start_usd": 3332205.0002260488,
#         "flashloan_end": 5982710.984434216,
#         "flashloan_end_usd": 5979426.476103762,
#         "flashloan_profit": 2647221.475877713,
#         "flashloan_profit_usd": 2645768.151287456
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3332205.0002585812,
#         "flashloan_start_usd": 3332205.0002585812,
#         "flashloan_end": 5951643.674540535,
#         "flashloan_end_usd": 5951643.674540535,
#         "flashloan_profit": 2619438.6742819534,
#         "flashloan_profit_usd": 2619438.6742819534
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3332323.7942154664,
#         "flashloan_start_usd": 3332323.7942154664,
#         "flashloan_end": 5239757.378113384,
#         "flashloan_end_usd": 5239757.378113384,
#         "flashloan_profit": 1907433.583897918,
#         "flashloan_profit_usd": 1907433.583897918
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 896.8171946379381,
#         "flashloan_start_usd": 3332205.0002247766,
#         "flashloan_end": 1613.216924324847,
#         "flashloan_end_usd": 5994052.671852158,
#         "flashloan_profit": 2661847.671627382,
#         "flashloan_profit_usd": 9890334590.221985
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 1591.9764766628923
# }
# {
#     "crvUSD": 3498928.7158168885
# }
# {
#     "frxETH": 1591.9764766628923
# }
# {
#     "crvUSD": 3498928.7158168885
# }
# {
#     "frxETH": 1591.9764766628923
# }
# {
#     "crvUSD": 3498928.7158168885
# }
# {
#     "frxETH": 1591.9764766628923
# }
# {
#     "crvUSD": 3498928.7158168885
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 3500731.6539403824,
#         "flashloan_start_usd": 3498809.7522623693,
#         "flashloan_end": 6265259.113463041,
#         "flashloan_end_usd": 6261819.48620975,
#         "flashloan_profit": 2763009.733947381,
#         "flashloan_profit_usd": 2761492.841603444
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3498809.752445618,
#         "flashloan_start_usd": 3498809.752445618,
#         "flashloan_end": 6224498.34023669,
#         "flashloan_end_usd": 6224498.34023669,
#         "flashloan_profit": 2725688.5877910717,
#         "flashloan_profit_usd": 2725688.5877910717
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3499045.904868973,
#         "flashloan_start_usd": 3499045.904868973,
#         "flashloan_end": 5405143.299561195,
#         "flashloan_end_usd": 5405143.299561195,
#         "flashloan_profit": 1906097.3946922221,
#         "flashloan_profit_usd": 1906097.3946922221
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 941.6565746634993,
#         "flashloan_start_usd": 3498809.7522539515,
#         "flashloan_end": 1690.6939963402735,
#         "flashloan_end_usd": 6281925.705861957,
#         "flashloan_profit": 2783115.953608006,
#         "flashloan_profit_usd": 10340917806.06637
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 1667.7824978226722
# }
# {
#     "crvUSD": 3665539.1325887325
# }
# {
#     "frxETH": 1667.7824978226722
# }
# {
#     "crvUSD": 3665539.1325887325
# }
# {
#     "frxETH": 1667.7824978226722
# }
# {
#     "crvUSD": 3665539.1325887325
# }
# {
#     "frxETH": 1667.7824978226722
# }
# {
#     "crvUSD": 3665539.1325887325
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 3667427.9223093754,
#         "flashloan_start_usd": 3665414.5043800273,
#         "flashloan_end": 6542816.221312773,
#         "flashloan_end_usd": 6539224.215207272,
#         "flashloan_profit": 2873809.710827245,
#         "flashloan_profit_usd": 2872231.989296001
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3665414.505234257,
#         "flashloan_start_usd": 3665414.505234257,
#         "flashloan_end": 6490635.835615942,
#         "flashloan_end_usd": 6490635.835615942,
#         "flashloan_profit": 2825221.3303816854,
#         "flashloan_profit_usd": 2825221.3303816854
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3665852.7576965163,
#         "flashloan_start_usd": 3665852.7576965163,
#         "flashloan_end": 5561006.830575878,
#         "flashloan_end_usd": 5561006.830575878,
#         "flashloan_profit": 1895154.0728793615,
#         "flashloan_profit_usd": 1895154.0728793615
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 986.4959547029679,
#         "flashloan_start_usd": 3665414.5043348004,
#         "flashloan_end": 1767.1381978713134,
#         "flashloan_end_usd": 6565961.016628673,
#         "flashloan_profit": 2900546.5122938734,
#         "flashloan_profit_usd": 10777241615.613993
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 1743.5885189824521
# }
# {
#     "crvUSD": 3832149.549360577
# }
# {
#     "frxETH": 1743.5885189824521
# }
# {
#     "crvUSD": 3832149.549360577
# }
# {
#     "frxETH": 1743.5885189824521
# }
# {
#     "crvUSD": 3832149.549360577
# }
# {
#     "frxETH": 1743.5885189824521
# }
# {
#     "crvUSD": 3832149.549360577
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 3834124.1910259165,
#         "flashloan_start_usd": 3832019.256845043,
#         "flashloan_end": 6814847.402138632,
#         "flashloan_end_usd": 6811106.050914858,
#         "flashloan_profit": 2979086.7940698145,
#         "flashloan_profit_usd": 2977451.27541987
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3832019.2602333156,
#         "flashloan_start_usd": 3832019.2602333156,
#         "flashloan_end": 6749522.092567202,
#         "flashloan_end_usd": 6749522.092567202,
#         "flashloan_profit": 2917502.832333886,
#         "flashloan_profit_usd": 2917502.832333886
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3832786.0147636835,
#         "flashloan_start_usd": 3832786.0147636835,
#         "flashloan_end": 5707874.201227764,
#         "flashloan_end_usd": 5707874.201227764,
#         "flashloan_profit": 1875088.1864640801,
#         "flashloan_profit_usd": 1875088.1864640801
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1031.335334803204,
#         "flashloan_start_usd": 3832019.256641437,
#         "flashloan_end": 1842.4159201945763,
#         "flashloan_end_usd": 6845662.168915766,
#         "flashloan_profit": 3013642.912274329,
#         "flashloan_profit_usd": 11197461468.417374
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 1819.394540142232
# }
# {
#     "crvUSD": 3998759.966132421
# }
# {
#     "frxETH": 1819.394540142232
# }
# {
#     "crvUSD": 3998759.966132421
# }
# {
#     "frxETH": 1819.394540142232
# }
# {
#     "crvUSD": 3998759.966132421
# }
# {
#     "frxETH": 1819.394540142232
# }
# {
#     "crvUSD": 3998759.966132421
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 4000820.4610093236,
#         "flashloan_start_usd": 3998624.0105762295,
#         "flashloan_end": 7080881.436122866,
#         "flashloan_end_usd": 7076994.032214435,
#         "flashloan_profit": 3078370.0216382053,
#         "flashloan_profit_usd": 3076679.996496326
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3998624.022274639,
#         "flashloan_start_usd": 3998624.022274639,
#         "flashloan_end": 7000721.462270295,
#         "flashloan_end_usd": 7000721.462270295,
#         "flashloan_profit": 3002097.4399956563,
#         "flashloan_profit_usd": 3002097.4399956563
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3999899.0023875786,
#         "flashloan_start_usd": 3999899.0023875786,
#         "flashloan_end": 5846264.39479613,
#         "flashloan_end_usd": 5846264.39479613,
#         "flashloan_profit": 1846365.3924085516,
#         "flashloan_profit_usd": 1846365.3924085516
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1076.174715129684,
#         "flashloan_start_usd": 3998624.0097887027,
#         "flashloan_end": 1916.4041313982166,
#         "flashloan_end_usd": 7120572.0265819,
#         "flashloan_profit": 3121948.016793197,
#         "flashloan_profit_usd": 11599878831.716635
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 1895.2005613020117
# }
# {
#     "crvUSD": 4165370.382904265
# }
# {
#     "frxETH": 1895.2005613020117
# }
# {
#     "crvUSD": 4165370.382904265
# }
# {
#     "frxETH": 1895.2005613020117
# }
# {
#     "crvUSD": 4165370.382904265
# }
# {
#     "frxETH": 1895.2005613020117
# }
# {
#     "crvUSD": 4165370.382904265
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 4167516.7350214003,
#         "flashloan_start_usd": 4165228.7683338732,
#         "flashloan_end": 7340515.767333298,
#         "flashloan_end_usd": 7336485.824177031,
#         "flashloan_profit": 3171257.0558431586,
#         "flashloan_profit_usd": 3169516.035719501
#     },
#     {
# ...
#         "flashloan_start_usd": 27827642.844555035,
#         "flashloan_end": 8260928.1830648305,
#         "flashloan_end_usd": 8260928.1830648305,
#         "flashloan_profit": -19566714.661490206,
#         "flashloan_profit_usd": -19566714.661490206
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 4299.023024048139,
#         "flashloan_start_usd": 15973406.957923025,
#         "flashloan_end": 3905.6352541313754,
#         "flashloan_end_usd": 14511739.293897998,
#         "flashloan_profit": -1461667.6640250266,
#         "flashloan_profit_usd": -5430957755.774749
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 6974.203979007266
# }
# {
#     "crvUSD": 15328268.306617828
# }
# {
#     "frxETH": 6974.203979007266
# }
# {
#     "crvUSD": 15328268.306617828
# }
# {
#     "frxETH": 6974.203979007266
# }
# {
#     "crvUSD": 15328268.306617828
# }
# {
#     "frxETH": 6974.203979007266
# }
# {
#     "crvUSD": 15328268.306617828
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 16324236.739974119,
#         "flashloan_start_usd": 16315274.734003874,
#         "flashloan_end": 13350751.634872248,
#         "flashloan_end_usd": 13343422.072224703,
#         "flashloan_profit": -2971852.6617791695,
#         "flashloan_profit_usd": -2970221.1146678524
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 16632483.59294757,
#         "flashloan_start_usd": 16632483.59294757,
#         "flashloan_end": 11860342.582342282,
#         "flashloan_end_usd": 11860342.582342282,
#         "flashloan_profit": -4772141.010605289,
#         "flashloan_profit_usd": -4772141.010605289
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 29261481.42328278,
#         "flashloan_start_usd": 29261481.42328278,
#         "flashloan_end": 8265017.048660945,
#         "flashloan_end_usd": 8265017.048660945,
#         "flashloan_profit": -20996464.374621835,
#         "flashloan_profit_usd": -20996464.374621835
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 4360.791220047784,
#         "flashloan_start_usd": 16202912.249297347,
#         "flashloan_end": 3911.3201291743735,
#         "flashloan_end_usd": 14532861.958759012,
#         "flashloan_profit": -1670050.2905383355,
#         "flashloan_profit_usd": -6205222159.021334
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 7050.010000167045
# }
# {
#     "crvUSD": 15494878.72338967
# }
# {
#     "frxETH": 7050.010000167045
# }
# {
#     "crvUSD": 15494878.72338967
# }
# {
#     "frxETH": 7050.010000167045
# }
# {
#     "crvUSD": 15494878.72338967
# }
# {
#     "frxETH": 7050.010000167045
# }
# {
#     "crvUSD": 15494878.72338967
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 16566434.526739182,
#         "flashloan_start_usd": 16557339.554184001,
#         "flashloan_end": 13360062.436706517,
#         "flashloan_end_usd": 13352727.762428764,
#         "flashloan_profit": -3204611.791755237,
#         "flashloan_profit_usd": -3202852.4598815637
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 16897237.539070293,
#         "flashloan_start_usd": 16897237.539070293,
#         "flashloan_end": 11858399.116688952,
#         "flashloan_end_usd": 11858399.116688952,
#         "flashloan_profit": -5038838.422381341,
#         "flashloan_profit_usd": -5038838.422381341
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1190471987.6081963,
#         "flashloan_start_usd": 1190471987.6081963,
#         "flashloan_end": 8268863.863823748,
#         "flashloan_end_usd": 8268863.863823748,
#         "flashloan_profit": -1182203123.7443726,
#         "flashloan_profit_usd": -1182203123.7443726
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 4423.607506027985,
#         "flashloan_start_usd": 16436311.813322524,
#         "flashloan_end": 3916.7361818703475,
#         "flashloan_end_usd": 14552985.789995646,
#         "flashloan_profit": -1883326.023326878,
#         "flashloan_profit_usd": -6997667339.013115
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 7125.816021326826
# }
# {
#     "crvUSD": 15661489.140161516
# }
# {
#     "frxETH": 7125.816021326826
# }
# {
#     "crvUSD": 15661489.140161516
# }
# {
#     "frxETH": 7125.816021326826
# }
# {
#     "crvUSD": 15661489.140161516
# }
# {
#     "frxETH": 7125.816021326826
# }
# {
#     "crvUSD": 15661489.140161516
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 16813363.1752263,
#         "flashloan_start_usd": 16804132.6388431,
#         "flashloan_end": 13368597.802520348,
#         "flashloan_end_usd": 13361258.442326764,
#         "flashloan_profit": -3442874.1965163373,
#         "flashloan_profit_usd": -3440984.05858245
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 17168284.347140923,
#         "flashloan_start_usd": 17168284.347140923,
#         "flashloan_end": 11855911.21765189,
#         "flashloan_end_usd": 11855911.21765189,
#         "flashloan_profit": -5312373.129489033,
#         "flashloan_profit_usd": -5312373.129489033
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 31510077.1823362,
#         "flashloan_start_usd": 31510077.1823362,
#         "flashloan_end": 8272477.735389428,
#         "flashloan_end_usd": 8272477.735389428,
#         "flashloan_profit": -23237599.44694677,
#         "flashloan_profit_usd": -23237599.44694677
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 4487.528842722598,
#         "flashloan_start_usd": 16673817.292731658,
#         "flashloan_end": 3921.892533905637,
#         "flashloan_end_usd": 14572144.680054445,
#         "flashloan_profit": -2101672.6126772123,
#         "flashloan_profit_usd": -7808953742.937324
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 7201.622042486606
# }
# {
#     "crvUSD": 15828099.55693336
# }
# {
#     "frxETH": 7201.622042486606
# }
# {
#     "crvUSD": 15828099.55693336
# }
# {
#     "frxETH": 7201.622042486606
# }
# {
#     "crvUSD": 15828099.55693336
# }
# {
#     "frxETH": 7201.622042486606
# }
# {
#     "crvUSD": 15828099.55693336
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 17065299.727573566,
#         "flashloan_start_usd": 17055930.87802313,
#         "flashloan_end": 13376386.915186435,
#         "flashloan_end_usd": 13369043.278769998,
#         "flashloan_profit": -3686887.5992531306,
#         "flashloan_profit_usd": -3684863.4979611407
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 17446035.110727847,
#         "flashloan_start_usd": 17446035.110727847,
#         "flashloan_end": 11852902.968425624,
#         "flashloan_end_usd": 11852902.968425624,
#         "flashloan_profit": -5593132.142302223,
#         "flashloan_profit_usd": -5593132.142302223
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1550695138.062612,
#         "flashloan_start_usd": 1550695138.062612,
#         "flashloan_end": 8275867.3784291595,
#         "flashloan_end_usd": 8275867.3784291595,
#         "flashloan_profit": -1542419270.684183,
#         "flashloan_profit_usd": -1542419270.684183
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 4552.6160006110895,
#         "flashloan_start_usd": 16915654.485710558,
#         "flashloan_end": 3926.797970694891,
#         "flashloan_end_usd": 14590371.27193423,
#         "flashloan_profit": -2325283.2137763286,
#         "flashloan_profit_usd": -8639799056.275188
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 7277.428063646385
# }
# {
#     "crvUSD": 15994709.973705204
# }
# {
#     "frxETH": 7277.428063646385
# }
# {
#     "crvUSD": 15994709.973705204
# }
# {
#     "frxETH": 7277.428063646385
# }
# {
#     "crvUSD": 15994709.973705204
# }
# {
#     "frxETH": 7277.428063646385
# }
# {
#     "crvUSD": 15994709.973705204
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 17322542.417245787,
#         "flashloan_start_usd": 17313032.34145872,
#         "flashloan_end": 13383457.796032893,
#         "flashloan_end_usd": 13376110.27770287,
#         "flashloan_profit": -3936922.063755848,
#         "flashloan_profit_usd": -3934760.693542846
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 17730938.311108846,
#         "flashloan_start_usd": 17730938.311108846,
#         "flashloan_end": 11849397.392779356,
#         "flashloan_end_usd": 11849397.392779356,
#         "flashloan_profit": -5881540.91832949,
#         "flashloan_profit_usd": -5881540.91832949
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1173170672.5851939,
#         "flashloan_start_usd": 1173170672.5851939,
#         "flashloan_end": 8279041.135872155,
#         "flashloan_end_usd": 8279041.135872155,
#         "flashloan_profit": -1164891631.4493217,
#         "flashloan_profit_usd": -1164891631.4493217
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 4618.933944046168,
#         "flashloan_start_usd": 17162064.7731585,
#         "flashloan_end": 3931.4609547870637,
#         "flashloan_end_usd": 14607697.008997267,
#         "flashloan_profit": -2554367.764161236,
#         "flashloan_profit_usd": -9490983320.839848
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 7353.234084806166
# }
# {
#     "crvUSD": 16161320.39047705
# }
# {
#     "frxETH": 7353.234084806166
# }
# {
#     "crvUSD": 16161320.39047705
# }
# {
#     "frxETH": 7353.234084806166
# }
# {
#     "crvUSD": 16161320.39047705
# }
# {
#     "frxETH": 7353.234084806166
# }
# {
#     "crvUSD": 16161320.39047705
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 17585413.067751557,
#         "flashloan_start_usd": 17575758.67597736,
#         "flashloan_end": 13389837.355247995,
#         "flashloan_end_usd": 13382486.334539963,
#         "flashloan_profit": -4193272.341437397,
#         "flashloan_profit_usd": -4190970.234921948
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 18023484.764467236,
#         "flashloan_start_usd": 18023484.764467236,
#         "flashloan_end": 11845416.505606858,
#         "flashloan_end_usd": 11845416.505606858,
#         "flashloan_profit": -6178068.258860378,
#         "flashloan_profit_usd": -6178068.258860378
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 868575407.5753708,
#         "flashloan_start_usd": 868575407.5753708,
#         "flashloan_end": 8282006.997002547,
#         "flashloan_end_usd": 8282006.997002547,
#         "flashloan_profit": -860293400.5783682,
#         "flashloan_profit_usd": -860293400.5783682
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 4686.552264613815,
#         "flashloan_start_usd": 17413306.728876445,
#         "flashloan_end": 3935.8896387283,
#         "flashloan_end_usd": 14624152.182762485,
#         "flashloan_profit": -2789154.5461139623,
#         "flashloan_profit_usd": -10363354739.995577
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 7429.040105965945
# }
# {
#     "crvUSD": 16327930.807248894
# }
# {
#     "frxETH": 7429.040105965945
# }
# {
#     "crvUSD": 16327930.807248894
# }
# {
#     "frxETH": 7429.040105965945
# }
# {
#     "crvUSD": 16327930.807248894
# }
# {
#     "frxETH": 7429.040105965945
# }
# {
#     "crvUSD": 16327930.807248894
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 17854259.840063017,
#         "flashloan_start_usd": 17844457.85141082,
#         "flashloan_end": 13395551.439974833,
#         "flashloan_end_usd": 13388197.282234287,
#         "flashloan_profit": -4456260.569176535,
#         "flashloan_profit_usd": -4453814.082124057
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 18324213.42002149,
#         "flashloan_start_usd": 18324213.42002149,
#         "flashloan_end": 11840981.360881688,
#         "flashloan_end_usd": 11840981.360881688,
#         "flashloan_profit": -6483232.059139801,
#         "flashloan_profit_usd": -6483232.059139801
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 34065479.76793428,
#         "flashloan_start_usd": 34065479.76793428,
#         "flashloan_end": 8284772.614902901,
#         "flashloan_end_usd": 8284772.614902901,
#         "flashloan_profit": -25780707.153031375,
#         "flashloan_profit_usd": -25780707.153031375
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 4755.545671563543,
#         "flashloan_start_usd": 17669657.941804785,
#         "flashloan_end": 3940.091877400662,
#         "flashloan_end_usd": 14639765.978751125,
#         "flashloan_profit": -3029891.963053659,
#         "flashloan_profit_usd": -11257836279.002546
#     }
# ]
# ****************************************************************************************************
# {
#     "frxETH": 7504.846127125726
# }
# {
#     "crvUSD": 16494541.224020736
# }
# {
#     "frxETH": 7504.846127125726
# }
# {
#     "crvUSD": 16494541.224020736
# }
# {
#     "frxETH": 7504.846127125726
# }
# {
#     "crvUSD": 16494541.224020736
# }
# {
#     "frxETH": 7504.846127125726
# }
# {
#     "crvUSD": 16494541.224020736
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 18129460.392143857,
#         "flashloan_start_usd": 18119507.31838857,
#         "flashloan_end": 13400624.880199958,
#         "flashloan_end_usd": 13393267.937140727,
#         "flashloan_profit": -4726239.381247842,
#         "flashloan_profit_usd": -4723644.675827537
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 18633718.19346222,
#         "flashloan_start_usd": 18633718.19346222,
#         "flashloan_end": 11836112.097156322,
#         "flashloan_end_usd": 11836112.097156322,
#         "flashloan_profit": -6797606.096305897,
#         "flashloan_profit_usd": -6797606.096305897
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 36122532.58151536,
#         "flashloan_start_usd": 36122532.58151536,
#         "flashloan_end": 8287345.322911754,
#         "flashloan_end_usd": 8287345.322911754,
#         "flashloan_profit": -27835187.258603603,
#         "flashloan_profit_usd": -27835187.258603603
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 4825.994548664175,
#         "flashloan_start_usd": 17931417.085071124,
#         "flashloan_end": 3944.0752398555233,
#         "flashloan_end_usd": 14654566.520454785,
#         "flashloan_profit": -3276850.56461634,
#         "flashloan_profit_usd": -12175433189.382828
#     }
# ]
# ****************************************************************************************************

# %%
# Sort the dataframe by scale
sorted_df = liquidation_profits_df.sort_values('scale')

# Find the point of maximum profit
max_profit_idx = sorted_df['flashloan_profit_usd'].idxmax()
max_profit_x = sorted_df.loc[max_profit_idx, 'scale']
max_profit_y = sorted_df.loc[max_profit_idx, 'flashloan_profit_usd']

# Find the point where profit turns negative
positive_profits = sorted_df[sorted_df['flashloan_profit_usd'] > 0]
if not positive_profits.empty:
    last_positive_idx = positive_profits.index[-1]
    zero_crossing_x = sorted_df.loc[last_positive_idx, 'scale']
    zero_crossing_y = 0
else:
    zero_crossing_x = zero_crossing_y = None

# Create the plot
plt.figure(figsize=(12, 8))
plt.scatter(sorted_df['scale'], sorted_df['flashloan_profit_usd'], alpha=0.6)
plt.plot(sorted_df['scale'], sorted_df['flashloan_profit_usd'], 'r-', alpha=0.3)

# Add vertical lines and annotations
plt.axvline(x=max_profit_x, color='g', linestyle='--', label='Max Profit')
plt.text(max_profit_x, plt.ylim()[1], f'Max Profit\n({max_profit_x:.4f}, {max_profit_y:.4f})', 
         rotation=90, va='top', ha='left', color='g')

if zero_crossing_x:
    plt.axvline(x=zero_crossing_x, color='r', linestyle='--', label='Profit turns negative')
    plt.text(zero_crossing_x, plt.ylim()[1], f'Profit turns negative\n({zero_crossing_x:.4f})', 
             rotation=90, va='top', ha='right', color='r')

# Adjust y-axis to give more space for labels
plt.ylim(plt.ylim()[0], plt.ylim()[1] * 1.1)

plt.xlabel('Scale')
plt.ylabel('Flashloan Profit USD')
plt.title('Flashloan Profit USD vs Scale')
plt.legend()

# Add grid for better readability
plt.grid(True, linestyle=':', alpha=0.7)

# Use scientific notation for y-axis if numbers are very large
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

# plt.tight_layout()
plt.show()

# Print the exact values
print(f"Maximum profit point: Scale = {max_profit_x:.2f}, Profit = {max_profit_y:.2f}")
if zero_crossing_x:
    print(f"Profit turns negative at: Scale = {zero_crossing_x:.2f}")
else:
    print("Profit does not turn negative within the given data range.")
# Out:
# Maximum profit point: Scale = 1242.44, Profit = 14929864412.67
# Profit turns negative at: Scale = 2515.15

# %% [markdown]
# ---

# %%
print("Total Liquidatable Collateral:")
print(json.dumps(total_collateral, indent=4))
print("\nTotal Liquidatable Debt:")
print(json.dumps(total_debt, indent=4))
# Out:
# Total Liquidatable Collateral:
# {
#     "frxETH": 2.501615375708575
# }
#
# Total Liquidatable Debt:
# {
#     "crvUSD": 5498.180408006912
# }
