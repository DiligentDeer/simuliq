# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import pandas as pd
import logging
import matplotlib.pyplot as plt
import json
import pickle
from itertools import product
from tqdm import tqdm
import numpy as np

# Add the project root to the system path using the current working directory
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# Import using absolute path from project root
from src.instances.chain_instance import ARBITRUM_DTO, OPTIMISM_DTO, ETHEREUM_DTO, BASE_DTO
from src.instances.aave_instance import AaveArbitrum, AaveOptimism, AaveEthereum, AaveBase
from src.models.token import TokenDTO
from src.models.trade_pair import PairDTO
# Out:
# 2024-12-15 20:17:42,497 INFO src.models.aave_protocol Initialized Aave Protocol DTO for network: Arbitrum
# 2024-12-15 20:17:42,498 INFO src.models.aave_protocol Initialized Aave Protocol DTO for network: Optimism
# 2024-12-15 20:17:42,498 INFO src.models.aave_protocol Initialized Aave Protocol DTO for network: Ethereum
# 2024-12-15 20:17:42,499 INFO src.models.aave_protocol Initialized Aave Protocol DTO for network: Base

# %%
from src.scripts.process_stored_data_aave import update_trade_pair_exchange_price, \
    create_liquidatable_user_data_series, create_health_ratio_data_emode, create_asset_mapping, \
    create_health_ratio_data, create_liquidatable_user_data, scale_supply_and_create_liquidations, \
    create_liquidations_v2, scale_price_and_identify_liquidatable_collateral

# %%
chain_object_mapping = {
    'ethereum': [ETHEREUM_DTO, AaveEthereum],
    'arbitrum': [ARBITRUM_DTO, AaveArbitrum],
    'optimism': [OPTIMISM_DTO, AaveOptimism],
    'base': [BASE_DTO, AaveBase]
}

# %%
CHOOSEN_CHAIN = 'ethereum'
AAVE_EMODE_LT = 0.95
ASSET_UNDER_CONSIDERATION = "tBTC"
EMODE_SWITCH = True
ASSET_UNDER_CONSIDERATION_CURVE = 'tBTC'
SOFT_LIQUIDATION_EFFICIENCY = 0.80
PRICE_DROP_FACTOR = 0.85



if CHOOSEN_CHAIN not in chain_object_mapping:
    print("Invalid chain chosen.")
    exit(1)
else:
    chain_instance, aave_instance = chain_object_mapping[CHOOSEN_CHAIN]

# %%
if not os.path.exists('aave_supported_asset_data.csv'):
    print("File not found. Fetching from RPC.")
    aave_supported_asset_data = aave_instance.get_aave_supported_asset_data()
    print("Saving to file.")
    aave_supported_asset_data.to_csv('aave_supported_asset_data.csv', index=False)
else:
    print("File found. Reading from file.")
    aave_supported_asset_data = pd.read_csv('aave_supported_asset_data.csv')
# Out:
# File found. Reading from file.

# %%
if not os.path.exists('aave_user_position_data.csv'):
    print("File not found. Fetching from RPC.")
    aave_user_position_data = aave_instance.get_user_position_data(aave_supported_asset_data)
    print("Saving to file.")
    aave_user_position_data.to_csv('aave_user_position_data.csv', index=False)
else:
    print("File found. Reading from file.")
    aave_user_position_data = pd.read_csv('aave_user_position_data.csv')


if not EMODE_SWITCH:
    # Filter out 0 from emode column
    aave_user_position_data = aave_user_position_data[aave_user_position_data['emode'] == 0]
# Out:
# File found. Reading from file.

# %%
aave_asset_object_dict = {}

for _, row in tqdm(aave_supported_asset_data.iterrows(), total=len(aave_supported_asset_data), desc="Creating TokenDTO objects"):
    token = TokenDTO(
        address=row['assetAddress'],
        name=row['symbol'],
        symbol=row['symbol'],
        decimals=row['decimals'],
        chain=chain_instance,
        price=row['price'],
    )
    aave_asset_object_dict[row['symbol']] = token
# Out:
# Creating TokenDTO objects: 100%|██████████| 37/37 [00:09<00:00,  3.70it/s]

# %%
current_price_mapping = {}
for index, asset in aave_supported_asset_data.iterrows():
    current_price_mapping[asset['symbol']] = asset['price']

# %%
# liquidatable_price_df = scale_price_and_identify_liquidatable_collateral(aave_supported_asset_data, 
#                                                             aave_user_position_data, 
#                                                             current_price_mapping, 
#                                                             AAVE_EMODE_LT, 
#                                                             ASSET_UNDER_CONSIDERATION,
#                                                             0.5, 
#                                                             30)

# %%
# # plot scale and liquidatable_collateral
# plt.figure(figsize=(16, 8))
# plt.plot(liquidatable_price_df['price'], liquidatable_price_df['liquidatable_collateral'], label='Liquidatable Collateral')
# plt.xlabel('Price')
# plt.ylabel('Liquidatable Collateral')
# plt.title('Liquidatable Collateral vs Scale')
# plt.legend()
# plt.grid(True, linestyle=':', alpha=0.7)
# plt.show()

# %% [markdown]
# ## Curve user positions

# %%
from src.instances.curve_mint_market_instance import market_objects_dict

# %%
market = market_objects_dict[ASSET_UNDER_CONSIDERATION_CURVE]
df = market.get_user_position_data()

# %%
output_liq_df, output_liq_df_raw = market.compute_price_for_max_hard_liq(df, SOFT_LIQUIDATION_EFFICIENCY)

# %%
output_liq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   max_price             10 non-null     float64
#  1   max_collateral_value  10 non-null     float64
#  2   debt                  10 non-null     float64
# dtypes: float64(3)
# memory usage: 372.0 bytes

# %%
# # Convert liquidatable_price_df's cumulative values to absolute values
# liquidatable_price_abs_df = liquidatable_price_df.copy()
# liquidatable_price_abs_df = liquidatable_price_abs_df.sort_values('price', ascending=True)  # Sort ascending first
# liquidatable_price_abs_df = liquidatable_price_abs_df.reset_index(drop=True)  # Reset index after sorting

# # Calculate differences from bottom up
# liquidatable_price_abs_df['liquidatable_collateral_abs'] = liquidatable_price_abs_df['liquidatable_collateral'].diff(-1)
# # Fill the last row with its liquidatable_collateral value since it's the base value
# liquidatable_price_abs_df.loc[liquidatable_price_abs_df.index[-1], 'liquidatable_collateral_abs'] = liquidatable_price_abs_df.loc[liquidatable_price_abs_df.index[-1], 'liquidatable_collateral']

# # Sort back to descending order for the rest of the processing
# liquidatable_price_abs_df = liquidatable_price_abs_df.sort_values('price', ascending=False)
# liquidatable_price_abs_df = liquidatable_price_abs_df.reset_index(drop=True)

# # Create new dataframes with renamed columns for clarity
# df1 = output_liq_df[['max_price', 'max_collateral_value']].rename(
#     columns={'max_price': 'price', 'max_collateral_value': 'liquidatable_collateral_abs'})
# df2 = liquidatable_price_abs_df[['price', 'liquidatable_collateral_abs']]

# # Concatenate the dataframes
# combined_df = pd.concat([df1, df2], ignore_index=True)

# # Sort by price in descending order
# combined_df = combined_df.sort_values('price', ascending=False)

# # Create cumulative sum column
# combined_df['cumulative_liquidatable_collateral'] = combined_df['liquidatable_collateral_abs'].cumsum()

# # Reset index after sorting
# combined_df = combined_df.reset_index(drop=True)

# %%
# # plot scale and liquidatable_collateral
# plt.figure(figsize=(16, 8))
# plt.plot(combined_df['price'], combined_df['cumulative_liquidatable_collateral'], label='Liquidatable Collateral')
# plt.xlabel('Price')
# plt.ylabel('Liquidatable Collateral')
# plt.title('Liquidatable Collateral vs Scale')
# plt.legend()
# plt.grid(True, linestyle=':', alpha=0.7)
# plt.show()

# %%
# # Calculate first and second derivatives
# first_derivative = np.gradient(combined_df['cumulative_liquidatable_collateral'], combined_df['price'])
# second_derivative = np.gradient(first_derivative, combined_df['price'])

# # Create subplots
# fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(16, 24))

# # Plot original function
# ax1.plot(combined_df['price'], combined_df['cumulative_liquidatable_collateral'], 'b-', label='Liquidatable Collateral')
# ax1.set_xlabel('Price')
# ax1.set_ylabel('Liquidatable Collateral')
# ax1.set_title('Original Function')
# ax1.grid(True, linestyle=':', alpha=0.7)
# ax1.legend()

# # Plot first derivative
# ax2.plot(combined_df['price'], first_derivative, 'r-', label='First Derivative')
# ax2.set_xlabel('Price')
# ax2.set_ylabel('Rate of Change')
# ax2.set_title('First Derivative')
# ax2.grid(True, linestyle=':', alpha=0.7)
# ax2.legend()

# # Plot second derivative
# ax3.plot(combined_df['price'], second_derivative, 'g-', label='Second Derivative')
# ax3.set_xlabel('Price')
# ax3.set_ylabel('Rate of Change of Rate of Change')
# ax3.set_title('Second Derivative')
# ax3.grid(True, linestyle=':', alpha=0.7)
# ax3.legend()

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ---

# %%
# Find value from aave_asset_object_dict where the key is the same as ASSET_UNDER_CONSIDERATION
asset_object = next((value for key, value in aave_asset_object_dict.items() if key == ASSET_UNDER_CONSIDERATION), None)

# %%
PRICE_ASSUMPTION = PRICE_DROP_FACTOR*asset_object.price

# %%
asset_object.price
# Out:
# 97148.0

# %%
PRICE_ASSUMPTION
# Out:
# 82575.8

# %%
def get_curve_liquidation_data(output_liq_df: pd.DataFrame, price_assumption: float) -> tuple[float, float]:
    """
    Get curve liquidation data for the closest price point >= price_assumption.
    Returns (collateral, debt) tuple or (None, None) if no suitable price found.
    """
    # Check if there are any prices >= price_assumption
    valid_rows = output_liq_df[output_liq_df['max_price'] <= price_assumption]
    
    if valid_rows.empty:
        return None, None
    
    # Get the closest row
    closest_row = valid_rows.sort_values('max_price').iloc[-1]
    return {ASSET_UNDER_CONSIDERATION_CURVE:float(closest_row['max_collateral_value'])}, {'crvUSD':float(closest_row['debt'])}

# %%
# Create a copy and sort by max_price in descending order
plot_df = output_liq_df.copy()
plot_df = plot_df.sort_values('max_price', ascending=False)

# Add cumulative sum column
plot_df['cum_collateral'] = plot_df['max_collateral_value'].cumsum()

plot_df['cum_debt'] = plot_df['debt'].cumsum()

# Create the plot
plt.figure(figsize=(12, 8))
plt.plot(plot_df['max_price'], plot_df['cum_collateral'], 
         label='Cumulative Collateral', 
         color='blue',
         linewidth=2)

plt.xlabel('Price')
plt.ylabel('Cumulative Collateral')
plt.title('Cumulative Liquidatable Collateral vs Price')
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
curve_collateral, curve_debt = get_curve_liquidation_data(output_liq_df, PRICE_ASSUMPTION)

# %%
print("Curve Liquidatable Collateral:")
print(json.dumps(curve_collateral, indent=4))
print("\nCurve Liquidatable Debt:")
print(json.dumps(curve_debt, indent=4))
# Out:
# Curve Liquidatable Collateral:
# {
#     "tBTC": 0.16800000000000004
# }
#
# Curve Liquidatable Debt:
# {
#     "crvUSD": 9810.846231367708
# }

# %%
def analyze_liquidatable_positions(
    aave_supported_asset_data: pd.DataFrame,
    aave_user_position_data: pd.DataFrame,
    asset_under_consideration: str,
    price_assumption: float,
    emode_lt: float,
    min_usd_threshold: float = 15000
) -> dict:
    """
    Analyzes liquidatable positions for given asset and price assumption.
    Returns both raw and USD values for liquidatable collateral and debt.
    """
    # Create price mapping
    new_price_mapping = {asset_under_consideration: price_assumption}
    price_mapping = dict(zip(aave_supported_asset_data['symbol'], aave_supported_asset_data['price']))
    
    # Create asset mapping and get health ratios
    asset_mapping = create_asset_mapping(aave_supported_asset_data, new_price_mapping)
    
    # Get health ratio data for both normal and emode
    health_ratio_data_no_emode = create_health_ratio_data(aave_user_position_data, asset_mapping)
    health_ratio_data_emode = create_health_ratio_data_emode(aave_user_position_data, asset_mapping, emode_lt)
    health_ratio_data = pd.concat([health_ratio_data_no_emode, health_ratio_data_emode])
    
    # Get liquidatable positions
    total_liquidatable_collateral, total_liquidatable_debt = create_liquidatable_user_data(health_ratio_data)
    
    # Filter non-zero positions
    total_liquidatable_collateral = {k: v for k, v in total_liquidatable_collateral.items() if v > 0}
    total_liquidatable_debt = {k: v for k, v in total_liquidatable_debt.items() if v > 0}
    
    # Convert to USD
    total_liquidatable_collateral_usd = {
        symbol: quantity * price_mapping.get(symbol, 1)
        for symbol, quantity in total_liquidatable_collateral.items()
    }
    
    total_liquidatable_debt_usd = {
        symbol: quantity * price_mapping.get(symbol, 1)
        for symbol, quantity in total_liquidatable_debt.items()
    }
    
    # Filter by USD threshold
    filtered_collateral_usd = {k: v for k, v in total_liquidatable_collateral_usd.items() if v > min_usd_threshold}
    filtered_debt_usd = {k: v for k, v in total_liquidatable_debt_usd.items() if v > min_usd_threshold}
    
    # Reconstruct raw values from filtered USD values
    filtered_collateral = {
        symbol: float(usd_value) / price_mapping.get(symbol, 1)
        for symbol, usd_value in filtered_collateral_usd.items()
    }
    
    filtered_debt = {
        symbol: float(usd_value) / price_mapping.get(symbol, 1)
        for symbol, usd_value in filtered_debt_usd.items()
    }
    
    return filtered_collateral, filtered_debt

# %%
aave_collateral, aave_debt = analyze_liquidatable_positions(
    aave_supported_asset_data,
    aave_user_position_data,
    ASSET_UNDER_CONSIDERATION,
    PRICE_ASSUMPTION,
    AAVE_EMODE_LT
)

aave_collateral
# Out:
# {'WBTC': 0.22579344, 'tBTC': 26.03680177607931}

# %%
print("Aave Liquidatable Collateral:")
print(json.dumps(aave_collateral, indent=4))
print("\nAave Liquidatable Debt:")
print(json.dumps(aave_debt, indent=4))
# Out:
# Aave Liquidatable Collateral:
# {
#     "WBTC": 0.22579344,
#     "tBTC": 26.03680177607931
# }
#
# Aave Liquidatable Debt:
# {
#     "USDC": 1521196.3365820001,
#     "USDT": 23540.857577,
#     "GHO": 251458.95950097466,
#     "RPL": 2269.469508227577
# }

# %%
def merge_liquidation_data(aave_data: dict, curve_data: dict) -> dict:
    """
    Merge liquidation data from Aave and Curve protocols.
    """
    merged_data = aave_data.copy()  # Start with Aave data
    
    # Merge Curve data
    for token, amount in curve_data.items():
        if token in merged_data:
            merged_data[token] += amount
        else:
            merged_data[token] = amount
    
    return merged_data

# %%
# Merge collateral data
total_collateral = merge_liquidation_data(aave_collateral, curve_collateral)

# Merge debt data
total_debt = merge_liquidation_data(aave_debt, curve_debt)

print("Total Liquidatable Collateral:")
print(json.dumps(total_collateral, indent=4))
print("\nTotal Liquidatable Debt:")
print(json.dumps(total_debt, indent=4))
# Out:
# Total Liquidatable Collateral:
# {
#     "WBTC": 0.22579344,
#     "tBTC": 26.20480177607931
# }
#
# Total Liquidatable Debt:
# {
#     "USDC": 1521196.3365820001,
#     "USDT": 23540.857577,
#     "GHO": 251458.95950097466,
#     "RPL": 2269.469508227577,
#     "crvUSD": 9810.846231367708
# }

# %%
# Try to load existing trade_pair_hashmap or create new one
try:
    if os.path.exists('trade_pair_hashmap.pkl'):
        with open('trade_pair_hashmap.pkl', 'rb') as f:
            trade_pair_hashmap = pickle.load(f)
        print(f"Loaded existing trade_pair_hashmap with {len(trade_pair_hashmap)} pairs")
    else:
        trade_pair_hashmap = {}
        print("Created new empty trade_pair_hashmap")
except Exception as e:
    print(f"Error loading trade_pair_hashmap: {str(e)}")
    trade_pair_hashmap = {}
    print("Created new empty trade_pair_hashmap due to error")
# Out:
# Loaded existing trade_pair_hashmap with 107 pairs

# %%
# FLASHLOAN_ASSET_SYMBOLS = ['WETH']
FLASHLOAN_ASSET_SYMBOLS = ['USDC', 'USDT', 'DAI', 'WETH']

# Create sets for easier lookup
flashloan_assets = set(FLASHLOAN_ASSET_SYMBOLS)
liquidatable_debt_assets = set(total_debt.keys())
liquidatable_collateral_assets = set(total_collateral.keys())

# Function to create and store PairDTO if it doesn't exist
def create_and_store_pair(sell_token, buy_token, trade_pair_hashmap):
    if sell_token != buy_token:
        key = f"{sell_token}-{buy_token}"
        if key not in trade_pair_hashmap:
            
            print(f"Creating pair: {sell_token} -> {buy_token}")
            
            pair_dto = PairDTO(
                sell_token=aave_asset_object_dict[sell_token],
                buy_token=aave_asset_object_dict[buy_token],
                network=ETHEREUM_DTO
            )
            trade_pair_hashmap[key] = pair_dto
            return 1
    return 0

# Set 1: Flashloan assets as sell, liquidatable debt as buy
new_pairs_count = 0
total_pairs_set1 = len(flashloan_assets) * len(liquidatable_debt_assets)
for sell_token, buy_token in tqdm(product(flashloan_assets, liquidatable_debt_assets), 
                                  total=total_pairs_set1, 
                                  desc="Creating Set 1 PairDTO objects"):
    new_pairs_count += create_and_store_pair(sell_token, buy_token, trade_pair_hashmap)

# Set 2: Liquidatable collateral as sell, flashloan assets as buy
total_pairs_set2 = len(liquidatable_collateral_assets) * len(flashloan_assets)
for sell_token, buy_token in tqdm(product(liquidatable_collateral_assets, flashloan_assets), 
                                  total=total_pairs_set2, 
                                  desc="Creating Set 2 PairDTO objects"):
    new_pairs_count += create_and_store_pair(sell_token, buy_token, trade_pair_hashmap)

print(f"Total pairs in trade_pair_hashmap: {len(trade_pair_hashmap)}")
print(f"New pairs added: {new_pairs_count}")

# Save updated trade_pair_hashmap to a pickle file
import pickle
with open('trade_pair_hashmap.pkl', 'wb') as f:
    pickle.dump(trade_pair_hashmap, f)
# Out:
# Creating Set 1 PairDTO objects: 100%|██████████| 20/20 [00:00<?, ?it/s]
# Creating Set 2 PairDTO objects: 100%|██████████| 8/8 [00:00<?, ?it/s]
# Total pairs in trade_pair_hashmap: 107
# New pairs added: 0

# %%
# Creata a copy of updated_trade_pair_hashmap
updated_trade_pair_hashmap_copy = trade_pair_hashmap.copy()


pair = updated_trade_pair_hashmap_copy["WBTC-USDT"]


def derived_func(x, r, k, c):
    """
    Calculate the value of y based on the given formula.

    Parameters:
        x (float): The value of x in the formula.
        r (float): The value of r in the formula.
        k (float): The value of k in the formula.
        c (float): The value of c in the formula.

    Returns:
        float: The calculated value of y.
    """
    exponent = k * (x ** -c)
    y = (x * r) * (1 - (1/np.exp(exponent)))
    return y

r = pair.exchange_price
k = pair.k
c = pair.c

pair_quotes_df = pair.quotes_df

# Create a new figure with a larger size
plt.figure(figsize=(16, 9))

# Plot scatter points for each dex_aggregator
aggregators = pair_quotes_df['dex_aggregator'].unique()
colors = plt.cm.rainbow(np.linspace(0, 1, len(aggregators)))

sell_token_decimals = pair.sell_token.decimals
buy_token_decimals = pair.buy_token.decimals

for aggregator, color in zip(aggregators, colors):
    df_agg = pair_quotes_df[pair_quotes_df['dex_aggregator'] == aggregator]
    if not df_agg.empty:
        adjusted_sell_amount = df_agg['sell_token_amount'] / (10 ** sell_token_decimals)
        adjusted_buy_amount = df_agg['buy_token_amount'] / (10 ** buy_token_decimals)
        plt.scatter(adjusted_sell_amount, 
                    adjusted_buy_amount, 
                    label=aggregator, color=color, alpha=0.7)
    else:
        print(f"No data for aggregator: {aggregator}")

# Plot the derived function
if not pair_quotes_df.empty:
    x_min = pair_quotes_df['sell_token_amount'].min() / (10 ** sell_token_decimals)
    x_max = pair_quotes_df['sell_token_amount'].max() / (10 ** sell_token_decimals)
    x_range = np.linspace(x_min, x_max, 1000)
    y_derived = derived_func(x_range, r, k, c)
    plt.plot(x_range, y_derived, 'k-', label='Derived Function', linewidth=2)

plt.xlabel(f'Sell Token Amount ({pair.sell_token.symbol})')
plt.ylabel(f'Buy Token Amount ({pair.buy_token.symbol})')
plt.title(f'Sell Token vs Buy Token: {pair.sell_token.symbol} -> {pair.buy_token.symbol}')
plt.legend()
plt.grid(True, alpha=0.3)
# plt.xscale('log')
# plt.yscale('log')
plt.show()

# Print the function parameters
print(f"\nFunction parameters:")
print(f"Exchange Price (r): {r:.6f}")
print(f"k: {k:.6f}")
print(f"c: {c:.6f}")
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_49916\3834038245.py:22: RuntimeWarning: overflow encountered in exp
#   y = (x * r) * (1 - (1/np.exp(exponent)))
# Function parameters:
# Exchange Price (r): 97028.000000
# k: 18238.618139
# c: 1.238565

# %%
def plot_trading_pair_analysis(pair_symbol, trade_pair_hashmap):
    """
    Create a scatter plot of trading data with derived function for a specific trading pair.
    
    Parameters:
        pair_symbol (str): Trading pair symbol (e.g., "WBTC-USDT")
        trade_pair_hashmap (dict): Dictionary containing trading pair data
    
    Returns:
        None (displays plot)
    """
    # Get the trading pair data
    pair = trade_pair_hashmap[pair_symbol]
    
    def derived_func(x, r, k, c):
        """Calculate the value of y based on the given formula."""
        exponent = k * (x ** -c)
        y = (x * r) * (1 - (1/np.exp(exponent)))
        return y

    r = pair.exchange_price
    k = pair.k
    c = pair.c
    pair_quotes_df = pair.quotes_df

    # Create plot
    plt.figure(figsize=(16, 9))

    # Plot scatter points for each dex_aggregator
    aggregators = pair_quotes_df['dex_aggregator'].unique()
    colors = plt.cm.rainbow(np.linspace(0, 1, len(aggregators)))

    sell_token_decimals = pair.sell_token.decimals
    buy_token_decimals = pair.buy_token.decimals

    # Plot data points for each aggregator
    for aggregator, color in zip(aggregators, colors):
        df_agg = pair_quotes_df[pair_quotes_df['dex_aggregator'] == aggregator]
        if not df_agg.empty:
            adjusted_sell_amount = df_agg['sell_token_amount'] / (10 ** sell_token_decimals)
            adjusted_buy_amount = df_agg['buy_token_amount'] / (10 ** buy_token_decimals)
            plt.scatter(adjusted_sell_amount, 
                       adjusted_buy_amount, 
                       label=aggregator, color=color, alpha=0.7)
        else:
            print(f"No data for aggregator: {aggregator}")

    # Plot derived function
    if not pair_quotes_df.empty:
        x_min = pair_quotes_df['sell_token_amount'].min() / (10 ** sell_token_decimals)
        x_max = pair_quotes_df['sell_token_amount'].max() / (10 ** sell_token_decimals)
        x_range = np.linspace(x_min, x_max, 1000)
        y_derived = derived_func(x_range, r, k, c)
        plt.plot(x_range, y_derived, 'k-', label='Derived Function', linewidth=2)

    # Set labels and title
    plt.xlabel(f'Sell Token Amount ({pair.sell_token.symbol})')
    plt.ylabel(f'Buy Token Amount ({pair.buy_token.symbol})')
    plt.title(f'Sell Token vs Buy Token: {pair.sell_token.symbol} -> {pair.buy_token.symbol}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    # Print function parameters
    print(f"\nFunction parameters:")
    print(f"Exchange Price (r): {r:.6f}")
    print(f"k: {k:.6f}")
    print(f"c: {c:.6f}")

# %%
plot_trading_pair_analysis("tBTC-USDT", trade_pair_hashmap)
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_49916\1409966717.py:18: RuntimeWarning: overflow encountered in exp
#   y = (x * r) * (1 - (1/np.exp(exponent)))
# Function parameters:
# Exchange Price (r): 97148.000000
# k: 34016.248851
# c: 1.740176

# %%
plot_trading_pair_analysis("tBTC-USDT", trade_pair_hashmap)
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_49916\1409966717.py:18: RuntimeWarning: overflow encountered in exp
#   y = (x * r) * (1 - (1/np.exp(exponent)))
# Function parameters:
# Exchange Price (r): 97148.000000
# k: 34016.248851
# c: 1.740176

# %%
# Create price mapping
new_price_mapping = {ASSET_UNDER_CONSIDERATION: PRICE_ASSUMPTION}
price_mapping = dict(zip(aave_supported_asset_data['symbol'], aave_supported_asset_data['price']))

# Create asset mapping and get health ratios
asset_mapping = create_asset_mapping(aave_supported_asset_data, new_price_mapping)

# %%
asset_mapping
# Out:
# {'WETH': {'price': 3715.59, 'liquidationThreshold': 0.83},
#  'wstETH': {'price': 4402.51, 'liquidationThreshold': 0.81},
#  'WBTC': {'price': 97028.0, 'liquidationThreshold': 0.78},
#  'USDC': {'price': 0.999451, 'liquidationThreshold': 0.78},
#  'DAI': {'price': 1.0, 'liquidationThreshold': 0.77},
#  'LINK': {'price': 22.48, 'liquidationThreshold': 0.71},
#  'AAVE': {'price': 256.34, 'liquidationThreshold': 0.73},
#  'cbETH': {'price': 4026.01, 'liquidationThreshold': 0.79},
#  'USDT': {'price': 1.0, 'liquidationThreshold': 0.78},
#  'rETH': {'price': 4164.8, 'liquidationThreshold': 0.79},
#  'LUSD': {'price': 0.998643, 'liquidationThreshold': 0.77},
#  'CRV': {'price': 1.062, 'liquidationThreshold': 0.41},
#  'MKR': {'price': 1881.12, 'liquidationThreshold': 0.7},
#  'SNX': {'price': 2.77, 'liquidationThreshold': 0.65},
#  'BAL': {'price': 3.24, 'liquidationThreshold': 0.59},
#  'UNI': {'price': 15.73, 'liquidationThreshold': 0.74},
#  'LDO': {'price': 1.82, 'liquidationThreshold': 0.5},
#  'ENS': {'price': 33.56461523924799, 'liquidationThreshold': 0.49},
#  '1INCH': {'price': 0.5428575874874582, 'liquidationThreshold': 0.67},
#  'FRAX': {'price': 0.997974, 'liquidationThreshold': 0.72},
#  'GHO': {'price': 0.996103, 'liquidationThreshold': 0.0},
#  'RPL': {'price': 13.79, 'liquidationThreshold': 0.0},
#  'sDAI': {'price': 1.123656307486038, 'liquidationThreshold': 0.78},
#  'STG': {'price': 0.352966, 'liquidationThreshold': 0.37},
#  'KNC': {'price': 0.674338, 'liquidationThreshold': 0.37},
#  'FXS': {'price': 3.62, 'liquidationThreshold': 0.42},
#  'crvUSD': {'price': 0.999966, 'liquidationThreshold': 0.0},
#  'PYUSD': {'price': 1.002, 'liquidationThreshold': 0.78},
#  'weETH': {'price': 3902.8007906347, 'liquidationThreshold': 0.75},
#  'osETH': {'price': 3838.8633311288622, 'liquidationThreshold': 0.75},
#  'USDe': {'price': 1.001, 'liquidationThreshold': 0.75},
#  'ETHx': {'price': 3872.24, 'liquidationThreshold': 0.77},
#  'sUSDe': {'price': 1.1329020379301624, 'liquidationThreshold': 0.75},
#  'tBTC': {'price': 82575.8, 'liquidationThreshold': 0.78},
#  'cbBTC': {'price': 97440.0, 'liquidationThreshold': 0.78},
#  'USDS': {'price': 1.0, 'liquidationThreshold': 0.78},
#  'rsETH': {'price': 3833.35, 'liquidationThreshold': 0.75}}

# %%
def construct_new_price_mapping(asset_mapping, 
                                new_price_mapping,
                                total_liquidatable_collateral,
                                total_liquidatable_debt):
    
    output_mapping = {}
    
    # Extract keys from total_liquidatable_collateral and total_liquidatable_debt and add to separate sets
    liquidatable_collateral_assets = set(total_liquidatable_collateral.keys())
    liquidatable_debt_assets = set(total_liquidatable_debt.keys())
    
    # Join liquidatable_collateral_assets and liquidatable_debt_assets and remove duplicates
    liquidatable_assets = liquidatable_collateral_assets.union(liquidatable_debt_assets)    
    
    for asset in liquidatable_assets:
        if asset in new_price_mapping:
            price = new_price_mapping[asset]
            
            output_mapping[asset] = price
        else:
            price = asset_mapping[asset]['price']
            output_mapping[asset] = price
    
    for asset in FLASHLOAN_ASSET_SYMBOLS:
        price = asset_mapping[asset]['price']
        output_mapping[asset] = price
            
    return output_mapping

# %%
new_broad_price_mapping = construct_new_price_mapping(asset_mapping, new_price_mapping, total_collateral, total_debt)

# %%
updated_trade_pair_hashmap = update_trade_pair_exchange_price(trade_pair_hashmap, new_broad_price_mapping)
# Out:
# Warning: Price not found for USDT or PYUSD. Skipping update for pair USDT-PYUSD.
# Warning: Price not found for USDT or cbBTC. Skipping update for pair USDT-cbBTC.
# Warning: Price not found for USDT or UNI. Skipping update for pair USDT-UNI.
# Warning: Price not found for DAI or PYUSD. Skipping update for pair DAI-PYUSD.
# Warning: Price not found for DAI or cbBTC. Skipping update for pair DAI-cbBTC.
# Warning: Price not found for DAI or UNI. Skipping update for pair DAI-UNI.
# Warning: Price not found for USDC or PYUSD. Skipping update for pair USDC-PYUSD.
# Warning: Price not found for USDC or cbBTC. Skipping update for pair USDC-cbBTC.
# Warning: Price not found for USDC or UNI. Skipping update for pair USDC-UNI.
# Warning: Price not found for WETH or PYUSD. Skipping update for pair WETH-PYUSD.
# Warning: Price not found for WETH or cbBTC. Skipping update for pair WETH-cbBTC.
# Warning: Price not found for WETH or UNI. Skipping update for pair WETH-UNI.
# Warning: Price not found for USDT or USDS. Skipping update for pair USDT-USDS.
# Warning: Price not found for USDC or USDS. Skipping update for pair USDC-USDS.
# Warning: Price not found for DAI or USDS. Skipping update for pair DAI-USDS.
# Warning: Price not found for WETH or USDS. Skipping update for pair WETH-USDS.
# Warning: Price not found for wstETH or USDT. Skipping update for pair wstETH-USDT.
# Warning: Price not found for wstETH or USDC. Skipping update for pair wstETH-USDC.
# Warning: Price not found for wstETH or DAI. Skipping update for pair wstETH-DAI.
# Warning: Price not found for wstETH or WETH. Skipping update for pair wstETH-WETH.
# Warning: Price not found for weETH or USDT. Skipping update for pair weETH-USDT.
# Warning: Price not found for weETH or USDC. Skipping update for pair weETH-USDC.
# Warning: Price not found for weETH or DAI. Skipping update for pair weETH-DAI.
# Warning: Price not found for weETH or WETH. Skipping update for pair weETH-WETH.
# Warning: Price not found for sfrxETH or USDC. Skipping update for pair sfrxETH-USDC.
# Warning: Price not found for sfrxETH or DAI. Skipping update for pair sfrxETH-DAI.
# Warning: Price not found for sfrxETH or WETH. Skipping update for pair sfrxETH-WETH.
# Warning: Price not found for DAI or ENS. Skipping update for pair DAI-ENS.
# Warning: Price not found for DAI or rETH. Skipping update for pair DAI-rETH.
# Warning: Price not found for DAI or wstETH. Skipping update for pair DAI-wstETH.
# Warning: Price not found for USDT or ENS. Skipping update for pair USDT-ENS.
# Warning: Price not found for USDT or rETH. Skipping update for pair USDT-rETH.
# Warning: Price not found for USDT or wstETH. Skipping update for pair USDT-wstETH.
# Warning: Price not found for WETH or ENS. Skipping update for pair WETH-ENS.
# Warning: Price not found for WETH or rETH. Skipping update for pair WETH-rETH.
# Warning: Price not found for WETH or wstETH. Skipping update for pair WETH-wstETH.
# Warning: Price not found for USDC or ENS. Skipping update for pair USDC-ENS.
# Warning: Price not found for USDC or rETH. Skipping update for pair USDC-rETH.
# Warning: Price not found for USDC or wstETH. Skipping update for pair USDC-wstETH.
# Warning: Price not found for LINK or DAI. Skipping update for pair LINK-DAI.
# Warning: Price not found for LINK or USDT. Skipping update for pair LINK-USDT.
# Warning: Price not found for LINK or WETH. Skipping update for pair LINK-WETH.
# Warning: Price not found for LINK or USDC. Skipping update for pair LINK-USDC.
# Warning: Price not found for rETH or DAI. Skipping update for pair rETH-DAI.
# Warning: Price not found for rETH or USDT. Skipping update for pair rETH-USDT.
# Warning: Price not found for rETH or WETH. Skipping update for pair rETH-WETH.
# Warning: Price not found for rETH or USDC. Skipping update for pair rETH-USDC.
# Warning: Price not found for cbBTC or DAI. Skipping update for pair cbBTC-DAI.
# Warning: Price not found for cbBTC or USDT. Skipping update for pair cbBTC-USDT.
# Warning: Price not found for cbBTC or WETH. Skipping update for pair cbBTC-WETH.
# Warning: Price not found for cbBTC or USDC. Skipping update for pair cbBTC-USDC.
# Warning: Price not found for AAVE or DAI. Skipping update for pair AAVE-DAI.
# Warning: Price not found for AAVE or USDT. Skipping update for pair AAVE-USDT.
# Warning: Price not found for AAVE or WETH. Skipping update for pair AAVE-WETH.
# Warning: Price not found for AAVE or USDC. Skipping update for pair AAVE-USDC.
# Warning: Price not found for USDC or weETH. Skipping update for pair USDC-weETH.
# Warning: Price not found for USDC or CRV. Skipping update for pair USDC-CRV.
# Warning: Price not found for DAI or weETH. Skipping update for pair DAI-weETH.
# Warning: Price not found for DAI or CRV. Skipping update for pair DAI-CRV.
# Warning: Price not found for WETH or weETH. Skipping update for pair WETH-weETH.
# Warning: Price not found for WETH or CRV. Skipping update for pair WETH-CRV.
# Warning: Price not found for USDT or weETH. Skipping update for pair USDT-weETH.
# Warning: Price not found for USDT or CRV. Skipping update for pair USDT-CRV.
# Warning: Price not found for cbETH or USDC. Skipping update for pair cbETH-USDC.
# Warning: Price not found for cbETH or DAI. Skipping update for pair cbETH-DAI.
# Warning: Price not found for cbETH or WETH. Skipping update for pair cbETH-WETH.
# Warning: Price not found for cbETH or USDT. Skipping update for pair cbETH-USDT.
# Warning: Price not found for stETH or USDC. Skipping update for pair stETH-USDC.
# Warning: Price not found for stETH or DAI. Skipping update for pair stETH-DAI.
# Warning: Price not found for stETH or WETH. Skipping update for pair stETH-WETH.
# Warning: Price not found for stETH or USDT. Skipping update for pair stETH-USDT.

# %%
liquidation_profits_df = scale_supply_and_create_liquidations(updated_trade_pair_hashmap, 
                                                              asset_mapping, 
                                                              total_collateral, 
                                                              total_debt,
                                                              0.02, 
                                                              12,
                                                              50)
# Out:
# {
#     "WBTC": 0.0045158688,
#     "tBTC": 0.5240960355215862
# }
# {
#     "USDC": 30423.926731640004,
#     "USDT": 470.81715154,
#     "GHO": 5029.179190019493,
#     "RPL": 45.38939016455154,
#     "crvUSD": 196.21692462735416
# }
# {
#     "WBTC": 0.0045158688,
#     "tBTC": 0.5240960355215862
# }
# {
#     "USDC": 30423.926731640004,
#     "USDT": 470.81715154,
#     "GHO": 5029.179190019493,
#     "RPL": 45.38939016455154,
#     "crvUSD": 196.21692462735416
# }
# {
#     "WBTC": 0.0045158688,
#     "tBTC": 0.5240960355215862
# }
# {
#     "USDC": 30423.926731640004,
#     "USDT": 470.81715154,
#     "GHO": 5029.179190019493,
#     "RPL": 45.38939016455154,
#     "crvUSD": 196.21692462735416
# }
# {
#     "WBTC": 0.0045158688,
#     "tBTC": 0.5240960355215862
# }
# {
#     "USDC": 30423.926731640004,
#     "USDT": 470.81715154,
#     "GHO": 5029.179190019493,
#     "RPL": 45.38939016455154,
#     "crvUSD": 196.21692462735416
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 36729.9162937867,
#         "flashloan_start_usd": 36709.75156974141,
#         "flashloan_end": 0,
#         "flashloan_end_usd": 0.0,
#         "flashloan_profit": -36709.75156974141,
#         "flashloan_profit_usd": -36689.59791612963
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 36709.751569741406,
#         "flashloan_start_usd": 36709.751569741406,
#         "flashloan_end": 0,
#         "flashloan_end_usd": 0.0,
#         "flashloan_profit": -36709.751569741406,
#         "flashloan_profit_usd": -36709.751569741406
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 36709.751569741406,
#         "flashloan_start_usd": 36709.751569741406,
#         "flashloan_end": 0,
#         "flashloan_end_usd": 0.0,
#         "flashloan_profit": -36709.751569741406,
#         "flashloan_profit_usd": -36709.751569741406
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 9.879925279630262,
#         "flashloan_start_usd": 36709.751569741406,
#         "flashloan_end": 11.765511029997874,
#         "flashloan_end_usd": 43715.815127949805,
#         "flashloan_profit": 7006.063558208397,
#         "flashloan_profit_usd": 26031659.69624354
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.059720060865306124,
#     "tBTC": 6.930902673836488
# }
# {
#     "USDC": 402340.9086143413,
#     "USDT": 6226.316616284082,
#     "GHO": 66508.32888025779,
#     "RPL": 600.2515270740694,
#     "crvUSD": 2594.868717520929
# }
# {
#     "WBTC": 0.059720060865306124,
#     "tBTC": 6.930902673836488
# }
# {
#     "USDC": 402340.9086143413,
#     "USDT": 6226.316616284082,
#     "GHO": 66508.32888025779,
#     "RPL": 600.2515270740694,
#     "crvUSD": 2594.868717520929
# }
# {
#     "WBTC": 0.059720060865306124,
#     "tBTC": 6.930902673836488
# }
# {
#     "USDC": 402340.9086143413,
#     "USDT": 6226.316616284082,
#     "GHO": 66508.32888025779,
#     "RPL": 600.2515270740694,
#     "crvUSD": 2594.868717520929
# }
# {
#     "WBTC": 0.059720060865306124,
#     "tBTC": 6.930902673836488
# }
# {
#     "USDC": 402340.9086143413,
#     "USDT": 6226.316616284082,
#     "GHO": 66508.32888025779,
#     "RPL": 600.2515270740694,
#     "crvUSD": 2594.868717520929
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 485734.40332723653,
#         "flashloan_start_usd": 485467.7351398099,
#         "flashloan_end": 0,
#         "flashloan_end_usd": 0.0,
#         "flashloan_profit": -485467.7351398099,
#         "flashloan_profit_usd": -485201.2133532181
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 485467.7351595975,
#         "flashloan_start_usd": 485467.7351595975,
#         "flashloan_end": 0,
#         "flashloan_end_usd": 0.0,
#         "flashloan_profit": -485467.7351595975,
#         "flashloan_profit_usd": -485467.7351595975
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 485467.73746758694,
#         "flashloan_start_usd": 485467.73746758694,
#         "flashloan_end": 0,
#         "flashloan_end_usd": 0.0,
#         "flashloan_profit": -485467.73746758694,
#         "flashloan_profit_usd": -485467.73746758694
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 130.65697104664687,
#         "flashloan_start_usd": 485467.7350512107,
#         "flashloan_end": 155.5928805599719,
#         "flashloan_end_usd": 578119.351079826,
#         "flashloan_profit": 92651.6160286153,
#         "flashloan_profit_usd": 344255417.9997628
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.11492425293061224,
#     "tBTC": 13.337709312151388
# }
# {
#     "USDC": 774257.8904970426,
#     "USDT": 11981.816081028162,
#     "GHO": 127987.47857049608,
#     "RPL": 1155.1136639835872,
#     "crvUSD": 4993.5205104145025
# }
# {
#     "WBTC": 0.11492425293061224,
#     "tBTC": 13.337709312151388
# }
# {
#     "USDC": 774257.8904970426,
#     "USDT": 11981.816081028162,
#     "GHO": 127987.47857049608,
#     "RPL": 1155.1136639835872,
#     "crvUSD": 4993.5205104145025
# }
# {
#     "WBTC": 0.11492425293061224,
#     "tBTC": 13.337709312151388
# }
# {
#     "USDC": 774257.8904970426,
#     "USDT": 11981.816081028162,
#     "GHO": 127987.47857049608,
#     "RPL": 1155.1136639835872,
#     "crvUSD": 4993.5205104145025
# }
# {
#     "WBTC": 0.11492425293061224,
#     "tBTC": 13.337709312151388
# }
# {
#     "USDC": 774257.8904970426,
#     "USDT": 11981.816081028162,
#     "GHO": 127987.47857049608,
#     "RPL": 1155.1136639835872,
#     "crvUSD": 4993.5205104145025
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 934739.0489038801,
#         "flashloan_start_usd": 934225.8771660319,
#         "flashloan_end": 1101977.0019924445,
#         "flashloan_end_usd": 1101372.0166183505,
#         "flashloan_profit": 167146.13945231884,
#         "flashloan_profit_usd": 167054.3762217595
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 934225.8955810941,
#         "flashloan_start_usd": 934225.8955810941,
#         "flashloan_end": 1101372.0166183505,
#         "flashloan_end_usd": 1101372.0166183505,
#         "flashloan_profit": 167146.12103725644,
#         "flashloan_profit_usd": 167146.12103725644
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 934226.8954714399,
#         "flashloan_start_usd": 934226.8954714399,
#         "flashloan_end": 292688.1515433404,
#         "flashloan_end_usd": 292688.1515433404,
#         "flashloan_profit": -641538.7439280995,
#         "flashloan_profit_usd": -641538.7439280995
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 251.434025886116,
#         "flashloan_start_usd": 934225.7522421938,
#         "flashloan_end": 299.4202500899459,
#         "flashloan_end_usd": 1112522.887031702,
#         "flashloan_profit": 178297.13478950842,
#         "flashloan_profit_usd": 662479051.0525496
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.1701284449959184,
#     "tBTC": 19.74451595046629
# }
# {
#     "USDC": 1146174.8723797437,
#     "USDT": 17737.315545772246,
#     "GHO": 189466.62826073437,
#     "RPL": 1709.975800893105,
#     "crvUSD": 7392.172303308078
# }
# {
#     "WBTC": 0.1701284449959184,
#     "tBTC": 19.74451595046629
# }
# {
#     "USDC": 1146174.8723797437,
#     "USDT": 17737.315545772246,
#     "GHO": 189466.62826073437,
#     "RPL": 1709.975800893105,
#     "crvUSD": 7392.172303308078
# }
# {
#     "WBTC": 0.1701284449959184,
#     "tBTC": 19.74451595046629
# }
# {
#     "USDC": 1146174.8723797437,
#     "USDT": 17737.315545772246,
#     "GHO": 189466.62826073437,
#     "RPL": 1709.975800893105,
#     "crvUSD": 7392.172303308078
# }
# {
#     "WBTC": 0.1701284449959184,
#     "tBTC": 19.74451595046629
# }
# {
#     "USDC": 1146174.8723797437,
#     "USDT": 17737.315545772246,
#     "GHO": 189466.62826073437,
#     "RPL": 1709.975800893105,
#     "crvUSD": 7392.172303308078
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 1383747.1908586002,
#         "flashloan_start_usd": 1382987.5136508187,
#         "flashloan_end": 1631314.7920433462,
#         "flashloan_end_usd": 1630419.2002225143,
#         "flashloan_profit": 247431.68657169558,
#         "flashloan_profit_usd": 247295.8465757677
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1382987.8274016208,
#         "flashloan_start_usd": 1382987.8274016208,
#         "flashloan_end": 1630419.2002225143,
#         "flashloan_end_usd": 1630419.2002225143,
#         "flashloan_profit": 247431.37282089354,
#         "flashloan_profit_usd": 247431.37282089354
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1383000.8805397395,
#         "flashloan_start_usd": 1383000.8805397395,
#         "flashloan_end": 294435.4060574267,
#         "flashloan_end_usd": 294435.4060574267,
#         "flashloan_profit": -1088565.4744823128,
#         "flashloan_profit_usd": -1088565.4744823128
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 372.21140084841045,
#         "flashloan_start_usd": 1382984.9588783453,
#         "flashloan_end": 443.24761961991993,
#         "flashloan_end_usd": 1646926.4229835784,
#         "flashloan_profit": 263941.4641052329,
#         "flashloan_profit_usd": 980698264.6147624
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.22533263706122453,
#     "tBTC": 26.15132258878119
# }
# {
#     "USDC": 1518091.8542624451,
#     "USDT": 23492.815010516326,
#     "GHO": 250945.7779509727,
#     "RPL": 2264.837937802623,
#     "crvUSD": 9790.824096201653
# }
# {
#     "WBTC": 0.22533263706122453,
#     "tBTC": 26.15132258878119
# }
# {
#     "USDC": 1518091.8542624451,
#     "USDT": 23492.815010516326,
#     "GHO": 250945.7779509727,
#     "RPL": 2264.837937802623,
#     "crvUSD": 9790.824096201653
# }
# {
#     "WBTC": 0.22533263706122453,
#     "tBTC": 26.15132258878119
# }
# {
#     "USDC": 1518091.8542624451,
#     "USDT": 23492.815010516326,
#     "GHO": 250945.7779509727,
#     "RPL": 2264.837937802623,
#     "crvUSD": 9790.824096201653
# }
# {
#     "WBTC": 0.22533263706122453,
#     "tBTC": 26.15132258878119
# }
# {
#     "USDC": 1518091.8542624451,
#     "USDT": 23492.815010516326,
#     "GHO": 250945.7779509727,
#     "RPL": 2264.837937802623,
#     "crvUSD": 9790.824096201653
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 1832772.257828228,
#         "flashloan_start_usd": 1831766.0658586803,
#         "flashloan_end": 2160652.5820942475,
#         "flashloan_end_usd": 2159466.3838266777,
#         "flashloan_profit": 327700.31796799746,
#         "flashloan_profit_usd": 327520.410493433
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1831767.6401492367,
#         "flashloan_start_usd": 1831767.6401492367,
#         "flashloan_end": 2159466.383826678,
#         "flashloan_end_usd": 2159466.383826678,
#         "flashloan_profit": 327698.7436774415,
#         "flashloan_profit_usd": 327698.7436774415
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 1831825.204399817,
#         "flashloan_start_usd": 1831825.204399817,
#         "flashloan_end": 292298.0826549842,
#         "flashloan_end_usd": 292298.0826549842,
#         "flashloan_profit": -1539527.1217448327,
#         "flashloan_profit_usd": -1539527.1217448327
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 492.9908474157192,
#         "flashloan_start_usd": 1831751.8627493721,
#         "flashloan_end": 587.0749891498939,
#         "flashloan_end_usd": 2181329.9589354545,
#         "flashloan_profit": 349578.09618608217,
#         "flashloan_profit_usd": 1298888878.408045
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.2805368291265306,
#     "tBTC": 32.55812922709609
# }
# {
#     "USDC": 1890008.8361451463,
#     "USDT": 29248.314475260406,
#     "GHO": 312424.92764121096,
#     "RPL": 2819.7000747121406,
#     "crvUSD": 12189.475889095227
# }
# {
#     "WBTC": 0.2805368291265306,
#     "tBTC": 32.55812922709609
# }
# {
#     "USDC": 1890008.8361451463,
#     "USDT": 29248.314475260406,
#     "GHO": 312424.92764121096,
#     "RPL": 2819.7000747121406,
#     "crvUSD": 12189.475889095227
# }
# {
#     "WBTC": 0.2805368291265306,
#     "tBTC": 32.55812922709609
# }
# {
#     "USDC": 1890008.8361451463,
#     "USDT": 29248.314475260406,
#     "GHO": 312424.92764121096,
#     "RPL": 2819.7000747121406,
#     "crvUSD": 12189.475889095227
# }
# {
#     "WBTC": 0.2805368291265306,
#     "tBTC": 32.55812922709609
# }
# {
#     "USDC": 1890008.8361451463,
#     "USDT": 29248.314475260406,
#     "GHO": 312424.92764121096,
#     "RPL": 2819.7000747121406,
#     "crvUSD": 12189.475889095227
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 2281837.684629666,
#         "flashloan_start_usd": 2280584.9557408043,
#         "flashloan_end": 2689990.372145149,
#         "flashloan_end_usd": 2688513.5674308413,
#         "flashloan_profit": 407928.6116900368,
#         "flashloan_profit_usd": 407704.65888221894
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2280589.529824501,
#         "flashloan_start_usd": 2280589.529824501,
#         "flashloan_end": 2688513.5674308413,
#         "flashloan_end_usd": 2688513.5674308413,
#         "flashloan_profit": 407924.03760634037,
#         "flashloan_profit_usd": 407924.03760634037
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2280745.2452750895,
#         "flashloan_start_usd": 2280745.2452750895,
#         "flashloan_end": 289227.94232673664,
#         "flashloan_end_usd": 289227.94232673664,
#         "flashloan_profit": -1991517.3029483529,
#         "flashloan_profit_usd": -1991517.3029483529
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 613.7762567972136,
#         "flashloan_start_usd": 2280540.9219931588,
#         "flashloan_end": 730.9023586798679,
#         "flashloan_end_usd": 2715733.4948873306,
#         "flashloan_profit": 435192.5728941716,
#         "flashloan_profit_usd": 1616997171.919855
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.33574102119183674,
#     "tBTC": 38.96493586541099
# }
# {
#     "USDC": 2261925.8180278474,
#     "USDT": 35003.81394000449,
#     "GHO": 373904.07733144925,
#     "RPL": 3374.5622116216587,
#     "crvUSD": 14588.1276819888
# }
# {
#     "WBTC": 0.33574102119183674,
#     "tBTC": 38.96493586541099
# }
# {
#     "USDC": 2261925.8180278474,
#     "USDT": 35003.81394000449,
#     "GHO": 373904.07733144925,
#     "RPL": 3374.5622116216587,
#     "crvUSD": 14588.1276819888
# }
# {
#     "WBTC": 0.33574102119183674,
#     "tBTC": 38.96493586541099
# }
# {
#     "USDC": 2261925.8180278474,
#     "USDT": 35003.81394000449,
#     "GHO": 373904.07733144925,
#     "RPL": 3374.5622116216587,
#     "crvUSD": 14588.1276819888
# }
# {
#     "WBTC": 0.33574102119183674,
#     "tBTC": 38.96493586541099
# }
# {
#     "USDC": 2261925.8180278474,
#     "USDT": 35003.81394000449,
#     "GHO": 373904.07733144925,
#     "RPL": 3374.5622116216587,
#     "crvUSD": 14588.1276819888
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 2730971.088914671,
#         "flashloan_start_usd": 2729471.785786857,
#         "flashloan_end": 3219328.162196051,
#         "flashloan_end_usd": 3217560.7510350053,
#         "flashloan_profit": 488088.9652481484,
#         "flashloan_profit_usd": 487821.0044062272
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2729481.6854734817,
#         "flashloan_start_usd": 2729481.6854734817,
#         "flashloan_end": 3217560.7510350053,
#         "flashloan_end_usd": 3217560.7510350053,
#         "flashloan_profit": 488079.06556152366,
#         "flashloan_profit_usd": 488079.06556152366
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 2729804.8108498645,
#         "flashloan_start_usd": 2729804.8108498645,
#         "flashloan_end": 286019.65921655676,
#         "flashloan_end_usd": 286019.65921655676,
#         "flashloan_profit": -2443785.151633308,
#         "flashloan_profit_usd": -2443785.151633308
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 734.5730237810268,
#         "flashloan_start_usd": 2729372.1814305456,
#         "flashloan_end": 874.729728209842,
#         "flashloan_end_usd": 3250137.030839207,
#         "flashloan_profit": 520764.8494086617,
#         "flashloan_profit_usd": 1934948666.8143294
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.3909452132571429,
#     "tBTC": 45.3717425037259
# }
# {
#     "USDC": 2633842.799910549,
#     "USDT": 40759.31340474857,
#     "GHO": 435383.22702168755,
#     "RPL": 3929.4243485311767,
#     "crvUSD": 16986.779474882376
# }
# {
#     "WBTC": 0.3909452132571429,
#     "tBTC": 45.3717425037259
# }
# {
#     "USDC": 2633842.799910549,
#     "USDT": 40759.31340474857,
#     "GHO": 435383.22702168755,
#     "RPL": 3929.4243485311767,
#     "crvUSD": 16986.779474882376
# }
# {
#     "WBTC": 0.3909452132571429,
#     "tBTC": 45.3717425037259
# }
# {
#     "USDC": 2633842.799910549,
#     "USDT": 40759.31340474857,
#     "GHO": 435383.22702168755,
#     "RPL": 3929.4243485311767,
#     "crvUSD": 16986.779474882376
# }
# {
#     "WBTC": 0.3909452132571429,
#     "tBTC": 45.3717425037259
# }
# {
#     "USDC": 2633842.799910549,
#     "USDT": 40759.31340474857,
#     "GHO": 435383.22702168755,
#     "RPL": 3929.4243485311767,
#     "crvUSD": 16986.779474882376
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 3180199.8519609477,
#         "flashloan_start_usd": 3178453.922242221,
#         "flashloan_end": 3748665.952246953,
#         "flashloan_end_usd": 3746607.9346391694,
#         "flashloan_profit": 568154.0123969481,
#         "flashloan_profit_usd": 567842.0958441421
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3178471.851332477,
#         "flashloan_start_usd": 3178471.851332477,
#         "flashloan_end": 3746607.934639169,
#         "flashloan_end_usd": 3746607.934639169,
#         "flashloan_profit": 568136.0833066921,
#         "flashloan_profit_usd": 568136.0833066921
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3179042.4262366635,
#         "flashloan_start_usd": 3179042.4262366635,
#         "flashloan_end": 282919.9388874742,
#         "flashloan_end_usd": 282919.9388874742,
#         "flashloan_profit": -2896122.4873491894,
#         "flashloan_profit_usd": -2896122.4873491894
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 855.3870963924732,
#         "flashloan_start_usd": 3178267.7414849093,
#         "flashloan_end": 1018.557097739785,
#         "flashloan_end_usd": 3784540.566790968,
#         "flashloan_profit": 606272.8253060586,
#         "flashloan_profit_usd": 2252661246.9789386
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.446149405322449,
#     "tBTC": 51.778549142040795
# }
# {
#     "USDC": 3005759.7817932502,
#     "USDT": 46514.812869492656,
#     "GHO": 496862.3767119259,
#     "RPL": 4484.286485440694,
#     "crvUSD": 19385.43126777595
# }
# {
#     "WBTC": 0.446149405322449,
#     "tBTC": 51.778549142040795
# }
# {
#     "USDC": 3005759.7817932502,
#     "USDT": 46514.812869492656,
#     "GHO": 496862.3767119259,
#     "RPL": 4484.286485440694,
#     "crvUSD": 19385.43126777595
# }
# {
#     "WBTC": 0.446149405322449,
#     "tBTC": 51.778549142040795
# }
# {
#     "USDC": 3005759.7817932502,
#     "USDT": 46514.812869492656,
#     "GHO": 496862.3767119259,
#     "RPL": 4484.286485440694,
#     "crvUSD": 19385.43126777595
# }
# {
#     "WBTC": 0.446149405322449,
#     "tBTC": 51.778549142040795
# }
# {
#     "USDC": 3005759.7817932502,
#     "USDT": 46514.812869492656,
#     "GHO": 496862.3767119259,
#     "RPL": 4484.286485440694,
#     "crvUSD": 19385.43126777595
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 3629549.2155708023,
#         "flashloan_start_usd": 3627556.593051454,
#         "flashloan_end": 4278003.742297769,
#         "flashloan_end_usd": 4275655.118243247,
#         "flashloan_profit": 648098.5251917931,
#         "flashloan_profit_usd": 647742.7191014627
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3627585.4864146197,
#         "flashloan_start_usd": 3627585.4864146197,
#         "flashloan_end": 4275655.11824333,
#         "flashloan_end_usd": 4275655.11824333,
#         "flashloan_profit": 648069.6318287104,
#         "flashloan_profit_usd": 648069.6318287104
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 3628491.294932621,
#         "flashloan_start_usd": 3628491.294932621,
#         "flashloan_end": 280003.52396740275,
#         "flashloan_end_usd": 280003.52396740275,
#         "flashloan_profit": -3348487.7709652185,
#         "flashloan_profit_usd": -3348487.7709652185
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 976.2243491382166,
#         "flashloan_start_usd": 3627249.429414466,
#         "flashloan_end": 1162.3844672557034,
#         "flashloan_end_usd": 4318944.102690619,
#         "flashloan_profit": 691694.6732761529,
#         "flashloan_profit_usd": 2570053811.078141
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.5013535973877551,
#     "tBTC": 58.18535578035569
# }
# {
#     "USDC": 3377676.7636759514,
#     "USDT": 52270.31233423673,
#     "GHO": 558341.5264021641,
#     "RPL": 5039.148622350212,
#     "crvUSD": 21784.083060669524
# }
# {
#     "WBTC": 0.5013535973877551,
#     "tBTC": 58.18535578035569
# }
# {
#     "USDC": 3377676.7636759514,
#     "USDT": 52270.31233423673,
#     "GHO": 558341.5264021641,
#     "RPL": 5039.148622350212,
#     "crvUSD": 21784.083060669524
# }
# {
#     "WBTC": 0.5013535973877551,
#     "tBTC": 58.18535578035569
# }
# {
#     "USDC": 3377676.7636759514,
#     "USDT": 52270.31233423673,
#     "GHO": 558341.5264021641,
#     "RPL": 5039.148622350212,
#     "crvUSD": 21784.083060669524
# }
# {
#     "WBTC": 0.5013535973877551,
#     "tBTC": 58.18535578035569
# }
# {
#     "USDC": 3377676.7636759514,
#     "USDT": 52270.31233423673,
#     "GHO": 558341.5264021641,
#     "RPL": 5039.148622350212,
#     "crvUSD": 21784.083060669524
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 4079041.8393318756,
#         "flashloan_start_usd": 4076802.445362082,
#         "flashloan_end": 4807341.532315635,
#         "flashloan_end_usd": 4804702.301814394,
#         "flashloan_profit": 727899.8564523115,
#         "flashloan_profit_usd": 727500.2394311192
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 4076845.380622578,
#         "flashloan_start_usd": 4076845.380622578,
#         "flashloan_end": 4804702.301846119,
#         "flashloan_end_usd": 4804702.301846119,
#         "flashloan_profit": 727856.9212235408,
#         "flashloan_profit_usd": 727856.9212235408
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 4078180.2716513486,
#         "flashloan_start_usd": 4078180.2716513486,
#         "flashloan_end": 277284.8538176723,
#         "flashloan_end_usd": 277284.8538176723,
#         "flashloan_profit": -3800895.417833676,
#         "flashloan_profit_usd": -3800895.417833676
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1097.0902938621189,
#         "flashloan_start_usd": 4076337.7249711505,
#         "flashloan_end": 1306.2118356084993,
#         "flashloan_end_usd": 4853347.634268584,
#         "flashloan_profit": 777009.9092974338,
#         "flashloan_profit_usd": 2887050248.886452
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.5565577894530612,
#     "tBTC": 64.5921624186706
# }
# {
#     "USDC": 3749593.7455586526,
#     "USDT": 58025.811798980816,
#     "GHO": 619820.6760924024,
#     "RPL": 5594.01075925973,
#     "crvUSD": 24182.7348535631
# }
# {
#     "WBTC": 0.5565577894530612,
#     "tBTC": 64.5921624186706
# }
# {
#     "USDC": 3749593.7455586526,
#     "USDT": 58025.811798980816,
#     "GHO": 619820.6760924024,
#     "RPL": 5594.01075925973,
#     "crvUSD": 24182.7348535631
# }
# {
#     "WBTC": 0.5565577894530612,
#     "tBTC": 64.5921624186706
# }
# {
#     "USDC": 3749593.7455586526,
#     "USDT": 58025.811798980816,
#     "GHO": 619820.6760924024,
#     "RPL": 5594.01075925973,
#     "crvUSD": 24182.7348535631
# }
# {
#     "WBTC": 0.5565577894530612,
#     "tBTC": 64.5921624186706
# }
# {
#     "USDC": 3749593.7455586526,
#     "USDT": 58025.811798980816,
#     "GHO": 619820.6760924024,
#     "RPL": 5594.01075925973,
#     "crvUSD": 24182.7348535631
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 4528697.9723297,
#         "flashloan_start_usd": 4526211.717142891,
#         "flashloan_end": 5336679.319672313,
#         "flashloan_end_usd": 5333749.482725812,
#         "flashloan_profit": 807537.7655829211,
#         "flashloan_profit_usd": 807094.4273496161
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 4526271.86571449,
#         "flashloan_start_usd": 4526271.86571449,
#         "flashloan_end": 5333749.485265771,
#         "flashloan_end_usd": 5333749.485265771,
#         "flashloan_profit": 807477.6195512805,
#         "flashloan_profit_usd": 807477.6195512805
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 4528134.903317074,
#         "flashloan_start_usd": 4528134.903317074,
#         "flashloan_end": 274756.4830412762,
#         "flashloan_end_usd": 274756.4830412762,
#         "flashloan_profit": -4253378.420275798,
#         "flashloan_profit_usd": -4253378.420275798
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1217.9899934586538,
#         "flashloan_start_usd": 4525551.43979504,
#         "flashloan_end": 1450.0391727473566,
#         "flashloan_end_usd": 5387751.049868351,
#         "flashloan_profit": 862199.6100733114,
#         "flashloan_profit_usd": 3203580249.192295
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.6117619815183674,
#     "tBTC": 70.9989690569855
# }
# {
#     "USDC": 4121510.7274413537,
#     "USDT": 63781.3112637249,
#     "GHO": 681299.8257826407,
#     "RPL": 6148.872896169248,
#     "crvUSD": 26581.386646456674
# }
# {
#     "WBTC": 0.6117619815183674,
#     "tBTC": 70.9989690569855
# }
# {
#     "USDC": 4121510.7274413537,
#     "USDT": 63781.3112637249,
#     "GHO": 681299.8257826407,
#     "RPL": 6148.872896169248,
#     "crvUSD": 26581.386646456674
# }
# {
#     "WBTC": 0.6117619815183674,
#     "tBTC": 70.9989690569855
# }
# {
#     "USDC": 4121510.7274413537,
#     "USDT": 63781.3112637249,
#     "GHO": 681299.8257826407,
#     "RPL": 6148.872896169248,
#     "crvUSD": 26581.386646456674
# }
# {
#     "WBTC": 0.6117619815183674,
#     "tBTC": 70.9989690569855
# }
# {
#     "USDC": 4121510.7274413537,
#     "USDT": 63781.3112637249,
#     "GHO": 681299.8257826407,
#     "RPL": 6148.872896169248,
#     "crvUSD": 26581.386646456674
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 4978535.818139841,
#         "flashloan_start_usd": 4975802.601975682,
#         "flashloan_end": 5866017.033332134,
#         "flashloan_end_usd": 5862796.589980834,
#         "flashloan_profit": 886993.9880051522,
#         "flashloan_profit_usd": 886507.0283057373
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 4975883.203686539,
#         "flashloan_start_usd": 4975883.203686539,
#         "flashloan_end": 5862796.661163098,
#         "flashloan_end_usd": 5862796.661163098,
#         "flashloan_profit": 886913.4574765591,
#         "flashloan_profit_usd": 886913.4574765591
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 4978378.293067806,
#         "flashloan_start_usd": 4978378.293067806,
#         "flashloan_end": 272403.55698859744,
#         "flashloan_end_usd": 272403.55698859744,
#         "flashloan_profit": -4705974.736079209,
#         "flashloan_profit_usd": -4705974.736079209
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1338.9280731767305,
#         "flashloan_start_usd": 4974907.759414729,
#         "flashloan_end": 1593.8661295519553,
#         "flashloan_end_usd": 5922153.05230195,
#         "flashloan_profit": 947245.2928872213,
#         "flashloan_profit_usd": 3519575137.798831
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.6669661735836735,
#     "tBTC": 77.4057756953004
# }
# {
#     "USDC": 4493427.709324055,
#     "USDT": 69536.81072846898,
#     "GHO": 742778.975472879,
#     "RPL": 6703.735033078766,
#     "crvUSD": 28980.038439350246
# }
# {
#     "WBTC": 0.6669661735836735,
#     "tBTC": 77.4057756953004
# }
# {
#     "USDC": 4493427.709324055,
#     "USDT": 69536.81072846898,
#     "GHO": 742778.975472879,
#     "RPL": 6703.735033078766,
#     "crvUSD": 28980.038439350246
# }
# {
#     "WBTC": 0.6669661735836735,
#     "tBTC": 77.4057756953004
# }
# {
#     "USDC": 4493427.709324055,
#     "USDT": 69536.81072846898,
#     "GHO": 742778.975472879,
#     "RPL": 6703.735033078766,
#     "crvUSD": 28980.038439350246
# }
# {
#     "WBTC": 0.6669661735836735,
#     "tBTC": 77.4057756953004
# }
# {
#     "USDC": 4493427.709324055,
#     "USDT": 69536.81072846898,
#     "GHO": 742778.975472879,
#     "RPL": 6703.735033078766,
#     "crvUSD": 28980.038439350246
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 5428571.918584426,
#         "flashloan_start_usd": 5425591.632601123,
#         "flashloan_end": 6395353.797349644,
#         "flashloan_end_usd": 6391842.748114899,
#         "flashloan_profit": 966251.1155137758,
#         "flashloan_profit_usd": 965720.6436513588
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 5425695.983801578,
#         "flashloan_start_usd": 5425695.983801578,
#         "flashloan_end": 6391843.703717282,
#         "flashloan_end_usd": 6391843.703717282,
#         "flashloan_profit": 966147.7199157039,
#         "flashloan_profit_usd": 966147.7199157039
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 5428931.764092873,
#         "flashloan_start_usd": 5428931.764092873,
#         "flashloan_end": 270209.52673398086,
#         "flashloan_end_usd": 270209.52673398086,
#         "flashloan_profit": -5158722.237358892,
#         "flashloan_profit_usd": -5158722.237358892
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1459.9087707144415,
#         "flashloan_start_usd": 5424422.429378872,
#         "flashloan_end": 1737.6904680762107,
#         "flashloan_end_usd": 6456545.326279288,
#         "flashloan_profit": 1032122.8969004159,
#         "flashloan_profit_usd": 3834945514.4942164
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.7221703656489796,
#     "tBTC": 83.8125823336153
# }
# {
#     "USDC": 4865344.691206757,
#     "USDT": 75292.31019321307,
#     "GHO": 804258.1251631173,
#     "RPL": 7258.597169988284,
#     "crvUSD": 31378.69023224382
# }
# {
#     "WBTC": 0.7221703656489796,
#     "tBTC": 83.8125823336153
# }
# {
#     "USDC": 4865344.691206757,
#     "USDT": 75292.31019321307,
#     "GHO": 804258.1251631173,
#     "RPL": 7258.597169988284,
#     "crvUSD": 31378.69023224382
# }
# {
#     "WBTC": 0.7221703656489796,
#     "tBTC": 83.8125823336153
# }
# {
#     "USDC": 4865344.691206757,
#     "USDT": 75292.31019321307,
#     "GHO": 804258.1251631173,
#     "RPL": 7258.597169988284,
#     "crvUSD": 31378.69023224382
# }
# {
#     "WBTC": 0.7221703656489796,
#     "tBTC": 83.8125823336153
# }
# {
#     "USDC": 4865344.691206757,
#     "USDT": 75292.31019321307,
#     "GHO": 804258.1251631173,
#     "RPL": 7258.597169988284,
#     "crvUSD": 31378.69023224382
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 5878821.495048239,
#         "flashloan_start_usd": 5875594.022047457,
#         "flashloan_end": 6924683.590457318,
#         "flashloan_end_usd": 6920881.9391661575,
#         "flashloan_profit": 1045287.9171186999,
#         "flashloan_profit_usd": 1044714.0540522017
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 5875725.47121713,
#         "flashloan_start_usd": 5875725.47121713,
#         "flashloan_end": 6920889.473309942,
#         "flashloan_end_usd": 6920889.473309942,
#         "flashloan_profit": 1045164.0020928113,
#         "flashloan_profit_usd": 1045164.0020928113
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 5879815.356927891,
#         "flashloan_start_usd": 5879815.356927891,
#         "flashloan_end": 268158.4026692996,
#         "flashloan_end_usd": 268158.4026692996,
#         "flashloan_profit": -5611656.954258592,
#         "flashloan_profit_usd": -5611656.954258592
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1580.9359966329127,
#         "flashloan_start_usd": 5874109.9797292845,
#         "flashloan_end": 1881.5029873797894,
#         "flashloan_end_usd": 6990893.684878472,
#         "flashloan_profit": 1116783.7051491875,
#         "flashloan_profit_usd": 4149510367.0152698
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.7773745577142858,
#     "tBTC": 90.2193889719302
# }
# {
#     "USDC": 5237261.673089458,
#     "USDT": 81047.80965795714,
#     "GHO": 865737.2748533556,
#     "RPL": 7813.459306897802,
#     "crvUSD": 33777.3420251374
# }
# {
#     "WBTC": 0.7773745577142858,
#     "tBTC": 90.2193889719302
# }
# {
#     "USDC": 5237261.673089458,
#     "USDT": 81047.80965795714,
#     "GHO": 865737.2748533556,
#     "RPL": 7813.459306897802,
#     "crvUSD": 33777.3420251374
# }
# {
#     "WBTC": 0.7773745577142858,
#     "tBTC": 90.2193889719302
# }
# {
#     "USDC": 5237261.673089458,
#     "USDT": 81047.80965795714,
#     "GHO": 865737.2748533556,
#     "RPL": 7813.459306897802,
#     "crvUSD": 33777.3420251374
# }
# {
#     "WBTC": 0.7773745577142858,
#     "tBTC": 90.2193889719302
# }
# {
#     "USDC": 5237261.673089458,
#     "USDT": 81047.80965795714,
#     "GHO": 865737.2748533556,
#     "RPL": 7813.459306897802,
#     "crvUSD": 33777.3420251374
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 6329298.732860155,
#         "flashloan_start_usd": 6325823.947855815,
#         "flashloan_end": 7453979.831010531,
#         "flashloan_end_usd": 7449887.596083306,
#         "flashloan_profit": 1124063.6482274907,
#         "flashloan_profit_usd": 1123446.5372846138
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 6325985.895273138,
#         "flashloan_start_usd": 6325985.895273138,
#         "flashloan_end": 7449927.614394912,
#         "flashloan_end_usd": 7449927.614394912,
#         "flashloan_profit": 1123941.7191217737,
#         "flashloan_profit_usd": 1123941.7191217737
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 6331048.200167147,
#         "flashloan_start_usd": 6331048.200167147,
#         "flashloan_end": 266235.5729335108,
#         "flashloan_end_usd": 266235.5729335108,
#         "flashloan_profit": -6064812.627233637,
#         "flashloan_profit_usd": -6064812.627233637
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1702.013392723748,
#         "flashloan_start_usd": 6323983.941870431,
#         "flashloan_end": 2025.276652977204,
#         "flashloan_end_usd": 7525097.6790355705,
#         "flashloan_profit": 1201113.737165139,
#         "flashloan_profit_usd": 4462846190.673419
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.8325787497795919,
#     "tBTC": 96.6261956102451
# }
# {
#     "USDC": 5609178.654972159,
#     "USDT": 86803.30912270122,
#     "GHO": 927216.424543594,
#     "RPL": 8368.32144380732,
#     "crvUSD": 36175.99381803097
# }
# {
#     "WBTC": 0.8325787497795919,
#     "tBTC": 96.6261956102451
# }
# {
#     "USDC": 5609178.654972159,
#     "USDT": 86803.30912270122,
#     "GHO": 927216.424543594,
#     "RPL": 8368.32144380732,
#     "crvUSD": 36175.99381803097
# }
# {
#     "WBTC": 0.8325787497795919,
#     "tBTC": 96.6261956102451
# }
# {
#     "USDC": 5609178.654972159,
#     "USDT": 86803.30912270122,
#     "GHO": 927216.424543594,
#     "RPL": 8368.32144380732,
#     "crvUSD": 36175.99381803097
# }
# {
#     "WBTC": 0.8325787497795919,
#     "tBTC": 96.6261956102451
# }
# {
#     "USDC": 5609178.654972159,
#     "USDT": 86803.30912270122,
#     "GHO": 927216.424543594,
#     "RPL": 8368.32144380732,
#     "crvUSD": 36175.99381803097
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 6780017.011613086,
#         "flashloan_start_usd": 6776294.78227371,
#         "flashloan_end": 7983158.951165387,
#         "flashloan_end_usd": 7978776.196901198,
#         "flashloan_profit": 1202481.4146274873,
#         "flashloan_profit_usd": 1201821.2523308569
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 6776490.68179605,
#         "flashloan_start_usd": 6776490.68179605,
#         "flashloan_end": 7978933.729479379,
#         "flashloan_end_usd": 7978933.729479379,
#         "flashloan_profit": 1202443.0476833293,
#         "flashloan_profit_usd": 1202443.0476833293
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 6782648.787949423,
#         "flashloan_start_usd": 6782648.787949423,
#         "flashloan_end": 264428.01476860966,
#         "flashloan_end_usd": 264428.01476860966,
#         "flashloan_profit": -6518220.7731808135,
#         "flashloan_profit_usd": -6518220.7731808135
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1823.1443837567538,
#         "flashloan_start_usd": 6774057.040842757,
#         "flashloan_end": 2168.9500211980317,
#         "flashloan_end_usd": 8058929.009263195,
#         "flashloan_profit": 1284871.9684204378,
#         "flashloan_profit_usd": 4774057437.143294
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.887782941844898,
#     "tBTC": 103.03300224856001
# }
# {
#     "USDC": 5981095.636854861,
#     "USDT": 92558.80858744531,
#     "GHO": 988695.5742338323,
#     "RPL": 8923.183580716837,
#     "crvUSD": 38574.64561092455
# }
# {
#     "WBTC": 0.887782941844898,
#     "tBTC": 103.03300224856001
# }
# {
#     "USDC": 5981095.636854861,
#     "USDT": 92558.80858744531,
#     "GHO": 988695.5742338323,
#     "RPL": 8923.183580716837,
#     "crvUSD": 38574.64561092455
# }
# {
#     "WBTC": 0.887782941844898,
#     "tBTC": 103.03300224856001
# }
# {
#     "USDC": 5981095.636854861,
#     "USDT": 92558.80858744531,
#     "GHO": 988695.5742338323,
#     "RPL": 8923.183580716837,
#     "crvUSD": 38574.64561092455
# }
# {
#     "WBTC": 0.887782941844898,
#     "tBTC": 103.03300224856001
# }
# {
#     "USDC": 5981095.636854861,
#     "USDT": 92558.80858744531,
#     "GHO": 988695.5742338323,
#     "RPL": 8923.183580716837,
#     "crvUSD": 38574.64561092455
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 7230989.08955251,
#         "flashloan_start_usd": 7227019.276542345,
#         "flashloan_end": 8512018.938022725,
#         "flashloan_end_usd": 8507345.83962575,
#         "flashloan_profit": 1280326.5630834056,
#         "flashloan_profit_usd": 1279623.6638002729
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 7227252.6383938575,
#         "flashloan_start_usd": 7227252.6383938575,
#         "flashloan_end": 8507837.774583757,
#         "flashloan_end_usd": 8507837.774583757,
#         "flashloan_profit": 1280585.1361898994,
#         "flashloan_profit_usd": 1280585.1361898994
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 7234635.189364875,
#         "flashloan_start_usd": 7234635.189364875,
#         "flashloan_end": 262724.25334051746,
#         "flashloan_end_usd": 262724.25334051746,
#         "flashloan_profit": -6971910.936024358,
#         "flashloan_profit_usd": -6971910.936024358
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 1944.3322215591493,
#         "flashloan_start_usd": 7224341.35910296,
#         "flashloan_end": 2312.408574535163,
#         "flashloan_end_usd": 8591962.175457107,
#         "flashloan_profit": 1367620.8163541472,
#         "flashloan_profit_usd": 5081518229.037306
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.9429871339102041,
#     "tBTC": 109.43980888687489
# }
# {
#     "USDC": 6353012.618737561,
#     "USDT": 98314.30805218937,
#     "GHO": 1050174.7239240704,
#     "RPL": 9478.045717626354,
#     "crvUSD": 40973.29740381811
# }
# {
#     "WBTC": 0.9429871339102041,
#     "tBTC": 109.43980888687489
# }
# {
#     "USDC": 6353012.618737561,
#     "USDT": 98314.30805218937,
#     "GHO": 1050174.7239240704,
#     "RPL": 9478.045717626354,
#     "crvUSD": 40973.29740381811
# }
# {
#     "WBTC": 0.9429871339102041,
#     "tBTC": 109.43980888687489
# }
# {
#     "USDC": 6353012.618737561,
#     "USDT": 98314.30805218937,
#     "GHO": 1050174.7239240704,
#     "RPL": 9478.045717626354,
#     "crvUSD": 40973.29740381811
# }
# {
#     "WBTC": 0.9429871339102041,
#     "tBTC": 109.43980888687489
# }
# {
#     "USDC": 6353012.618737561,
#     "USDT": 98314.30805218937,
#     "GHO": 1050174.7239240704,
#     "RPL": 9478.045717626354,
#     "crvUSD": 40973.29740381811
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 7682227.250743233,
#         "flashloan_start_usd": 7678009.707982575,
#         "flashloan_end": 9040162.090438973,
#         "flashloan_end_usd": 9035199.041451322,
#         "flashloan_profit": 1357189.3334687476,
#         "flashloan_profit_usd": 1356444.2365246732
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 7678284.101930311,
#         "flashloan_start_usd": 7678284.101930311,
#         "flashloan_end": 9036479.656393,
#         "flashloan_end_usd": 9036479.656393,
#         "flashloan_profit": 1358195.55446269,
#         "flashloan_profit_usd": 1358195.55446269
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 7687025.208051694,
#         "flashloan_start_usd": 7687025.208051694,
#         "flashloan_end": 261114.22407421577,
#         "flashloan_end_usd": 261114.22407421577,
#         "flashloan_profit": -7425910.983977478,
#         "flashloan_profit_usd": -7425910.983977478
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 2065.5800218416107,
#         "flashloan_start_usd": 7674848.473354471,
#         "flashloan_end": 2455.469526900943,
#         "flashloan_end_usd": 9123518.019457875,
#         "flashloan_profit": 1448669.5461034048,
#         "flashloan_profit_usd": 5382662078.80635
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 0.9981913259755102,
#     "tBTC": 115.84661552518979
# }
# {
#     "USDC": 6724929.600620262,
#     "USDT": 104069.80751693345,
#     "GHO": 1111653.8736143087,
#     "RPL": 10032.907854535872,
#     "crvUSD": 43371.949196711685
# }
# {
#     "WBTC": 0.9981913259755102,
#     "tBTC": 115.84661552518979
# }
# {
#     "USDC": 6724929.600620262,
#     "USDT": 104069.80751693345,
#     "GHO": 1111653.8736143087,
#     "RPL": 10032.907854535872,
#     "crvUSD": 43371.949196711685
# }
# {
#     "WBTC": 0.9981913259755102,
#     "tBTC": 115.84661552518979
# }
# {
#     "USDC": 6724929.600620262,
#     "USDT": 104069.80751693345,
#     "GHO": 1111653.8736143087,
#     "RPL": 10032.907854535872,
#     "crvUSD": 43371.949196711685
# }
# {
#     "WBTC": 0.9981913259755102,
#     "tBTC": 115.84661552518979
# }
# {
#     "USDC": 6724929.600620262,
#     "USDT": 104069.80751693345,
#     "GHO": 1111653.8736143087,
#     "RPL": 10032.907854535872,
#     "crvUSD": 43371.949196711685
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 8133743.422708454,
#         "flashloan_start_usd": 8129277.997569387,
#         "flashloan_end": 9566922.55976461,
#         "flashloan_end_usd": 9561670.3192793,
#         "flashloan_profit": 1432392.3217099132,
#         "flashloan_profit_usd": 1431605.9383252945
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 8129597.056143636,
#         "flashloan_start_usd": 8129597.056143636,
#         "flashloan_end": 9564553.914853405,
#         "flashloan_end_usd": 9564553.914853405,
#         "flashloan_profit": 1434956.8587097693,
#         "flashloan_profit_usd": 1434956.8587097693
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 8139836.505094252,
#         "flashloan_start_usd": 8139836.505094252,
#         "flashloan_end": 259589.10762321416,
#         "flashloan_end_usd": 259589.10762321416,
#         "flashloan_profit": -7880247.397471038,
#         "flashloan_profit_usd": -7880247.397471038
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 2186.8907946976688,
#         "flashloan_start_usd": 8125589.567870711,
#         "flashloan_end": 2597.8747864512334,
#         "flashloan_end_usd": 9652637.577790339,
#         "flashloan_profit": 1527048.0099196273,
#         "flashloan_profit_usd": 5673884315.177268
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 1.0533955180408163,
#     "tBTC": 122.2534221635047
# }
# {
#     "USDC": 7096846.582502963,
#     "USDT": 109825.30698167754,
#     "GHO": 1173133.023304547,
#     "RPL": 10587.76999144539,
#     "crvUSD": 45770.600989605264
# }
# {
#     "WBTC": 1.0533955180408163,
#     "tBTC": 122.2534221635047
# }
# {
#     "USDC": 7096846.582502963,
#     "USDT": 109825.30698167754,
#     "GHO": 1173133.023304547,
#     "RPL": 10587.76999144539,
#     "crvUSD": 45770.600989605264
# }
# {
#     "WBTC": 1.0533955180408163,
#     "tBTC": 122.2534221635047
# }
# {
#     "USDC": 7096846.582502963,
# ...
#         "flashloan_profit_usd": -76372.76807907224
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 19651739.983919792,
#         "flashloan_start_usd": 19651739.983919792,
#         "flashloan_end": 236157.0522084263,
#         "flashloan_end_usd": 236157.0522084263,
#         "flashloan_profit": -19415582.931711365,
#         "flashloan_profit_usd": -19415582.931711365
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 5248.506016342035,
#         "flashloan_start_usd": 19501296.4692603,
#         "flashloan_end": 5049.485971866033,
#         "flashloan_end_usd": 18761819.582205713,
#         "flashloan_profit": -739476.8870545888,
#         "flashloan_profit_usd": -2747592926.7711596
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 2.4335003196734695,
#     "tBTC": 282.42358812137724
# }
# {
#     "USDC": 16394771.129570495,
#     "USDT": 253712.79360027958,
#     "GHO": 2710111.7655605045,
#     "RPL": 24459.323414183335,
#     "crvUSD": 105736.89581194462
# }
# {
#     "WBTC": 2.4335003196734695,
#     "tBTC": 282.42358812137724
# }
# {
#     "USDC": 16394771.129570495,
#     "USDT": 253712.79360027958,
#     "GHO": 2710111.7655605045,
#     "RPL": 24459.323414183335,
#     "crvUSD": 105736.89581194462
# }
# {
#     "WBTC": 2.4335003196734695,
#     "tBTC": 282.42358812137724
# }
# {
#     "USDC": 16394771.129570495,
#     "USDT": 253712.79360027958,
#     "GHO": 2710111.7655605045,
#     "RPL": 24459.323414183335,
#     "crvUSD": 105736.89581194462
# }
# {
#     "WBTC": 2.4335003196734695,
#     "tBTC": 282.42358812137724
# }
# {
#     "USDC": 16394771.129570495,
#     "USDT": 253712.79360027958,
#     "GHO": 2710111.7655605045,
#     "RPL": 24459.323414183335,
#     "crvUSD": 105736.89581194462
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 20008682.48927551,
#         "flashloan_start_usd": 19997697.7225889,
#         "flashloan_end": 18645504.713307135,
#         "flashloan_end_usd": 18635268.331219528,
#         "flashloan_profit": -1362429.3913693698,
#         "flashloan_profit_usd": -1361681.417633508
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 20000699.93389518,
#         "flashloan_start_usd": 20000699.93389518,
#         "flashloan_end": 19646805.81771367,
#         "flashloan_end_usd": 19646805.81771367,
#         "flashloan_profit": -353894.1161815077,
#         "flashloan_profit_usd": -353894.1161815077
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 20122287.464882065,
#         "flashloan_start_usd": 20122287.464882065,
#         "flashloan_end": 235545.3017608196,
#         "flashloan_end_usd": 235545.3017608196,
#         "flashloan_profit": -19886742.163121246,
#         "flashloan_profit_usd": -19886742.163121246
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 5372.476515637425,
#         "flashloan_start_usd": 19961920.01673726,
#         "flashloan_end": 5092.757948784423,
#         "flashloan_end_usd": 18922600.506923914,
#         "flashloan_profit": -1039319.5098133454,
#         "flashloan_profit_usd": -3861685177.467368
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 2.4887045117387756,
#     "tBTC": 288.8303947596921
# }
# {
#     "USDC": 16766688.111453196,
#     "USDT": 259468.29306502367,
#     "GHO": 2771590.915250743,
#     "RPL": 25014.185551092854,
#     "crvUSD": 108135.5476048382
# }
# {
#     "WBTC": 2.4887045117387756,
#     "tBTC": 288.8303947596921
# }
# {
#     "USDC": 16766688.111453196,
#     "USDT": 259468.29306502367,
#     "GHO": 2771590.915250743,
#     "RPL": 25014.185551092854,
#     "crvUSD": 108135.5476048382
# }
# {
#     "WBTC": 2.4887045117387756,
#     "tBTC": 288.8303947596921
# }
# {
#     "USDC": 16766688.111453196,
#     "USDT": 259468.29306502367,
#     "GHO": 2771590.915250743,
#     "RPL": 25014.185551092854,
#     "crvUSD": 108135.5476048382
# }
# {
#     "WBTC": 2.4887045117387756,
#     "tBTC": 288.8303947596921
# }
# {
#     "USDC": 16766688.111453196,
#     "USDT": 259468.29306502367,
#     "GHO": 2771590.915250743,
#     "RPL": 25014.185551092854,
#     "crvUSD": 108135.5476048382
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 20472163.75389437,
#         "flashloan_start_usd": 20460924.535993483,
#         "flashloan_end": 18761925.03624701,
#         "flashloan_end_usd": 18751624.73940211,
#         "flashloan_profit": -1709299.7965913704,
#         "flashloan_profit_usd": -1708361.3910030418
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 20464098.224749085,
#         "flashloan_start_usd": 20464098.224749085,
#         "flashloan_end": 19817014.91140283,
#         "flashloan_end_usd": 19817014.91140283,
#         "flashloan_profit": -647083.3133462556,
#         "flashloan_profit_usd": -647083.3133462556
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 20593814.21768496,
#         "flashloan_start_usd": 20593814.21768496,
#         "flashloan_end": 234948.04896637733,
#         "flashloan_end_usd": 234948.04896637733,
#         "flashloan_profit": -20358866.168718584,
#         "flashloan_profit_usd": -20358866.168718584
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 5496.592547193331,
#         "flashloan_start_usd": 20423084.302426066,
#         "flashloan_end": 5132.680839219992,
#         "flashloan_end_usd": 19070937.59939741,
#         "flashloan_profit": -1352146.7030286577,
#         "flashloan_profit_usd": -5024022768.306251
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 2.5439087038040817,
#     "tBTC": 295.237201398007
# }
# {
#     "USDC": 17138605.093335897,
#     "USDT": 265223.7925297677,
#     "GHO": 2833070.064940981,
#     "RPL": 25569.04768800237,
#     "crvUSD": 110534.19939773178
# }
# {
#     "WBTC": 2.5439087038040817,
#     "tBTC": 295.237201398007
# }
# {
#     "USDC": 17138605.093335897,
#     "USDT": 265223.7925297677,
#     "GHO": 2833070.064940981,
#     "RPL": 25569.04768800237,
#     "crvUSD": 110534.19939773178
# }
# {
#     "WBTC": 2.5439087038040817,
#     "tBTC": 295.237201398007
# }
# {
#     "USDC": 17138605.093335897,
#     "USDT": 265223.7925297677,
#     "GHO": 2833070.064940981,
#     "RPL": 25569.04768800237,
#     "crvUSD": 110534.19939773178
# }
# {
#     "WBTC": 2.5439087038040817,
#     "tBTC": 295.237201398007
# }
# {
#     "USDC": 17138605.093335897,
#     "USDT": 265223.7925297677,
#     "GHO": 2833070.064940981,
#     "RPL": 25569.04768800237,
#     "crvUSD": 110534.19939773178
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 20936269.536994673,
#         "flashloan_start_usd": 20924775.525018863,
#         "flashloan_end": 18865065.646699402,
#         "flashloan_end_usd": 18854708.725659363,
#         "flashloan_profit": -2070066.7993594988,
#         "flashloan_profit_usd": -2068930.3326866503
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 20928126.40694129,
#         "flashloan_start_usd": 20928126.40694129,
#         "flashloan_end": 19972786.24657725,
#         "flashloan_end_usd": 19972786.24657725,
#         "flashloan_profit": -955340.1603640392,
#         "flashloan_profit_usd": -955340.1603640392
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 21066345.17711998,
#         "flashloan_start_usd": 21066345.17711998,
#         "flashloan_end": 234364.66047674426,
#         "flashloan_end_usd": 234364.66047674426,
#         "flashloan_profit": -20831980.516643237,
#         "flashloan_profit_usd": -20831980.516643237
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 5620.857778285239,
#         "flashloan_start_usd": 20884802.952418853,
#         "flashloan_end": 5169.414461650231,
#         "flashloan_end_usd": 19207424.679562982,
#         "flashloan_profit": -1677378.27285587,
#         "flashloan_profit_usd": -6232449936.840542
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 2.599112895869388,
#     "tBTC": 301.6440080363219
# }
# {
#     "USDC": 17510522.0752186,
#     "USDT": 270979.29199451185,
#     "GHO": 2894549.2146312194,
#     "RPL": 26123.90982491189,
#     "crvUSD": 112932.85119062536
# }
# {
#     "WBTC": 2.599112895869388,
#     "tBTC": 301.6440080363219
# }
# {
#     "USDC": 17510522.0752186,
#     "USDT": 270979.29199451185,
#     "GHO": 2894549.2146312194,
#     "RPL": 26123.90982491189,
#     "crvUSD": 112932.85119062536
# }
# {
#     "WBTC": 2.599112895869388,
#     "tBTC": 301.6440080363219
# }
# {
#     "USDC": 17510522.0752186,
#     "USDT": 270979.29199451185,
#     "GHO": 2894549.2146312194,
#     "RPL": 26123.90982491189,
#     "crvUSD": 112932.85119062536
# }
# {
#     "WBTC": 2.599112895869388,
#     "tBTC": 301.6440080363219
# }
# {
#     "USDC": 17510522.0752186,
#     "USDT": 270979.29199451185,
#     "GHO": 2894549.2146312194,
#     "RPL": 26123.90982491189,
#     "crvUSD": 112932.85119062536
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 21401014.441589613,
#         "flashloan_start_usd": 21389265.284661178,
#         "flashloan_end": 18955649.256089643,
#         "flashloan_end_usd": 18945242.60464805,
#         "flashloan_profit": -2444022.6800131304,
#         "flashloan_profit_usd": -2442680.911561803
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 21392799.13170216,
#         "flashloan_start_usd": 21392799.13170216,
#         "flashloan_end": 20114741.45313737,
#         "flashloan_end_usd": 20114741.45313737,
#         "flashloan_profit": -1278057.678564787,
#         "flashloan_profit_usd": -1278057.678564787
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 21539905.58229416,
#         "flashloan_start_usd": 21539905.58229416,
#         "flashloan_end": 233794.54262032395,
#         "flashloan_end_usd": 233794.54262032395,
#         "flashloan_profit": -21306111.039673835,
#         "flashloan_profit_usd": -21306111.039673835
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 5745.275934826077,
#         "flashloan_start_usd": 21347089.810680423,
#         "flashloan_end": 5203.115444918693,
#         "flashloan_end_usd": 19332643.715985447,
#         "flashloan_profit": -2014446.0946949755,
#         "flashloan_profit_usd": -7484855764.987704
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 2.654317087934694,
#     "tBTC": 308.05081467463685
# }
# {
#     "USDC": 17882439.0571013,
#     "USDT": 276734.7914592559,
#     "GHO": 2956028.3643214577,
#     "RPL": 26678.771961821407,
#     "crvUSD": 115331.50298351892
# }
# {
#     "WBTC": 2.654317087934694,
#     "tBTC": 308.05081467463685
# }
# {
#     "USDC": 17882439.0571013,
#     "USDT": 276734.7914592559,
#     "GHO": 2956028.3643214577,
#     "RPL": 26678.771961821407,
#     "crvUSD": 115331.50298351892
# }
# {
#     "WBTC": 2.654317087934694,
#     "tBTC": 308.05081467463685
# }
# {
#     "USDC": 17882439.0571013,
#     "USDT": 276734.7914592559,
#     "GHO": 2956028.3643214577,
#     "RPL": 26678.771961821407,
#     "crvUSD": 115331.50298351892
# }
# {
#     "WBTC": 2.654317087934694,
#     "tBTC": 308.05081467463685
# }
# {
#     "USDC": 17882439.0571013,
#     "USDT": 276734.7914592559,
#     "GHO": 2956028.3643214577,
#     "RPL": 26678.771961821407,
#     "crvUSD": 115331.50298351892
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 21866413.257223733,
#         "flashloan_start_usd": 21854408.596345518,
#         "flashloan_end": 19034380.121169675,
#         "flashloan_end_usd": 19023930.24648315,
#         "flashloan_profit": -2830478.349862364,
#         "flashloan_profit_usd": -2828924.4172482896
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 21858131.233847674,
#         "flashloan_start_usd": 21858131.233847674,
#         "flashloan_end": 20243503.04672416,
#         "flashloan_end_usd": 20243503.04672416,
#         "flashloan_profit": -1614628.1871235147,
#         "flashloan_profit_usd": -1614628.1871235147
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 22014520.973180734,
#         "flashloan_start_usd": 22014520.973180734,
#         "flashloan_end": 233237.1382030398,
#         "flashloan_end_usd": 233237.1382030398,
#         "flashloan_profit": -21781283.834977694,
#         "flashloan_profit_usd": -21781283.834977694
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 5869.850801937219,
#         "flashloan_start_usd": 21809958.941169914,
#         "flashloan_end": 5233.936503299007,
#         "flashloan_end_usd": 19447162.13229276,
#         "flashloan_profit": -2362796.8088771547,
#         "flashloan_profit_usd": -8779184195.095867
#     }
# ]
# ****************************************************************************************************
# {
#     "WBTC": 2.70952128,
#     "tBTC": 314.45762131295174
# }
# {
#     "USDC": 18254356.038984,
#     "USDT": 282490.290924,
#     "GHO": 3017507.514011696,
#     "RPL": 27233.634098730923,
#     "crvUSD": 117730.1547764125
# }
# {
#     "WBTC": 2.70952128,
#     "tBTC": 314.45762131295174
# }
# {
#     "USDC": 18254356.038984,
#     "USDT": 282490.290924,
#     "GHO": 3017507.514011696,
#     "RPL": 27233.634098730923,
#     "crvUSD": 117730.1547764125
# }
# {
#     "WBTC": 2.70952128,
#     "tBTC": 314.45762131295174
# }
# {
#     "USDC": 18254356.038984,
#     "USDT": 282490.290924,
#     "GHO": 3017507.514011696,
#     "RPL": 27233.634098730923,
#     "crvUSD": 117730.1547764125
# }
# {
#     "WBTC": 2.70952128,
#     "tBTC": 314.45762131295174
# }
# {
#     "USDC": 18254356.038984,
#     "USDT": 282490.290924,
#     "GHO": 3017507.514011696,
#     "RPL": 27233.634098730923,
#     "crvUSD": 117730.1547764125
# }
# [
#     {
#         "flashloan_asset": "USDC",
#         "flashloan_asset_price": 0.999451,
#         "flashloan_start": 22332480.960010618,
#         "flashloan_start_usd": 22320220.427963573,
#         "flashloan_end": 19101940.94609745,
#         "flashloan_end_usd": 19091453.98051804,
#         "flashloan_profit": -3228766.447445531,
#         "flashloan_profit_usd": -3226993.8546658834
#     },
#     {
#         "flashloan_asset": "USDT",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 22324137.731692083,
#         "flashloan_start_usd": 22324137.731692083,
#         "flashloan_end": 20359689.358835213,
#         "flashloan_end_usd": 20359689.358835213,
#         "flashloan_profit": -1964448.3728568703,
#         "flashloan_profit_usd": -1964448.3728568703
#     },
#     {
#         "flashloan_asset": "DAI",
#         "flashloan_asset_price": 1.0,
#         "flashloan_start": 22490217.18701673,
#         "flashloan_start_usd": 22490217.18701673,
#         "flashloan_end": 232691.923621709,
#         "flashloan_end_usd": 232691.923621709,
#         "flashloan_profit": -22257525.26339502,
#         "flashloan_profit_usd": -22257525.26339502
#     },
#     {
#         "flashloan_asset": "WETH",
#         "flashloan_asset_price": 3715.59,
#         "flashloan_start": 5994.586224459907,
#         "flashloan_start_usd": 22273424.629740987,
#         "flashloan_end": 5262.025881296846,
#         "flashloan_end_usd": 19551530.744287748,
#         "flashloan_profit": -2721893.8854532368,
#         "flashloan_profit_usd": -10113441701.851192
#     }
# ]
# ****************************************************************************************************

# %%
# Sort the dataframe by scale
sorted_df = liquidation_profits_df.sort_values('scale')

# Find the point of maximum profit
max_profit_idx = sorted_df['flashloan_profit_usd'].idxmax()
max_profit_x = sorted_df.loc[max_profit_idx, 'scale']
max_profit_y = sorted_df.loc[max_profit_idx, 'flashloan_profit_usd']

# Find the point where profit turns negative
positive_profits = sorted_df[sorted_df['flashloan_profit_usd'] > 0]
if not positive_profits.empty:
    last_positive_idx = positive_profits.index[-1]
    zero_crossing_x = sorted_df.loc[last_positive_idx, 'scale']
    zero_crossing_y = 0
else:
    zero_crossing_x = zero_crossing_y = None

# Create the plot
plt.figure(figsize=(12, 8))
plt.scatter(sorted_df['scale'], sorted_df['flashloan_profit_usd'], alpha=0.6)
plt.plot(sorted_df['scale'], sorted_df['flashloan_profit_usd'], 'r-', alpha=0.3)

# Add vertical lines and annotations
plt.axvline(x=max_profit_x, color='g', linestyle='--', label='Max Profit')
plt.text(max_profit_x, plt.ylim()[1], f'Max Profit\n({max_profit_x:.4f}, {max_profit_y:.4f})', 
         rotation=90, va='top', ha='left', color='g')

if zero_crossing_x:
    plt.axvline(x=zero_crossing_x, color='r', linestyle='--', label='Profit turns negative')
    plt.text(zero_crossing_x, plt.ylim()[1], f'Profit turns negative\n({zero_crossing_x:.4f})', 
             rotation=90, va='top', ha='right', color='r')

# Adjust y-axis to give more space for labels
plt.ylim(plt.ylim()[0], plt.ylim()[1] * 1.1)

plt.xlabel('Scale')
plt.ylabel('Flashloan Profit USD')
plt.title('Flashloan Profit USD vs Scale')
plt.legend()

# Add grid for better readability
plt.grid(True, linestyle=':', alpha=0.7)

# Use scientific notation for y-axis if numbers are very large
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

# plt.tight_layout()
plt.show()

# Print the exact values
print(f"Maximum profit point: Scale = {max_profit_x:.2f}, Profit = {max_profit_y:.2f}")
if zero_crossing_x:
    print(f"Profit turns negative at: Scale = {zero_crossing_x:.2f}")
else:
    print("Profit does not turn negative within the given data range.")
# Out:
# Maximum profit point: Scale = 6.38, Profit = 6988582732.49
# Profit turns negative at: Scale = 10.29

# %% [markdown]
# ---
